# %%
import torch.nn as nn
import torch.optim as optim
import numpy as np
from torch_geometric.loader import DataLoader
import sys
import os
import torch
notebook_dir = os.getcwd()
project_root = os.path.abspath(os.path.join(notebook_dir, ".."))
sys.path.append(project_root)
from gnn_model.graph_structure_from_trajecotry import node_data_list
from gnn_model.message_passing_MLP import GNN_MLP
from gnn_model.train_model import train_model

# %%
import torch
import random

def generate_random_positions(N, dim, min_dist, box_size):
    positions = []
    while len(positions) < N:
        pos = torch.rand(dim) * box_size
        if all(torch.norm(pos - p) >= min_dist for p in positions):
            positions.append(pos)
    return torch.stack(positions)

def generate_random_velocities(N, dim, velocity_scale=1.0):
    return (torch.rand((N, dim)) - 0.5) * 2 * velocity_scale

def compute_gravitational_forces(positions, masses, G=1.0, eps=1e-5):
    N, dim = positions.shape
    forces = torch.zeros_like(positions)
    for i in range(N):
        for j in range(i + 1, N):
            r_vec = positions[j] - positions[i]
            dist = torch.norm(r_vec) + eps
            force_mag = G * masses[i] * masses[j] / dist**2
            force_dir = r_vec / dist
            force = force_mag * force_dir
            forces[i] += force
            forces[j] -= force
    return forces

def n_body_simulation(N=5, T=100, dt=0.01, dim=2,
                      mass_range=(1.0, 10.0), min_dist=0.5,
                      box_size=10.0, velocity_scale=1.0):
    # Initialize
    masses = torch.tensor([random.uniform(*mass_range) for _ in range(N)], dtype=torch.float32)
    positions = generate_random_positions(N, dim, min_dist, box_size)
    velocities = generate_random_velocities(N, dim, velocity_scale)

    # Store results
    trajectory = torch.zeros((T, N, dim), dtype=torch.float32)
    trajectory_velocities = torch.zeros((T, N, dim), dtype=torch.float32)
    t_array  = torch.arange(0, T * dt, dt, dtype=torch.float32)

    for t in range(T):
        trajectory[t] = positions
        trajectory_velocities[t] = velocities

        # Compute forces and update positions & velocities (Euler method)
        forces = compute_gravitational_forces(positions, masses)
        accelerations = forces / masses[:, None]
        velocities = velocities + accelerations * dt
        positions = positions + velocities * dt

    trajectory_data = {
        "time": t_array,
        "positions": trajectory,
        "velocities": trajectory_velocities,
        "masses": masses
    }

    return trajectory_data

# Example usage:
trajectory_data = n_body_simulation(N=5, T=200, dt=0.01, dim=2)
# print(trajectory_data)  # (T, N, dim)

# %%
nodes_data = node_data_list(trajectory_data,self_loop=False, complete_graph=True)
# Out:
# /Users/ruxi/Documents/GitHub/DeepLearningPH/gnn_model/graph_structure_from_trajecotry.py:81: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_target = torch.tensor(acceleration, dtype=torch.float32)

# %%
model = GNN_MLP(n_f=6, m_dim=2, out_channels=2, hidden_channels=128, single_node=True)

# %%
train_model(model, nodes_data, lr=0.01, epochs=100)
# Out:
# GNN_MLP()

# %%
# Output results
print("\nSimulation Results:")
for idx, data in enumerate(nodes_data):
    with torch.no_grad():
        pred_force = model(data.x, data.edge_index)  # Model predicts net force
        print(pred_force)
        # Ground truth force
        ground_truth_force = data.y
        print(ground_truth_force)
        
        # Ensure correct shapes and conversion to NumPy for printing
        pred_force_np = pred_force.cpu().numpy().flatten()  # Convert to NumPy array and flatten
        ground_truth_np = ground_truth_force.cpu().numpy().flatten()  # Convert to NumPy and flatten

        # Print each component of the force vector
        print(f"Sample {idx + 1}:")
        for i in range(len(pred_force_np)):
            print(f"   Component {i}: Ground Truth = {ground_truth_np[i]:.6f}, Predicted = {pred_force_np[i]:.6f}")
# Out:
# Simulation Results:
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-0.8364,  2.1248],
#         [-3.0196,  2.5127],
#         [ 0.8583, -2.4032],
#         [ 0.6074, -0.3552],
#         [ 1.6098, -1.3349]])
# Sample 1:
#    Component 0: Ground Truth = -0.836408, Predicted = -1.616510
#    Component 1: Ground Truth = 2.124828, Predicted = 0.238266
#    Component 2: Ground Truth = -3.019640, Predicted = -1.616510
#    Component 3: Ground Truth = 2.512685, Predicted = 0.238266
#    Component 4: Ground Truth = 0.858322, Predicted = -1.616510
#    Component 5: Ground Truth = -2.403229, Predicted = 0.238266
#    Component 6: Ground Truth = 0.607359, Predicted = -1.616510
#    Component 7: Ground Truth = -0.355160, Predicted = 0.238266
#    Component 8: Ground Truth = 1.609769, Predicted = -1.616510
#    Component 9: Ground Truth = -1.334894, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-0.8565,  2.1457],
#         [-2.9698,  2.4933],
#         [ 0.8314, -2.3937],
#         [ 0.6074, -0.3537],
#         [ 1.6373, -1.3658]])
# Sample 2:
#    Component 0: Ground Truth = -0.856462, Predicted = -1.616510
#    Component 1: Ground Truth = 2.145714, Predicted = 0.238266
#    Component 2: Ground Truth = -2.969763, Predicted = -1.616510
#    Component 3: Ground Truth = 2.493346, Predicted = 0.238266
#    Component 4: Ground Truth = 0.831364, Predicted = -1.616510
#    Component 5: Ground Truth = -2.393687, Predicted = 0.238266
#    Component 6: Ground Truth = 0.607383, Predicted = -1.616510
#    Component 7: Ground Truth = -0.353718, Predicted = 0.238266
#    Component 8: Ground Truth = 1.637316, Predicted = -1.616510
#    Component 9: Ground Truth = -1.365799, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-0.8775,  2.1677],
#         [-2.9225,  2.4759],
#         [ 0.8059, -2.3854],
#         [ 0.6074, -0.3523],
#         [ 1.6663, -1.3981]])
# Sample 3:
#    Component 0: Ground Truth = -0.877476, Predicted = -1.616510
#    Component 1: Ground Truth = 2.167684, Predicted = 0.238266
#    Component 2: Ground Truth = -2.922461, Predicted = -1.616510
#    Component 3: Ground Truth = 2.475935, Predicted = 0.238266
#    Component 4: Ground Truth = 0.805870, Predicted = -1.616510
#    Component 5: Ground Truth = -2.385372, Predicted = 0.238266
#    Component 6: Ground Truth = 0.607407, Predicted = -1.616510
#    Component 7: Ground Truth = -0.352287, Predicted = 0.238266
#    Component 8: Ground Truth = 1.666304, Predicted = -1.616510
#    Component 9: Ground Truth = -1.398116, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-0.8995,  2.1908],
#         [-2.8776,  2.4604],
#         [ 0.7817, -2.3783],
#         [ 0.6074, -0.3509],
#         [ 1.6968, -1.4319]])
# Sample 4:
#    Component 0: Ground Truth = -0.899521, Predicted = -1.616510
#    Component 1: Ground Truth = 2.190799, Predicted = 0.238266
#    Component 2: Ground Truth = -2.877557, Predicted = -1.616510
#    Component 3: Ground Truth = 2.460399, Predicted = 0.238266
#    Component 4: Ground Truth = 0.781739, Predicted = -1.616510
#    Component 5: Ground Truth = -2.378255, Predicted = 0.238266
#    Component 6: Ground Truth = 0.607428, Predicted = -1.616510
#    Component 7: Ground Truth = -0.350875, Predicted = 0.238266
#    Component 8: Ground Truth = 1.696831, Predicted = -1.616510
#    Component 9: Ground Truth = -1.431936, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-0.9227,  2.2151],
#         [-2.8349,  2.4467],
#         [ 0.7589, -2.3723],
#         [ 0.6075, -0.3495],
#         [ 1.7290, -1.4674]])
# Sample 5:
#    Component 0: Ground Truth = -0.922668, Predicted = -1.616510
#    Component 1: Ground Truth = 2.215117, Predicted = 0.238266
#    Component 2: Ground Truth = -2.834883, Predicted = -1.616510
#    Component 3: Ground Truth = 2.446684, Predicted = 0.238266
#    Component 4: Ground Truth = 0.758874, Predicted = -1.616510
#    Component 5: Ground Truth = -2.372300, Predicted = 0.238266
#    Component 6: Ground Truth = 0.607458, Predicted = -1.616510
#    Component 7: Ground Truth = -0.349480, Predicted = 0.238266
#    Component 8: Ground Truth = 1.729008, Predicted = -1.616510
#    Component 9: Ground Truth = -1.467359, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-0.9470,  2.2407],
#         [-2.7943,  2.4348],
#         [ 0.7372, -2.3675],
#         [ 0.6075, -0.3481],
#         [ 1.7630, -1.5045]])
# Sample 6:
#    Component 0: Ground Truth = -0.947005, Predicted = -1.616510
#    Component 1: Ground Truth = 2.240712, Predicted = 0.238266
#    Component 2: Ground Truth = -2.794281, Predicted = -1.616510
#    Component 3: Ground Truth = 2.434752, Predicted = 0.238266
#    Component 4: Ground Truth = 0.737189, Predicted = -1.616510
#    Component 5: Ground Truth = -2.367491, Predicted = 0.238266
#    Component 6: Ground Truth = 0.607488, Predicted = -1.616510
#    Component 7: Ground Truth = -0.348103, Predicted = 0.238266
#    Component 8: Ground Truth = 1.762951, Predicted = -1.616510
#    Component 9: Ground Truth = -1.504487, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-0.9726,  2.2677],
#         [-2.7556,  2.4246],
#         [ 0.7166, -2.3638],
#         [ 0.6075, -0.3467],
#         [ 1.7988, -1.5434]])
# Sample 7:
#    Component 0: Ground Truth = -0.972614, Predicted = -1.616510
#    Component 1: Ground Truth = 2.267670, Predicted = 0.238266
#    Component 2: Ground Truth = -2.755612, Predicted = -1.616510
#    Component 3: Ground Truth = 2.424565, Predicted = 0.238266
#    Component 4: Ground Truth = 0.716606, Predicted = -1.616510
#    Component 5: Ground Truth = -2.363795, Predicted = 0.238266
#    Component 6: Ground Truth = 0.607526, Predicted = -1.616510
#    Component 7: Ground Truth = -0.346744, Predicted = 0.238266
#    Component 8: Ground Truth = 1.798790, Predicted = -1.616510
#    Component 9: Ground Truth = -1.543444, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-0.9996,  2.2961],
#         [-2.7187,  2.4161],
#         [ 0.6970, -2.3612],
#         [ 0.6076, -0.3454],
#         [ 1.8367, -1.5844]])
# Sample 8:
#    Component 0: Ground Truth = -0.999600, Predicted = -1.616510
#    Component 1: Ground Truth = 2.296067, Predicted = 0.238266
#    Component 2: Ground Truth = -2.718744, Predicted = -1.616510
#    Component 3: Ground Truth = 2.416093, Predicted = 0.238266
#    Component 4: Ground Truth = 0.697050, Predicted = -1.616510
#    Component 5: Ground Truth = -2.361209, Predicted = 0.238266
#    Component 6: Ground Truth = 0.607565, Predicted = -1.616510
#    Component 7: Ground Truth = -0.345403, Predicted = 0.238266
#    Component 8: Ground Truth = 1.836673, Predicted = -1.616510
#    Component 9: Ground Truth = -1.584357, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-1.0281,  2.3260],
#         [-2.6836,  2.4093],
#         [ 0.6785, -2.3597],
#         [ 0.6076, -0.3441],
#         [ 1.8768, -1.6274]])
# Sample 9:
#    Component 0: Ground Truth = -1.028067, Predicted = -1.616510
#    Component 1: Ground Truth = 2.326000, Predicted = 0.238266
#    Component 2: Ground Truth = -2.683557, Predicted = -1.616510
#    Component 3: Ground Truth = 2.409313, Predicted = 0.238266
#    Component 4: Ground Truth = 0.678453, Predicted = -1.616510
#    Component 5: Ground Truth = -2.359713, Predicted = 0.238266
#    Component 6: Ground Truth = 0.607613, Predicted = -1.616510
#    Component 7: Ground Truth = -0.344074, Predicted = 0.238266
#    Component 8: Ground Truth = 1.876754, Predicted = -1.616510
#    Component 9: Ground Truth = -1.627356, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-1.0581,  2.3576],
#         [-2.6499,  2.4042],
#         [ 0.6608, -2.3593],
#         [ 0.6077, -0.3428],
#         [ 1.9192, -1.6726]])
# Sample 10:
#    Component 0: Ground Truth = -1.058140, Predicted = -1.616510
#    Component 1: Ground Truth = 2.357565, Predicted = 0.238266
#    Component 2: Ground Truth = -2.649938, Predicted = -1.616510
#    Component 3: Ground Truth = 2.404207, Predicted = 0.238266
#    Component 4: Ground Truth = 0.660753, Predicted = -1.616510
#    Component 5: Ground Truth = -2.359288, Predicted = 0.238266
#    Component 6: Ground Truth = 0.607666, Predicted = -1.616510
#    Component 7: Ground Truth = -0.342762, Predicted = 0.238266
#    Component 8: Ground Truth = 1.919209, Predicted = -1.616510
#    Component 9: Ground Truth = -1.672595, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-1.0899,  2.3909],
#         [-2.6178,  2.4008],
#         [ 0.6439, -2.3599],
#         [ 0.6077, -0.3415],
#         [ 1.9642, -1.7203]])
# Sample 11:
#    Component 0: Ground Truth = -1.089949, Predicted = -1.616510
#    Component 1: Ground Truth = 2.390886, Predicted = 0.238266
#    Component 2: Ground Truth = -2.617789, Predicted = -1.616510
#    Component 3: Ground Truth = 2.400765, Predicted = 0.238266
#    Component 4: Ground Truth = 0.643894, Predicted = -1.616510
#    Component 5: Ground Truth = -2.359939, Predicted = 0.238266
#    Component 6: Ground Truth = 0.607726, Predicted = -1.616510
#    Component 7: Ground Truth = -0.341469, Predicted = 0.238266
#    Component 8: Ground Truth = 1.964236, Predicted = -1.616510
#    Component 9: Ground Truth = -1.720250, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-1.1236,  2.4261],
#         [-2.5870,  2.3990],
#         [ 0.6278, -2.3617],
#         [ 0.6078, -0.3402],
#         [ 2.0120, -1.7705]])
# Sample 12:
#    Component 0: Ground Truth = -1.123637, Predicted = -1.616510
#    Component 1: Ground Truth = 2.426076, Predicted = 0.238266
#    Component 2: Ground Truth = -2.587003, Predicted = -1.616510
#    Component 3: Ground Truth = 2.398973, Predicted = 0.238266
#    Component 4: Ground Truth = 0.627819, Predicted = -1.616510
#    Component 5: Ground Truth = -2.361656, Predicted = 0.238266
#    Component 6: Ground Truth = 0.607795, Predicted = -1.616510
#    Component 7: Ground Truth = -0.340194, Predicted = 0.238266
#    Component 8: Ground Truth = 2.012045, Predicted = -1.616510
#    Component 9: Ground Truth = -1.770497, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-1.1594,  2.4633],
#         [-2.5575,  2.3988],
#         [ 0.6125, -2.3644],
#         [ 0.6079, -0.3389],
#         [ 2.0629, -1.8235]])
# Sample 13:
#    Component 0: Ground Truth = -1.159373, Predicted = -1.616510
#    Component 1: Ground Truth = 2.463270, Predicted = 0.238266
#    Component 2: Ground Truth = -2.557493, Predicted = -1.616510
#    Component 3: Ground Truth = 2.398836, Predicted = 0.238266
#    Component 4: Ground Truth = 0.612480, Predicted = -1.616510
#    Component 5: Ground Truth = -2.364439, Predicted = 0.238266
#    Component 6: Ground Truth = 0.607869, Predicted = -1.616510
#    Component 7: Ground Truth = -0.338930, Predicted = 0.238266
#    Component 8: Ground Truth = 2.062876, Predicted = -1.616510
#    Component 9: Ground Truth = -1.823539, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-1.1973,  2.5026],
#         [-2.5292,  2.4004],
#         [ 0.5978, -2.3683],
#         [ 0.6080, -0.3377],
#         [ 2.1170, -1.8796]])
# Sample 14:
#    Component 0: Ground Truth = -1.197336, Predicted = -1.616510
#    Component 1: Ground Truth = 2.502631, Predicted = 0.238266
#    Component 2: Ground Truth = -2.529167, Predicted = -1.616510
#    Component 3: Ground Truth = 2.400351, Predicted = 0.238266
#    Component 4: Ground Truth = 0.597825, Predicted = -1.616510
#    Component 5: Ground Truth = -2.368288, Predicted = 0.238266
#    Component 6: Ground Truth = 0.607952, Predicted = -1.616510
#    Component 7: Ground Truth = -0.337684, Predicted = 0.238266
#    Component 8: Ground Truth = 2.116989, Predicted = -1.616510
#    Component 9: Ground Truth = -1.879596, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-1.2377,  2.5443],
#         [-2.5020,  2.4035],
#         [ 0.5838, -2.3732],
#         [ 0.6080, -0.3365],
#         [ 2.1747, -1.9389]])
# Sample 15:
#    Component 0: Ground Truth = -1.237733, Predicted = -1.616510
#    Component 1: Ground Truth = 2.544310, Predicted = 0.238266
#    Component 2: Ground Truth = -2.501955, Predicted = -1.616510
#    Component 3: Ground Truth = 2.403537, Predicted = 0.238266
#    Component 4: Ground Truth = 0.583813, Predicted = -1.616510
#    Component 5: Ground Truth = -2.373215, Predicted = 0.238266
#    Component 6: Ground Truth = 0.608045, Predicted = -1.616510
#    Component 7: Ground Truth = -0.336457, Predicted = 0.238266
#    Component 8: Ground Truth = 2.174707, Predicted = -1.616510
#    Component 9: Ground Truth = -1.938923, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-1.2808,  2.5885],
#         [-2.4758,  2.4084],
#         [ 0.5704, -2.3792],
#         [ 0.6081, -0.3352],
#         [ 2.2363, -2.0018]])
# Sample 16:
#    Component 0: Ground Truth = -1.280785, Predicted = -1.616510
#    Component 1: Ground Truth = 2.588485, Predicted = 0.238266
#    Component 2: Ground Truth = -2.475767, Predicted = -1.616510
#    Component 3: Ground Truth = 2.408391, Predicted = 0.238266
#    Component 4: Ground Truth = 0.570395, Predicted = -1.616510
#    Component 5: Ground Truth = -2.379208, Predicted = 0.238266
#    Component 6: Ground Truth = 0.608149, Predicted = -1.616510
#    Component 7: Ground Truth = -0.335246, Predicted = 0.238266
#    Component 8: Ground Truth = 2.236341, Predicted = -1.616510
#    Component 9: Ground Truth = -2.001779, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-1.3268,  2.6354],
#         [-2.4505,  2.4149],
#         [ 0.5575, -2.3863],
#         [ 0.6083, -0.3341],
#         [ 2.3023, -2.0685]])
# Sample 17:
#    Component 0: Ground Truth = -1.326757, Predicted = -1.616510
#    Component 1: Ground Truth = 2.635382, Predicted = 0.238266
#    Component 2: Ground Truth = -2.450536, Predicted = -1.616510
#    Component 3: Ground Truth = 2.414947, Predicted = 0.238266
#    Component 4: Ground Truth = 0.557542, Predicted = -1.616510
#    Component 5: Ground Truth = -2.386295, Predicted = 0.238266
#    Component 6: Ground Truth = 0.608262, Predicted = -1.616510
#    Component 7: Ground Truth = -0.334054, Predicted = 0.238266
#    Component 8: Ground Truth = 2.302276, Predicted = -1.616510
#    Component 9: Ground Truth = -2.068483, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-1.3759,  2.6852],
#         [-2.4262,  2.4232],
#         [ 0.5452, -2.3945],
#         [ 0.6084, -0.3329],
#         [ 2.3730, -2.1394]])
# Sample 18:
#    Component 0: Ground Truth = -1.375937, Predicted = -1.616510
#    Component 1: Ground Truth = 2.685228, Predicted = 0.238266
#    Component 2: Ground Truth = -2.426203, Predicted = -1.616510
#    Component 3: Ground Truth = 2.423229, Predicted = 0.238266
#    Component 4: Ground Truth = 0.545207, Predicted = -1.616510
#    Component 5: Ground Truth = -2.394491, Predicted = 0.238266
#    Component 6: Ground Truth = 0.608385, Predicted = -1.616510
#    Component 7: Ground Truth = -0.332874, Predicted = 0.238266
#    Component 8: Ground Truth = 2.372952, Predicted = -1.616510
#    Component 9: Ground Truth = -2.139374, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-1.4286,  2.7382],
#         [-2.4027,  2.4333],
#         [ 0.5334, -2.4038],
#         [ 0.6085, -0.3317],
#         [ 2.4488, -2.2148]])
# Sample 19:
#    Component 0: Ground Truth = -1.428645, Predicted = -1.616510
#    Component 1: Ground Truth = 2.738248, Predicted = 0.238266
#    Component 2: Ground Truth = -2.402686, Predicted = -1.616510
#    Component 3: Ground Truth = 2.433256, Predicted = 0.238266
#    Component 4: Ground Truth = 0.533357, Predicted = -1.616510
#    Component 5: Ground Truth = -2.403800, Predicted = 0.238266
#    Component 6: Ground Truth = 0.608521, Predicted = -1.616510
#    Component 7: Ground Truth = -0.331712, Predicted = 0.238266
#    Component 8: Ground Truth = 2.448832, Predicted = -1.616510
#    Component 9: Ground Truth = -2.214812, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-1.4853,  2.7948],
#         [-2.3799,  2.4451],
#         [ 0.5220, -2.4143],
#         [ 0.6087, -0.3306],
#         [ 2.5305, -2.2953]])
# Sample 20:
#    Component 0: Ground Truth = -1.485260, Predicted = -1.616510
#    Component 1: Ground Truth = 2.794765, Predicted = 0.238266
#    Component 2: Ground Truth = -2.379923, Predicted = -1.616510
#    Component 3: Ground Truth = 2.445073, Predicted = 0.238266
#    Component 4: Ground Truth = 0.521958, Predicted = -1.616510
#    Component 5: Ground Truth = -2.414255, Predicted = 0.238266
#    Component 6: Ground Truth = 0.608667, Predicted = -1.616510
#    Component 7: Ground Truth = -0.330567, Predicted = 0.238266
#    Component 8: Ground Truth = 2.530478, Predicted = -1.616510
#    Component 9: Ground Truth = -2.295254, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-1.5462,  2.8551],
#         [-2.3579,  2.4587],
#         [ 0.5110, -2.4259],
#         [ 0.6088, -0.3294],
#         [ 2.6185, -2.3812]])
# Sample 21:
#    Component 0: Ground Truth = -1.546207, Predicted = -1.616510
#    Component 1: Ground Truth = 2.855077, Predicted = 0.238266
#    Component 2: Ground Truth = -2.357867, Predicted = -1.616510
#    Component 3: Ground Truth = 2.458724, Predicted = 0.238266
#    Component 4: Ground Truth = 0.510973, Predicted = -1.616510
#    Component 5: Ground Truth = -2.425876, Predicted = 0.238266
#    Component 6: Ground Truth = 0.608829, Predicted = -1.616510
#    Component 7: Ground Truth = -0.329435, Predicted = 0.238266
#    Component 8: Ground Truth = 2.618518, Predicted = -1.616510
#    Component 9: Ground Truth = -2.381160, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-1.6120,  2.9196],
#         [-2.3364,  2.4742],
#         [ 0.5004, -2.4387],
#         [ 0.6090, -0.3283],
#         [ 2.7137, -2.4731]])
# Sample 22:
#    Component 0: Ground Truth = -1.611964, Predicted = -1.616510
#    Component 1: Ground Truth = 2.919553, Predicted = 0.238266
#    Component 2: Ground Truth = -2.336435, Predicted = -1.616510
#    Component 3: Ground Truth = 2.474247, Predicted = 0.238266
#    Component 4: Ground Truth = 0.500372, Predicted = -1.616510
#    Component 5: Ground Truth = -2.438681, Predicted = 0.238266
#    Component 6: Ground Truth = 0.609004, Predicted = -1.616510
#    Component 7: Ground Truth = -0.328320, Predicted = 0.238266
#    Component 8: Ground Truth = 2.713655, Predicted = -1.616510
#    Component 9: Ground Truth = -2.473067, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-1.6831,  2.9886],
#         [-2.3156,  2.4917],
#         [ 0.4901, -2.4527],
#         [ 0.6092, -0.3272],
#         [ 2.8167, -2.5716]])
# Sample 23:
#    Component 0: Ground Truth = -1.683098, Predicted = -1.616510
#    Component 1: Ground Truth = 2.988616, Predicted = 0.238266
#    Component 2: Ground Truth = -2.315589, Predicted = -1.616510
#    Component 3: Ground Truth = 2.491710, Predicted = 0.238266
#    Component 4: Ground Truth = 0.490124, Predicted = -1.616510
#    Component 5: Ground Truth = -2.452718, Predicted = 0.238266
#    Component 6: Ground Truth = 0.609193, Predicted = -1.616510
#    Component 7: Ground Truth = -0.327224, Predicted = 0.238266
#    Component 8: Ground Truth = 2.816739, Predicted = -1.616510
#    Component 9: Ground Truth = -2.571597, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-1.7602,  3.0627],
#         [-2.2953,  2.5112],
#         [ 0.4802, -2.4680],
#         [ 0.6094, -0.3261],
#         [ 2.9287, -2.6774]])
# Sample 24:
#    Component 0: Ground Truth = -1.760245, Predicted = -1.616510
#    Component 1: Ground Truth = 3.062723, Predicted = 0.238266
#    Component 2: Ground Truth = -2.295260, Predicted = -1.616510
#    Component 3: Ground Truth = 2.511160, Predicted = 0.238266
#    Component 4: Ground Truth = 0.480196, Predicted = -1.616510
#    Component 5: Ground Truth = -2.468004, Predicted = 0.238266
#    Component 6: Ground Truth = 0.609395, Predicted = -1.616510
#    Component 7: Ground Truth = -0.326139, Predicted = 0.238266
#    Component 8: Ground Truth = 2.928696, Predicted = -1.616510
#    Component 9: Ground Truth = -2.677439, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-1.8442,  3.1424],
#         [-2.2754,  2.5327],
#         [ 0.4706, -2.4846],
#         [ 0.6096, -0.3251],
#         [ 3.0507, -2.7914]])
# Sample 25:
#    Component 0: Ground Truth = -1.844159, Predicted = -1.616510
#    Component 1: Ground Truth = 3.142427, Predicted = 0.238266
#    Component 2: Ground Truth = -2.275394, Predicted = -1.616510
#    Component 3: Ground Truth = 2.532678, Predicted = 0.238266
#    Component 4: Ground Truth = 0.470558, Predicted = -1.616510
#    Component 5: Ground Truth = -2.484591, Predicted = 0.238266
#    Component 6: Ground Truth = 0.609612, Predicted = -1.616510
#    Component 7: Ground Truth = -0.325072, Predicted = 0.238266
#    Component 8: Ground Truth = 3.050659, Predicted = -1.616510
#    Component 9: Ground Truth = -2.791415, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-1.9357,  3.2283],
#         [-2.2559,  2.5563],
#         [ 0.4612, -2.5025],
#         [ 0.6098, -0.3240],
#         [ 3.1839, -2.9144]])
# Sample 26:
#    Component 0: Ground Truth = -1.935714, Predicted = -1.616510
#    Component 1: Ground Truth = 3.228322, Predicted = 0.238266
#    Component 2: Ground Truth = -2.255943, Predicted = -1.616510
#    Component 3: Ground Truth = 2.556341, Predicted = 0.238266
#    Component 4: Ground Truth = 0.461176, Predicted = -1.616510
#    Component 5: Ground Truth = -2.502521, Predicted = 0.238266
#    Component 6: Ground Truth = 0.609848, Predicted = -1.616510
#    Component 7: Ground Truth = -0.324023, Predicted = 0.238266
#    Component 8: Ground Truth = 3.183916, Predicted = -1.616510
#    Component 9: Ground Truth = -2.914420, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-2.0359,  3.3211],
#         [-2.2368,  2.5822],
#         [ 0.4520, -2.5218],
#         [ 0.6101, -0.3230],
#         [ 3.3300, -3.0475]])
# Sample 27:
#    Component 0: Ground Truth = -2.035927, Predicted = -1.616510
#    Component 1: Ground Truth = 3.321138, Predicted = 0.238266
#    Component 2: Ground Truth = -2.236839, Predicted = -1.616510
#    Component 3: Ground Truth = 2.582223, Predicted = 0.238266
#    Component 4: Ground Truth = 0.452024, Predicted = -1.616510
#    Component 5: Ground Truth = -2.521836, Predicted = 0.238266
#    Component 6: Ground Truth = 0.610099, Predicted = -1.616510
#    Component 7: Ground Truth = -0.322986, Predicted = 0.238266
#    Component 8: Ground Truth = 3.329972, Predicted = -1.616510
#    Component 9: Ground Truth = -3.047517, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-2.1460,  3.4217],
#         [-2.2180,  2.6104],
#         [ 0.4431, -2.5426],
#         [ 0.6104, -0.3220],
#         [ 3.4906, -3.1919]])
# Sample 28:
#    Component 0: Ground Truth = -2.146003, Predicted = -1.616510
#    Component 1: Ground Truth = 3.421669, Predicted = 0.238266
#    Component 2: Ground Truth = -2.218021, Predicted = -1.616510
#    Component 3: Ground Truth = 2.610417, Predicted = 0.238266
#    Component 4: Ground Truth = 0.443067, Predicted = -1.616510
#    Component 5: Ground Truth = -2.542583, Predicted = 0.238266
#    Component 6: Ground Truth = 0.610368, Predicted = -1.616510
#    Component 7: Ground Truth = -0.321966, Predicted = 0.238266
#    Component 8: Ground Truth = 3.490614, Predicted = -1.616510
#    Component 9: Ground Truth = -3.191918, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-2.2674,  3.5309],
#         [-2.1995,  2.6411],
#         [ 0.4343, -2.5648],
#         [ 0.6107, -0.3210],
#         [ 3.6680, -3.3491]])
# Sample 29:
#    Component 0: Ground Truth = -2.267393, Predicted = -1.616510
#    Component 1: Ground Truth = 3.530923, Predicted = 0.238266
#    Component 2: Ground Truth = -2.199455, Predicted = -1.616510
#    Component 3: Ground Truth = 2.641050, Predicted = 0.238266
#    Component 4: Ground Truth = 0.434277, Predicted = -1.616510
#    Component 5: Ground Truth = -2.564848, Predicted = 0.238266
#    Component 6: Ground Truth = 0.610656, Predicted = -1.616510
#    Component 7: Ground Truth = -0.320959, Predicted = 0.238266
#    Component 8: Ground Truth = 3.668014, Predicted = -1.616510
#    Component 9: Ground Truth = -3.349069, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-2.4018,  3.6500],
#         [-2.1811,  2.6742],
#         [ 0.4256, -2.5887],
#         [ 0.6110, -0.3200],
#         [ 3.8647, -3.5206]])
# Sample 30:
#    Component 0: Ground Truth = -2.401793, Predicted = -1.616510
#    Component 1: Ground Truth = 3.649966, Predicted = 0.238266
#    Component 2: Ground Truth = -2.181067, Predicted = -1.616510
#    Component 3: Ground Truth = 2.674211, Predicted = 0.238266
#    Component 4: Ground Truth = 0.425619, Predicted = -1.616510
#    Component 5: Ground Truth = -2.588666, Predicted = 0.238266
#    Component 6: Ground Truth = 0.610963, Predicted = -1.616510
#    Component 7: Ground Truth = -0.319970, Predicted = 0.238266
#    Component 8: Ground Truth = 3.864661, Predicted = -1.616510
#    Component 9: Ground Truth = -3.520611, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-2.5513,  3.7801],
#         [-2.1628,  2.7100],
#         [ 0.4171, -2.6141],
#         [ 0.6113, -0.3190],
#         [ 4.0836, -3.7085]])
# Sample 31:
#    Component 0: Ground Truth = -2.551266, Predicted = -1.616510
#    Component 1: Ground Truth = 3.780143, Predicted = 0.238266
#    Component 2: Ground Truth = -2.162786, Predicted = -1.616510
#    Component 3: Ground Truth = 2.710027, Predicted = 0.238266
#    Component 4: Ground Truth = 0.417056, Predicted = -1.616510
#    Component 5: Ground Truth = -2.614114, Predicted = 0.238266
#    Component 6: Ground Truth = 0.611289, Predicted = -1.616510
#    Component 7: Ground Truth = -0.318997, Predicted = 0.238266
#    Component 8: Ground Truth = 4.083625, Predicted = -1.616510
#    Component 9: Ground Truth = -3.708522, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-2.7183,  3.9231],
#         [-2.1446,  2.7487],
#         [ 0.4086, -2.6413],
#         [ 0.6116, -0.3180],
#         [ 4.3287, -3.9152]])
# Sample 32:
#    Component 0: Ground Truth = -2.718344, Predicted = -1.616510
#    Component 1: Ground Truth = 3.923062, Predicted = 0.238266
#    Component 2: Ground Truth = -2.144577, Predicted = -1.616510
#    Component 3: Ground Truth = 2.748659, Predicted = 0.238266
#    Component 4: Ground Truth = 0.408563, Predicted = -1.616510
#    Component 5: Ground Truth = -2.641293, Predicted = 0.238266
#    Component 6: Ground Truth = 0.611637, Predicted = -1.616510
#    Component 7: Ground Truth = -0.318033, Predicted = 0.238266
#    Component 8: Ground Truth = 4.328684, Predicted = -1.616510
#    Component 9: Ground Truth = -3.915159, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-2.9061,  4.0805],
#         [-2.1264,  2.7902],
#         [ 0.4001, -2.6703],
#         [ 0.6120, -0.3171],
#         [ 4.6043, -4.1433]])
# Sample 33:
#    Component 0: Ground Truth = -2.906072, Predicted = -1.616510
#    Component 1: Ground Truth = 4.080538, Predicted = 0.238266
#    Component 2: Ground Truth = -2.126350, Predicted = -1.616510
#    Component 3: Ground Truth = 2.790233, Predicted = 0.238266
#    Component 4: Ground Truth = 0.400094, Predicted = -1.616510
#    Component 5: Ground Truth = -2.670261, Predicted = 0.238266
#    Component 6: Ground Truth = 0.612006, Predicted = -1.616510
#    Component 7: Ground Truth = -0.317091, Predicted = 0.238266
#    Component 8: Ground Truth = 4.604332, Predicted = -1.616510
#    Component 9: Ground Truth = -4.143266, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-3.1183,  4.2548],
#         [-2.1080,  2.8349],
#         [ 0.3916, -2.7011],
#         [ 0.6124, -0.3162],
#         [ 4.9162, -4.3962]])
# Sample 34:
#    Component 0: Ground Truth = -3.118251, Predicted = -1.616510
#    Component 1: Ground Truth = 4.254845, Predicted = 0.238266
#    Component 2: Ground Truth = -2.108033, Predicted = -1.616510
#    Component 3: Ground Truth = 2.834916, Predicted = 0.238266
#    Component 4: Ground Truth = 0.391611, Predicted = -1.616510
#    Component 5: Ground Truth = -2.701115, Predicted = 0.238266
#    Component 6: Ground Truth = 0.612395, Predicted = -1.616510
#    Component 7: Ground Truth = -0.316160, Predicted = 0.238266
#    Component 8: Ground Truth = 4.916241, Predicted = -1.616510
#    Component 9: Ground Truth = -4.396215, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-3.3597,  4.4488],
#         [-2.0896,  2.8829],
#         [ 0.3831, -2.7340],
#         [ 0.6128, -0.3152],
#         [ 5.2715, -4.6781]])
# Sample 35:
#    Component 0: Ground Truth = -3.359658, Predicted = -1.616510
#    Component 1: Ground Truth = 4.448752, Predicted = 0.238266
#    Component 2: Ground Truth = -2.089598, Predicted = -1.616510
#    Component 3: Ground Truth = 2.882913, Predicted = 0.238266
#    Component 4: Ground Truth = 0.383076, Predicted = -1.616510
#    Component 5: Ground Truth = -2.733982, Predicted = 0.238266
#    Component 6: Ground Truth = 0.612814, Predicted = -1.616510
#    Component 7: Ground Truth = -0.315243, Predicted = 0.238266
#    Component 8: Ground Truth = 5.271488, Predicted = -1.616510
#    Component 9: Ground Truth = -4.678111, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-3.6363,  4.6656],
#         [-2.0709,  2.9344],
#         [ 0.3744, -2.7690],
#         [ 0.6133, -0.3143],
#         [ 5.6790, -4.9939]])
# Sample 36:
#    Component 0: Ground Truth = -3.636271, Predicted = -1.616510
#    Component 1: Ground Truth = 4.665594, Predicted = 0.238266
#    Component 2: Ground Truth = -2.070918, Predicted = -1.616510
#    Component 3: Ground Truth = 2.934396, Predicted = 0.238266
#    Component 4: Ground Truth = 0.374443, Predicted = -1.616510
#    Component 5: Ground Truth = -2.768950, Predicted = 0.238266
#    Component 6: Ground Truth = 0.613252, Predicted = -1.616510
#    Component 7: Ground Truth = -0.314343, Predicted = 0.238266
#    Component 8: Ground Truth = 5.678969, Predicted = -1.616510
#    Component 9: Ground Truth = -4.993908, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-3.9558,  4.9095],
#         [-2.0519,  2.9896],
#         [ 0.3657, -2.8061],
#         [ 0.6137, -0.3135],
#         [ 6.1501, -5.3498]])
# Sample 37:
#    Component 0: Ground Truth = -3.955790, Predicted = -1.616510
#    Component 1: Ground Truth = 4.909529, Predicted = 0.238266
#    Component 2: Ground Truth = -2.051934, Predicted = -1.616510
#    Component 3: Ground Truth = 2.989593, Predicted = 0.238266
#    Component 4: Ground Truth = 0.365665, Predicted = -1.616510
#    Component 5: Ground Truth = -2.806146, Predicted = 0.238266
#    Component 6: Ground Truth = 0.613715, Predicted = -1.616510
#    Component 7: Ground Truth = -0.313454, Predicted = 0.238266
#    Component 8: Ground Truth = 6.150102, Predicted = -1.616510
#    Component 9: Ground Truth = -5.349780, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-4.3283,  5.1858],
#         [-2.0326,  3.0488],
#         [ 0.3567, -2.8457],
#         [ 0.6142, -0.3126],
#         [ 6.6998, -5.7535]])
# Sample 38:
#    Component 0: Ground Truth = -4.328255, Predicted = -1.616510
#    Component 1: Ground Truth = 5.185788, Predicted = 0.238266
#    Component 2: Ground Truth = -2.032568, Predicted = -1.616510
#    Component 3: Ground Truth = 3.048760, Predicted = 0.238266
#    Component 4: Ground Truth = 0.356689, Predicted = -1.616510
#    Component 5: Ground Truth = -2.845729, Predicted = 0.238266
#    Component 6: Ground Truth = 0.614212, Predicted = -1.616510
#    Component 7: Ground Truth = -0.312585, Predicted = 0.238266
#    Component 8: Ground Truth = 6.699819, Predicted = -1.616510
#    Component 9: Ground Truth = -5.753511, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-4.7669,  5.5009],
#         [-2.0127,  3.1121],
#         [ 0.3475, -2.8878],
#         [ 0.6147, -0.3117],
#         [ 7.3477, -6.2149]])
# Sample 39:
#    Component 0: Ground Truth = -4.766856, Predicted = -1.616510
#    Component 1: Ground Truth = 5.500942, Predicted = 0.238266
#    Component 2: Ground Truth = -2.012696, Predicted = -1.616510
#    Component 3: Ground Truth = 3.112143, Predicted = 0.238266
#    Component 4: Ground Truth = 0.347454, Predicted = -1.616510
#    Component 5: Ground Truth = -2.887825, Predicted = 0.238266
#    Component 6: Ground Truth = 0.614730, Predicted = -1.616510
#    Component 7: Ground Truth = -0.311727, Predicted = 0.238266
#    Component 8: Ground Truth = 7.347722, Predicted = -1.616510
#    Component 9: Ground Truth = -6.214863, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-5.2894,  5.8635],
#         [-1.9922,  3.1800],
#         [ 0.3379, -2.9326],
#         [ 0.6153, -0.3109],
#         [ 8.1202, -6.7464]])
# Sample 40:
#    Component 0: Ground Truth = -5.289395, Predicted = -1.616510
#    Component 1: Ground Truth = 5.863464, Predicted = 0.238266
#    Component 2: Ground Truth = -1.992234, Predicted = -1.616510
#    Component 3: Ground Truth = 3.180027, Predicted = 0.238266
#    Component 4: Ground Truth = 0.337901, Predicted = -1.616510
#    Component 5: Ground Truth = -2.932603, Predicted = 0.238266
#    Component 6: Ground Truth = 0.615280, Predicted = -1.616510
#    Component 7: Ground Truth = -0.310885, Predicted = 0.238266
#    Component 8: Ground Truth = 8.120234, Predicted = -1.616510
#    Component 9: Ground Truth = -6.746397, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-5.9204,  6.2844],
#         [-1.9711,  3.2528],
#         [ 0.3280, -2.9803],
#         [ 0.6159, -0.3101],
#         [ 9.0538, -7.3645]])
# Sample 41:
#    Component 0: Ground Truth = -5.920389, Predicted = -1.616510
#    Component 1: Ground Truth = 6.284386, Predicted = 0.238266
#    Component 2: Ground Truth = -1.971068, Predicted = -1.616510
#    Component 3: Ground Truth = 3.252766, Predicted = 0.238266
#    Component 4: Ground Truth = 0.327960, Predicted = -1.616510
#    Component 5: Ground Truth = -2.980271, Predicted = 0.238266
#    Component 6: Ground Truth = 0.615863, Predicted = -1.616510
#    Component 7: Ground Truth = -0.310058, Predicted = 0.238266
#    Component 8: Ground Truth = 9.053811, Predicted = -1.616510
#    Component 9: Ground Truth = -7.364542, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-6.6942,  6.7783],
#         [-1.9490,  3.3307],
#         [ 0.3175, -3.0310],
#         [ 0.6165, -0.3092],
#         [10.1995, -8.0909]])
# Sample 42:
#    Component 0: Ground Truth = -6.694229, Predicted = -1.616510
#    Component 1: Ground Truth = 6.778274, Predicted = 0.238266
#    Component 2: Ground Truth = -1.949044, Predicted = -1.616510
#    Component 3: Ground Truth = 3.330677, Predicted = 0.238266
#    Component 4: Ground Truth = 0.317546, Predicted = -1.616510
#    Component 5: Ground Truth = -3.030994, Predicted = 0.238266
#    Component 6: Ground Truth = 0.616475, Predicted = -1.616510
#    Component 7: Ground Truth = -0.309246, Predicted = 0.238266
#    Component 8: Ground Truth = 10.199526, Predicted = -1.616510
#    Component 9: Ground Truth = -8.090920, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-7.6609,  7.3648],
#         [-1.9261,  3.4142],
#         [ 0.3066, -3.0850],
#         [ 0.6171, -0.3084],
#         [11.6317, -8.9548]])
# Sample 43:
#    Component 0: Ground Truth = -7.660903, Predicted = -1.616510
#    Component 1: Ground Truth = 7.364829, Predicted = 0.238266
#    Component 2: Ground Truth = -1.926066, Predicted = -1.616510
#    Component 3: Ground Truth = 3.414193, Predicted = 0.238266
#    Component 4: Ground Truth = 0.306583, Predicted = -1.616510
#    Component 5: Ground Truth = -3.085037, Predicted = 0.238266
#    Component 6: Ground Truth = 0.617126, Predicted = -1.616510
#    Component 7: Ground Truth = -0.308448, Predicted = 0.238266
#    Component 8: Ground Truth = 11.631655, Predicted = -1.616510
#    Component 9: Ground Truth = -8.954820, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-8.8951,  8.0710],
#         [-1.9019,  3.5037],
#         [ 0.2950, -3.1426],
#         [ 0.6178, -0.3077],
#         [13.4611, -9.9963]])
# Sample 44:
#    Component 0: Ground Truth = -8.895096, Predicted = -1.616510
#    Component 1: Ground Truth = 8.071025, Predicted = 0.238266
#    Component 2: Ground Truth = -1.901938, Predicted = -1.616510
#    Component 3: Ground Truth = 3.503713, Predicted = 0.238266
#    Component 4: Ground Truth = 0.294960, Predicted = -1.616510
#    Component 5: Ground Truth = -3.142618, Predicted = 0.238266
#    Component 6: Ground Truth = 0.617812, Predicted = -1.616510
#    Component 7: Ground Truth = -0.307668, Predicted = 0.238266
#    Component 8: Ground Truth = 13.461149, Predicted = -1.616510
#    Component 9: Ground Truth = -9.996257, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-10.5132,   8.9346],
#         [ -1.8765,   3.5997],
#         [  0.2826,  -3.2040],
#         [  0.6185,  -0.3069],
#         [ 15.8610, -11.2713]])
# Sample 45:
#    Component 0: Ground Truth = -10.513206, Predicted = -1.616510
#    Component 1: Ground Truth = 8.934599, Predicted = 0.238266
#    Component 2: Ground Truth = -1.876505, Predicted = -1.616510
#    Component 3: Ground Truth = 3.599732, Predicted = 0.238266
#    Component 4: Ground Truth = 0.282573, Predicted = -1.616510
#    Component 5: Ground Truth = -3.204014, Predicted = 0.238266
#    Component 6: Ground Truth = 0.618533, Predicted = -1.616510
#    Component 7: Ground Truth = -0.306898, Predicted = 0.238266
#    Component 8: Ground Truth = 15.860978, Predicted = -1.616510
#    Component 9: Ground Truth = -11.271335, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-12.7057,  10.0094],
#         [ -1.8496,   3.7028],
#         [  0.2693,  -3.2696],
#         [  0.6193,  -0.3062],
#         [ 19.1140, -12.8601]])
# Sample 46:
#    Component 0: Ground Truth = -12.705696, Predicted = -1.616510
#    Component 1: Ground Truth = 10.009441, Predicted = 0.238266
#    Component 2: Ground Truth = -1.849558, Predicted = -1.616510
#    Component 3: Ground Truth = 3.702817, Predicted = 0.238266
#    Component 4: Ground Truth = 0.269288, Predicted = -1.616510
#    Component 5: Ground Truth = -3.269568, Predicted = 0.238266
#    Component 6: Ground Truth = 0.619300, Predicted = -1.616510
#    Component 7: Ground Truth = -0.306154, Predicted = 0.238266
#    Component 8: Ground Truth = 19.114037, Predicted = -1.616510
#    Component 9: Ground Truth = -12.860120, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-15.8029,  11.3730],
#         [ -1.8209,   3.8135],
#         [  0.2550,  -3.3396],
#         [  0.6201,  -0.3054],
#         [ 23.7112, -14.8777]])
# Sample 47:
#    Component 0: Ground Truth = -15.802923, Predicted = -1.616510
#    Component 1: Ground Truth = 11.373030, Predicted = 0.238266
#    Component 2: Ground Truth = -1.820876, Predicted = -1.616510
#    Component 3: Ground Truth = 3.813533, Predicted = 0.238266
#    Component 4: Ground Truth = 0.254965, Predicted = -1.616510
#    Component 5: Ground Truth = -3.339589, Predicted = 0.238266
#    Component 6: Ground Truth = 0.620112, Predicted = -1.616510
#    Component 7: Ground Truth = -0.305420, Predicted = 0.238266
#    Component 8: Ground Truth = 23.711155, Predicted = -1.616510
#    Component 9: Ground Truth = -14.877667, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-20.4244,  13.1350],
#         [ -1.7902,   3.9326],
#         [  0.2394,  -3.4145],
#         [  0.6210,  -0.3047],
#         [ 30.5727, -17.4869]])
# Sample 48:
#    Component 0: Ground Truth = -20.424374, Predicted = -1.616510
#    Component 1: Ground Truth = 13.134993, Predicted = 0.238266
#    Component 2: Ground Truth = -1.790215, Predicted = -1.616510
#    Component 3: Ground Truth = 3.932575, Predicted = 0.238266
#    Component 4: Ground Truth = 0.239429, Predicted = -1.616510
#    Component 5: Ground Truth = -3.414470, Predicted = 0.238266
#    Component 6: Ground Truth = 0.620972, Predicted = -1.616510
#    Component 7: Ground Truth = -0.304705, Predicted = 0.238266
#    Component 8: Ground Truth = 30.572681, Predicted = -1.616510
#    Component 9: Ground Truth = -17.486898, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-27.8553,  15.4313],
#         [ -1.7573,   4.0607],
#         [  0.2225,  -3.4947],
#         [  0.6219,  -0.3040],
#         [ 41.6078, -20.8899]])
# Sample 49:
#    Component 0: Ground Truth = -27.855255, Predicted = -1.616510
#    Component 1: Ground Truth = 15.431347, Predicted = 0.238266
#    Component 2: Ground Truth = -1.757266, Predicted = -1.616510
#    Component 3: Ground Truth = 4.060708, Predicted = 0.238266
#    Component 4: Ground Truth = 0.222486, Predicted = -1.616510
#    Component 5: Ground Truth = -3.494650, Predicted = 0.238266
#    Component 6: Ground Truth = 0.621889, Predicted = -1.616510
#    Component 7: Ground Truth = -0.304020, Predicted = 0.238266
#    Component 8: Ground Truth = 41.607849, Predicted = -1.616510
#    Component 9: Ground Truth = -20.889851, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[-41.1640,  18.2994],
#         [ -1.7217,   4.1988],
#         [  0.2039,  -3.5806],
#         [  0.6229,  -0.3034],
#         [ 61.3752, -25.1419]])
# Sample 50:
#    Component 0: Ground Truth = -41.164028, Predicted = -1.616510
#    Component 1: Ground Truth = 18.299400, Predicted = 0.238266
#    Component 2: Ground Truth = -1.721724, Predicted = -1.616510
#    Component 3: Ground Truth = 4.198781, Predicted = 0.238266
#    Component 4: Ground Truth = 0.203907, Predicted = -1.616510
#    Component 5: Ground Truth = -3.580599, Predicted = 0.238266
#    Component 6: Ground Truth = 0.622864, Predicted = -1.616510
#    Component 7: Ground Truth = -0.303351, Predicted = 0.238266
#    Component 8: Ground Truth = 61.375183, Predicted = -1.616510
#    Component 9: Ground Truth = -25.141903, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.0857, -0.4971]])
# tensor([[-69.3556,  20.6113],
#         [ -1.6832,   4.3478],
#         [  0.1834,  -3.6729],
#         [  0.6239,  -0.3027],
#         [103.2521, -28.5677]])
# Sample 51:
#    Component 0: Ground Truth = -69.355568, Predicted = -1.616510
#    Component 1: Ground Truth = 20.611330, Predicted = 0.238266
#    Component 2: Ground Truth = -1.683237, Predicted = -1.616510
#    Component 3: Ground Truth = 4.347829, Predicted = 0.238266
#    Component 4: Ground Truth = 0.183413, Predicted = -1.616510
#    Component 5: Ground Truth = -3.672886, Predicted = 0.238266
#    Component 6: Ground Truth = 0.623918, Predicted = -1.616510
#    Component 7: Ground Truth = -0.302726, Predicted = 0.238266
#    Component 8: Ground Truth = 103.252083, Predicted = -1.085679
#    Component 9: Ground Truth = -28.567747, Predicted = -0.497109
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [29.7987, 10.2756]])
# tensor([[-1.4881e+02,  8.4542e+00],
#         [-1.6414e+00,  4.5090e+00],
#         [ 1.6067e-01, -3.7721e+00],
#         [ 6.2506e-01, -3.0215e-01],
#         [ 2.2128e+02, -1.0499e+01]])
# Sample 52:
#    Component 0: Ground Truth = -148.806717, Predicted = -1.616510
#    Component 1: Ground Truth = 8.454164, Predicted = 0.238266
#    Component 2: Ground Truth = -1.641382, Predicted = -1.616510
#    Component 3: Ground Truth = 4.509018, Predicted = 0.238266
#    Component 4: Ground Truth = 0.160667, Predicted = -1.616510
#    Component 5: Ground Truth = -3.772084, Predicted = 0.238266
#    Component 6: Ground Truth = 0.625061, Predicted = -1.616510
# ...
#    Component 6: Ground Truth = 0.412560, Predicted = -1.616510
#    Component 7: Ground Truth = -0.560248, Predicted = 0.238266
#    Component 8: Ground Truth = -0.264645, Predicted = -1.616510
#    Component 9: Ground Truth = -0.008154, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[ 0.4230,  0.6976],
#         [-2.0169,  5.4681],
#         [ 0.4832, -3.3189],
#         [ 0.4072, -0.5580],
#         [-0.2607, -0.0089]])
# Sample 183:
#    Component 0: Ground Truth = 0.423021, Predicted = -1.616510
#    Component 1: Ground Truth = 0.697647, Predicted = 0.238266
#    Component 2: Ground Truth = -2.016880, Predicted = -1.616510
#    Component 3: Ground Truth = 5.468121, Predicted = 0.238266
#    Component 4: Ground Truth = 0.483192, Predicted = -1.616510
#    Component 5: Ground Truth = -3.318905, Predicted = 0.238266
#    Component 6: Ground Truth = 0.407155, Predicted = -1.616510
#    Component 7: Ground Truth = -0.557977, Predicted = 0.238266
#    Component 8: Ground Truth = -0.260684, Predicted = -1.616510
#    Component 9: Ground Truth = -0.008869, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[ 0.4291,  0.6945],
#         [-2.0008,  5.6659],
#         [ 0.4699, -3.4308],
#         [ 0.4019, -0.5554],
#         [-0.2568, -0.0095]])
# Sample 184:
#    Component 0: Ground Truth = 0.429082, Predicted = -1.616510
#    Component 1: Ground Truth = 0.694544, Predicted = 0.238266
#    Component 2: Ground Truth = -2.000787, Predicted = -1.616510
#    Component 3: Ground Truth = 5.665874, Predicted = 0.238266
#    Component 4: Ground Truth = 0.469918, Predicted = -1.616510
#    Component 5: Ground Truth = -3.430847, Predicted = 0.238266
#    Component 6: Ground Truth = 0.401867, Predicted = -1.616510
#    Component 7: Ground Truth = -0.555444, Predicted = 0.238266
#    Component 8: Ground Truth = -0.256825, Predicted = -1.616510
#    Component 9: Ground Truth = -0.009537, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[ 0.4351,  0.6912],
#         [-1.9818,  5.8807],
#         [ 0.4550, -3.5526],
#         [ 0.3967, -0.5526],
#         [-0.2530, -0.0102]])
# Sample 185:
#    Component 0: Ground Truth = 0.435138, Predicted = -1.616510
#    Component 1: Ground Truth = 0.691218, Predicted = 0.238266
#    Component 2: Ground Truth = -1.981773, Predicted = -1.616510
#    Component 3: Ground Truth = 5.880725, Predicted = 0.238266
#    Component 4: Ground Truth = 0.454966, Predicted = -1.616510
#    Component 5: Ground Truth = -3.552643, Predicted = 0.238266
#    Component 6: Ground Truth = 0.396681, Predicted = -1.616510
#    Component 7: Ground Truth = -0.552619, Predicted = 0.238266
#    Component 8: Ground Truth = -0.253010, Predicted = -1.616510
#    Component 9: Ground Truth = -0.010180, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[ 0.4411,  0.6877],
#         [-1.9592,  6.1148],
#         [ 0.4380, -3.6855],
#         [ 0.3916, -0.5495],
#         [-0.2493, -0.0108]])
# Sample 186:
#    Component 0: Ground Truth = 0.441122, Predicted = -1.616510
#    Component 1: Ground Truth = 0.687677, Predicted = 0.238266
#    Component 2: Ground Truth = -1.959207, Predicted = -1.616510
#    Component 3: Ground Truth = 6.114841, Predicted = 0.238266
#    Component 4: Ground Truth = 0.437960, Predicted = -1.616510
#    Component 5: Ground Truth = -3.685538, Predicted = 0.238266
#    Component 6: Ground Truth = 0.391627, Predicted = -1.616510
#    Component 7: Ground Truth = -0.549532, Predicted = 0.238266
#    Component 8: Ground Truth = -0.249338, Predicted = -1.616510
#    Component 9: Ground Truth = -0.010800, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[ 0.4471,  0.6839],
#         [-1.9323,  6.3707],
#         [ 0.4184, -3.8309],
#         [ 0.3867, -0.5462],
#         [-0.2457, -0.0114]])
# Sample 187:
#    Component 0: Ground Truth = 0.447059, Predicted = -1.616510
#    Component 1: Ground Truth = 0.683922, Predicted = 0.238266
#    Component 2: Ground Truth = -1.932289, Predicted = -1.616510
#    Component 3: Ground Truth = 6.370658, Predicted = 0.238266
#    Component 4: Ground Truth = 0.418435, Predicted = -1.616510
#    Component 5: Ground Truth = -3.830913, Predicted = 0.238266
#    Component 6: Ground Truth = 0.386703, Predicted = -1.616510
#    Component 7: Ground Truth = -0.546170, Predicted = 0.238266
#    Component 8: Ground Truth = -0.245667, Predicted = -1.616510
#    Component 9: Ground Truth = -0.011396, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[ 0.4529,  0.6800],
#         [-1.9000,  6.6510],
#         [ 0.3958, -3.9904],
#         [ 0.3819, -0.5425],
#         [-0.2421, -0.0119]])
# Sample 188:
#    Component 0: Ground Truth = 0.452948, Predicted = -1.616510
#    Component 1: Ground Truth = 0.679953, Predicted = 0.238266
#    Component 2: Ground Truth = -1.900019, Predicted = -1.616510
#    Component 3: Ground Truth = 6.651044, Predicted = 0.238266
#    Component 4: Ground Truth = 0.395818, Predicted = -1.616510
#    Component 5: Ground Truth = -3.990427, Predicted = 0.238266
#    Component 6: Ground Truth = 0.381929, Predicted = -1.616510
#    Component 7: Ground Truth = -0.542534, Predicted = 0.238266
#    Component 8: Ground Truth = -0.242138, Predicted = -1.616510
#    Component 9: Ground Truth = -0.011945, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[ 0.4588,  0.6758],
#         [-1.8612,  6.9594],
#         [ 0.3694, -4.1660],
#         [ 0.3773, -0.5386],
#         [-0.2387, -0.0125]])
# Sample 189:
#    Component 0: Ground Truth = 0.458765, Predicted = -1.616510
#    Component 1: Ground Truth = 0.675771, Predicted = 0.238266
#    Component 2: Ground Truth = -1.861169, Predicted = -1.616510
#    Component 3: Ground Truth = 6.959367, Predicted = 0.238266
#    Component 4: Ground Truth = 0.369399, Predicted = -1.616510
#    Component 5: Ground Truth = -4.166023, Predicted = 0.238266
#    Component 6: Ground Truth = 0.377310, Predicted = -1.616510
#    Component 7: Ground Truth = -0.538612, Predicted = 0.238266
#    Component 8: Ground Truth = -0.238657, Predicted = -1.616510
#    Component 9: Ground Truth = -0.012469, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[ 0.4645,  0.6714],
#         [-1.8142,  7.2997],
#         [ 0.3383, -4.3600],
#         [ 0.3729, -0.5344],
#         [-0.2352, -0.0130]])
# Sample 190:
#    Component 0: Ground Truth = 0.464488, Predicted = -1.616510
#    Component 1: Ground Truth = 0.671381, Predicted = 0.238266
#    Component 2: Ground Truth = -1.814200, Predicted = -1.616510
#    Component 3: Ground Truth = 7.299651, Predicted = 0.238266
#    Component 4: Ground Truth = 0.338293, Predicted = -1.616510
#    Component 5: Ground Truth = -4.359965, Predicted = 0.238266
#    Component 6: Ground Truth = 0.372863, Predicted = -1.616510
#    Component 7: Ground Truth = -0.534416, Predicted = 0.238266
#    Component 8: Ground Truth = -0.235224, Predicted = -1.616510
#    Component 9: Ground Truth = -0.012994, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[ 0.4701,  0.6668],
#         [-1.7571,  7.6766],
#         [ 0.3014, -4.5750],
#         [ 0.3686, -0.5299],
#         [-0.2319, -0.0135]])
# Sample 191:
#    Component 0: Ground Truth = 0.470132, Predicted = -1.616510
#    Component 1: Ground Truth = 0.666775, Predicted = 0.238266
#    Component 2: Ground Truth = -1.757126, Predicted = -1.616510
#    Component 3: Ground Truth = 7.676565, Predicted = 0.238266
#    Component 4: Ground Truth = 0.301382, Predicted = -1.616510
#    Component 5: Ground Truth = -4.574964, Predicted = 0.238266
#    Component 6: Ground Truth = 0.368591, Predicted = -1.616510
#    Component 7: Ground Truth = -0.529939, Predicted = 0.238266
#    Component 8: Ground Truth = -0.231883, Predicted = -1.616510
#    Component 9: Ground Truth = -0.013471, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[ 0.4757,  0.6620],
#         [-1.6876,  8.0962],
#         [ 0.2573, -4.8145],
#         [ 0.3645, -0.5252],
#         [-0.2286, -0.0139]])
# Sample 192:
#    Component 0: Ground Truth = 0.475699, Predicted = -1.616510
#    Component 1: Ground Truth = 0.661990, Predicted = 0.238266
#    Component 2: Ground Truth = -1.687572, Predicted = -1.616510
#    Component 3: Ground Truth = 8.096239, Predicted = 0.238266
#    Component 4: Ground Truth = 0.257264, Predicted = -1.616510
#    Component 5: Ground Truth = -4.814532, Predicted = 0.238266
#    Component 6: Ground Truth = 0.364529, Predicted = -1.616510
#    Component 7: Ground Truth = -0.525207, Predicted = 0.238266
#    Component 8: Ground Truth = -0.228646, Predicted = -1.616510
#    Component 9: Ground Truth = -0.013924, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[ 0.4812,  0.6570],
#         [-1.6023,  8.5651],
#         [ 0.2041, -5.0823],
#         [ 0.3607, -0.5202],
#         [-0.2254, -0.0144]])
# Sample 193:
#    Component 0: Ground Truth = 0.481153, Predicted = -1.616510
#    Component 1: Ground Truth = 0.656978, Predicted = 0.238266
#    Component 2: Ground Truth = -1.602294, Predicted = -1.616510
#    Component 3: Ground Truth = 8.565077, Predicted = 0.238266
#    Component 4: Ground Truth = 0.204108, Predicted = -1.616510
#    Component 5: Ground Truth = -5.082314, Predicted = 0.238266
#    Component 6: Ground Truth = 0.360650, Predicted = -1.616510
#    Component 7: Ground Truth = -0.520182, Predicted = 0.238266
#    Component 8: Ground Truth = -0.225449, Predicted = -1.616510
#    Component 9: Ground Truth = -0.014377, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[ 0.4865,  0.6518],
#         [-1.4972,  9.0919],
#         [ 0.1396, -5.3833],
#         [ 0.3570, -0.5149],
#         [-0.2223, -0.0148]])
# Sample 194:
#    Component 0: Ground Truth = 0.486488, Predicted = -1.616510
#    Component 1: Ground Truth = 0.651770, Predicted = 0.238266
#    Component 2: Ground Truth = -1.497205, Predicted = -1.616510
#    Component 3: Ground Truth = 9.091873, Predicted = 0.238266
#    Component 4: Ground Truth = 0.139577, Predicted = -1.616510
#    Component 5: Ground Truth = -5.383349, Predicted = 0.238266
#    Component 6: Ground Truth = 0.356986, Predicted = -1.616510
#    Component 7: Ground Truth = -0.514871, Predicted = 0.238266
#    Component 8: Ground Truth = -0.222299, Predicted = -1.616510
#    Component 9: Ground Truth = -0.014782, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[ 0.4917,  0.6464],
#         [-1.3670,  9.6873],
#         [ 0.0606, -5.7238],
#         [ 0.3536, -0.5093],
#         [-0.2192, -0.0152]])
# Sample 195:
#    Component 0: Ground Truth = 0.491715, Predicted = -1.616510
#    Component 1: Ground Truth = 0.646383, Predicted = 0.238266
#    Component 2: Ground Truth = -1.366998, Predicted = -1.616510
#    Component 3: Ground Truth = 9.687338, Predicted = 0.238266
#    Component 4: Ground Truth = 0.060600, Predicted = -1.616510
#    Component 5: Ground Truth = -5.723804, Predicted = 0.238266
#    Component 6: Ground Truth = 0.353551, Predicted = -1.616510
#    Component 7: Ground Truth = -0.509310, Predicted = 0.238266
#    Component 8: Ground Truth = -0.219202, Predicted = -1.616510
#    Component 9: Ground Truth = -0.015187, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[ 0.4968,  0.6408],
#         [-1.2045, 10.3643],
#         [-0.0369, -6.1110],
#         [ 0.3504, -0.5035],
#         [-0.2162, -0.0156]])
# Sample 196:
#    Component 0: Ground Truth = 0.496793, Predicted = -1.616510
#    Component 1: Ground Truth = 0.640801, Predicted = 0.238266
#    Component 2: Ground Truth = -1.204540, Predicted = -1.616510
#    Component 3: Ground Truth = 10.364268, Predicted = 0.238266
#    Component 4: Ground Truth = -0.036903, Predicted = -1.616510
#    Component 5: Ground Truth = -6.110996, Predicted = 0.238266
#    Component 6: Ground Truth = 0.350350, Predicted = -1.616510
#    Component 7: Ground Truth = -0.503469, Predicted = 0.238266
#    Component 8: Ground Truth = -0.216198, Predicted = -1.616510
#    Component 9: Ground Truth = -0.015569, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[ 0.5018,  0.6350],
#         [-1.0002, 11.1392],
#         [-0.1584, -6.5544],
#         [ 0.3474, -0.4973],
#         [-0.2132, -0.0159]])
# Sample 197:
#    Component 0: Ground Truth = 0.501752, Predicted = -1.616510
#    Component 1: Ground Truth = 0.635037, Predicted = 0.238266
#    Component 2: Ground Truth = -1.000215, Predicted = -1.616510
#    Component 3: Ground Truth = 11.139236, Predicted = 0.238266
#    Component 4: Ground Truth = -0.158417, Predicted = -1.616510
#    Component 5: Ground Truth = -6.554407, Predicted = 0.238266
#    Component 6: Ground Truth = 0.347382, Predicted = -1.616510
#    Component 7: Ground Truth = -0.497342, Predicted = 0.238266
#    Component 8: Ground Truth = -0.213242, Predicted = -1.616510
#    Component 9: Ground Truth = -0.015926, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[ 0.5066,  0.6291],
#         [-0.7410, 12.0333],
#         [-0.3114, -7.0661],
#         [ 0.3447, -0.4910],
#         [-0.2103, -0.0163]])
# Sample 198:
#    Component 0: Ground Truth = 0.506568, Predicted = -1.616510
#    Component 1: Ground Truth = 0.629092, Predicted = 0.238266
#    Component 2: Ground Truth = -0.740982, Predicted = -1.616510
#    Component 3: Ground Truth = 12.033259, Predicted = 0.238266
#    Component 4: Ground Truth = -0.311419, Predicted = -1.616510
#    Component 5: Ground Truth = -7.066090, Predicted = 0.238266
#    Component 6: Ground Truth = 0.344664, Predicted = -1.616510
#    Component 7: Ground Truth = -0.490964, Predicted = 0.238266
#    Component 8: Ground Truth = -0.210333, Predicted = -1.616510
#    Component 9: Ground Truth = -0.016284, Predicted = 0.238266
# tensor([[-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383],
#         [-1.6165,  0.2383]])
# tensor([[ 0.5112,  0.6230],
#         [-0.4087, 13.0735],
#         [-0.5063, -7.6616],
#         [ 0.3422, -0.4843],
#         [-0.2075, -0.0166]])
# Sample 199:
#    Component 0: Ground Truth = 0.511241, Predicted = -1.616510
#    Component 1: Ground Truth = 0.622979, Predicted = 0.238266
#    Component 2: Ground Truth = -0.408698, Predicted = -1.616510
#    Component 3: Ground Truth = 13.073469, Predicted = 0.238266
#    Component 4: Ground Truth = -0.506311, Predicted = -1.616510
#    Component 5: Ground Truth = -7.661576, Predicted = 0.238266
#    Component 6: Ground Truth = 0.342197, Predicted = -1.616510
#    Component 7: Ground Truth = -0.484300, Predicted = 0.238266
#    Component 8: Ground Truth = -0.207520, Predicted = -1.616510
#    Component 9: Ground Truth = -0.016594, Predicted = 0.238266
