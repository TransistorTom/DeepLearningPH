# %%
import torch.nn as nn
import torch.optim as optim
import numpy as np
from torch_geometric.loader import DataLoader
import sys
import os
import torch
notebook_dir = os.getcwd()
project_root = os.path.abspath(os.path.join(notebook_dir, ".."))
sys.path.append(project_root)
from gnn_model.graph_structure_from_trajecotry import node_data_list
from gnn_model.message_passing_MLP import GNN_MLP
from gnn_model.train_model import train_model

# %%
import torch
import random

def generate_random_positions(N, dim, min_dist, box_size):
    positions = []
    while len(positions) < N:
        pos = torch.rand(dim) * box_size
        if all(torch.norm(pos - p) >= min_dist for p in positions):
            positions.append(pos)
    return torch.stack(positions)

def generate_random_velocities(N, dim, velocity_scale=1.0):
    return (torch.rand((N, dim)) - 0.5) * 2 * velocity_scale

def compute_gravitational_forces(positions, masses, G=1.0, eps=1e-5):
    N, dim = positions.shape
    forces = torch.zeros_like(positions)
    for i in range(N):
        for j in range(i + 1, N):
            r_vec = positions[j] - positions[i]
            dist = torch.norm(r_vec) + eps
            force_mag = G * masses[i] * masses[j] / dist**2
            force_dir = r_vec / dist
            force = force_mag * force_dir
            forces[i] += force
            forces[j] -= force
    return forces

def n_body_simulation(N=5, T=100, dt=0.01, dim=2,
                      mass_range=(1.0, 10.0), min_dist=0.5,
                      box_size=10.0, velocity_scale=1.0):
    # Initialize
    masses = torch.tensor([random.uniform(*mass_range) for _ in range(N)], dtype=torch.float32)
    positions = generate_random_positions(N, dim, min_dist, box_size)
    velocities = generate_random_velocities(N, dim, velocity_scale)

    # Store results
    trajectory = torch.zeros((T, N, dim), dtype=torch.float32)
    trajectory_velocities = torch.zeros((T, N, dim), dtype=torch.float32)
    t_array  = torch.arange(0, T * dt, dt, dtype=torch.float32)

    for t in range(T):
        trajectory[t] = positions
        trajectory_velocities[t] = velocities

        # Compute forces and update positions & velocities (Euler method)
        forces = compute_gravitational_forces(positions, masses)
        accelerations = forces / masses[:, None]
        velocities = velocities + accelerations * dt
        positions = positions + velocities * dt

    trajectory_data = {
        "time": t_array,
        "positions": trajectory,
        "velocities": trajectory_velocities,
        "masses": masses
    }

    return trajectory_data

# Example usage:
trajectory_data = n_body_simulation(N=3, T=200, dt=0.01, dim=2)
# print(trajectory_data)  # (T, N, dim)

# %%
nodes_data = node_data_list(trajectory_data, self_loop=False, complete_graph=True)
# Out:
# /Users/ruxi/Documents/GitHub/DeepLearningPH/gnn_model/graph_structure_from_trajecotry.py:81: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_target = torch.tensor(acceleration, dtype=torch.float32)

# %%
model = GNN_MLP(n_f=6, m_dim=2, out_channels=2, hidden_channels=128, single_node=True)

# %%
train_model(model, nodes_data, lr=0.005, epochs=50)
# Out:
# GNN_MLP()

# %%
# Output results
print("\nSimulation Results:")
for idx, data in enumerate(nodes_data):
    with torch.no_grad():
        pred_force = model(data.x, data.edge_index)  # Model predicts net force
        print(pred_force)
        # Ground truth force
        ground_truth_force = data.y
        print(ground_truth_force)
        
        # Ensure correct shapes and conversion to NumPy for printing
        pred_force_np = pred_force.cpu().numpy().flatten()  # Convert to NumPy array and flatten
        ground_truth_np = ground_truth_force.cpu().numpy().flatten()  # Convert to NumPy and flatten

        # Print each component of the force vector
        print(f"Sample {idx + 1}:")
        for i in range(len(pred_force_np)):
            print(f"   Component {i}: Ground Truth = {ground_truth_np[i]:.6f}, Predicted = {pred_force_np[i]:.6f}")
# Out:
# Simulation Results:
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 2.5358,  2.6829],
#         [-1.6585,  1.1766],
#         [-1.4329, -3.0288]])
# Sample 1:
#    Component 0: Ground Truth = 2.535820, Predicted = -0.438032
#    Component 1: Ground Truth = 2.682906, Predicted = 0.972715
#    Component 2: Ground Truth = -1.658547, Predicted = -0.438032
#    Component 3: Ground Truth = 1.176596, Predicted = 0.972715
#    Component 4: Ground Truth = -1.432860, Predicted = -0.438032
#    Component 5: Ground Truth = -3.028830, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 2.5607,  2.7408],
#         [-1.6550,  1.1742],
#         [-1.4571, -3.0798]])
# Sample 2:
#    Component 0: Ground Truth = 2.560723, Predicted = -0.438032
#    Component 1: Ground Truth = 2.740794, Predicted = 0.972715
#    Component 2: Ground Truth = -1.655048, Predicted = -0.438032
#    Component 3: Ground Truth = 1.174212, Predicted = 0.972715
#    Component 4: Ground Truth = -1.457138, Predicted = -0.438032
#    Component 5: Ground Truth = -3.079849, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 2.5880,  2.8033],
#         [-1.6520,  1.1722],
#         [-1.4834, -3.1352]])
# Sample 3:
#    Component 0: Ground Truth = 2.588046, Predicted = -0.438032
#    Component 1: Ground Truth = 2.803284, Predicted = 0.972715
#    Component 2: Ground Truth = -1.651990, Predicted = -0.438032
#    Component 3: Ground Truth = 1.172215, Predicted = 0.972715
#    Component 4: Ground Truth = -1.483381, Predicted = -0.438032
#    Component 5: Ground Truth = -3.135224, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 2.6180,  2.8708],
#         [-1.6494,  1.1706],
#         [-1.5117, -3.1953]])
# Sample 4:
#    Component 0: Ground Truth = 2.617955, Predicted = -0.438032
#    Component 1: Ground Truth = 2.870792, Predicted = 0.972715
#    Component 2: Ground Truth = -1.649362, Predicted = -0.438032
#    Component 3: Ground Truth = 1.170599, Predicted = 0.972715
#    Component 4: Ground Truth = -1.511735, Predicted = -0.438032
#    Component 5: Ground Truth = -3.195322, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 2.6506,  2.9438],
#         [-1.6472,  1.1694],
#         [-1.5424, -3.2606]])
# Sample 5:
#    Component 0: Ground Truth = 2.650630, Predicted = -0.438032
#    Component 1: Ground Truth = 2.943778, Predicted = 0.972715
#    Component 2: Ground Truth = -1.647156, Predicted = -0.438032
#    Component 3: Ground Truth = 1.169365, Predicted = 0.972715
#    Component 4: Ground Truth = -1.542367, Predicted = -0.438032
#    Component 5: Ground Truth = -3.260563, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 2.6863,  3.0228],
#         [-1.6454,  1.1685],
#         [-1.5755, -3.3314]])
# Sample 6:
#    Component 0: Ground Truth = 2.686286, Predicted = -0.438032
#    Component 1: Ground Truth = 3.022767, Predicted = 0.972715
#    Component 2: Ground Truth = -1.645369, Predicted = -0.438032
#    Component 3: Ground Truth = 1.168517, Predicted = 0.972715
#    Component 4: Ground Truth = -1.575464, Predicted = -0.438032
#    Component 5: Ground Truth = -3.331420, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 2.7251,  3.1084],
#         [-1.6440,  1.1680],
#         [-1.6112, -3.4084]])
# Sample 7:
#    Component 0: Ground Truth = 2.725124, Predicted = -0.438032
#    Component 1: Ground Truth = 3.108364, Predicted = 0.972715
#    Component 2: Ground Truth = -1.643991, Predicted = -0.438032
#    Component 3: Ground Truth = 1.168045, Predicted = 0.972715
#    Component 4: Ground Truth = -1.611238, Predicted = -0.438032
#    Component 5: Ground Truth = -3.408436, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 2.7674,  3.2013],
#         [-1.6430,  1.1680],
#         [-1.6499, -3.4922]])
# Sample 8:
#    Component 0: Ground Truth = 2.767444, Predicted = -0.438032
#    Component 1: Ground Truth = 3.201253, Predicted = 0.972715
#    Component 2: Ground Truth = -1.643014, Predicted = -0.438032
#    Component 3: Ground Truth = 1.167958, Predicted = 0.972715
#    Component 4: Ground Truth = -1.649934, Predicted = -0.438032
#    Component 5: Ground Truth = -3.492231, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 2.8135,  3.3022],
#         [-1.6424,  1.1683],
#         [-1.6918, -3.5835]])
# Sample 9:
#    Component 0: Ground Truth = 2.813507, Predicted = -0.438032
#    Component 1: Ground Truth = 3.302217, Predicted = 0.972715
#    Component 2: Ground Truth = -1.642430, Predicted = -0.438032
#    Component 3: Ground Truth = 1.168253, Predicted = 0.972715
#    Component 4: Ground Truth = -1.691819, Predicted = -0.438032
#    Component 5: Ground Truth = -3.583515, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 2.8637,  3.4122],
#         [-1.6422,  1.1689],
#         [-1.7372, -3.6831]])
# Sample 10:
#    Component 0: Ground Truth = 2.863680, Predicted = -0.438032
#    Component 1: Ground Truth = 3.412167, Predicted = 0.972715
#    Component 2: Ground Truth = -1.642238, Predicted = -0.438032
#    Component 3: Ground Truth = 1.168931, Predicted = 0.972715
#    Component 4: Ground Truth = -1.737200, Predicted = -0.438032
#    Component 5: Ground Truth = -3.683109, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 2.9184,  3.5322],
#         [-1.6424,  1.1700],
#         [-1.7864, -3.7920]])
# Sample 11:
#    Component 0: Ground Truth = 2.918351, Predicted = -0.438032
#    Component 1: Ground Truth = 3.532166, Predicted = 0.972715
#    Component 2: Ground Truth = -1.642430, Predicted = -0.438032
#    Component 3: Ground Truth = 1.169998, Predicted = 0.972715
#    Component 4: Ground Truth = -1.786444, Predicted = -0.438032
#    Component 5: Ground Truth = -3.791965, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 2.9780,  3.6634],
#         [-1.6430,  1.1715],
#         [-1.8400, -3.9112]])
# Sample 12:
#    Component 0: Ground Truth = 2.977956, Predicted = -0.438032
#    Component 1: Ground Truth = 3.663421, Predicted = 0.972715
#    Component 2: Ground Truth = -1.643002, Predicted = -0.438032
#    Component 3: Ground Truth = 1.171454, Predicted = 0.972715
#    Component 4: Ground Truth = -1.839951, Predicted = -0.438032
#    Component 5: Ground Truth = -3.911183, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 3.0430,  3.8074],
#         [-1.6439,  1.1733],
#         [-1.8982, -4.0421]])
# Sample 13:
#    Component 0: Ground Truth = 3.043020, Predicted = -0.438032
#    Component 1: Ground Truth = 3.807355, Predicted = 0.972715
#    Component 2: Ground Truth = -1.643947, Predicted = -0.438032
#    Component 3: Ground Truth = 1.173301, Predicted = 0.972715
#    Component 4: Ground Truth = -1.898194, Predicted = -0.438032
#    Component 5: Ground Truth = -4.042057, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 3.1142,  3.9657],
#         [-1.6453,  1.1755],
#         [-1.9617, -4.1861]])
# Sample 14:
#    Component 0: Ground Truth = 3.114150, Predicted = -0.438032
#    Component 1: Ground Truth = 3.965662, Predicted = 0.972715
#    Component 2: Ground Truth = -1.645257, Predicted = -0.438032
#    Component 3: Ground Truth = 1.175546, Predicted = 0.972715
#    Component 4: Ground Truth = -1.961716, Predicted = -0.438032
#    Component 5: Ground Truth = -4.186103, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 3.1920,  4.1403],
#         [-1.6469,  1.1782],
#         [-2.0312, -4.3451]])
# Sample 15:
#    Component 0: Ground Truth = 3.192046, Predicted = -0.438032
#    Component 1: Ground Truth = 4.140333, Predicted = 0.972715
#    Component 2: Ground Truth = -1.646929, Predicted = -0.438032
#    Component 3: Ground Truth = 1.178193, Predicted = 0.972715
#    Component 4: Ground Truth = -2.031158, Predicted = -0.438032
#    Component 5: Ground Truth = -4.345129, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 3.2775,  4.3337],
#         [-1.6490,  1.1812],
#         [-2.1072, -4.5212]])
# Sample 16:
#    Component 0: Ground Truth = 3.277503, Predicted = -0.438032
#    Component 1: Ground Truth = 4.333720, Predicted = 0.972715
#    Component 2: Ground Truth = -1.648953, Predicted = -0.438032
#    Component 3: Ground Truth = 1.181244, Predicted = 0.972715
#    Component 4: Ground Truth = -2.107249, Predicted = -0.438032
#    Component 5: Ground Truth = -4.521248, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 3.3715,  4.5487],
#         [-1.6513,  1.1847],
#         [-2.1909, -4.7170]])
# Sample 17:
#    Component 0: Ground Truth = 3.371499, Predicted = -0.438032
#    Component 1: Ground Truth = 4.548666, Predicted = 0.972715
#    Component 2: Ground Truth = -1.651328, Predicted = -0.438032
#    Component 3: Ground Truth = 1.184707, Predicted = 0.972715
#    Component 4: Ground Truth = -2.190872, Predicted = -0.438032
#    Component 5: Ground Truth = -4.717050, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 3.4752,  4.7886],
#         [-1.6540,  1.1886],
#         [-2.2831, -4.9356]])
# Sample 18:
#    Component 0: Ground Truth = 3.475204, Predicted = -0.438032
#    Component 1: Ground Truth = 4.788618, Predicted = 0.972715
#    Component 2: Ground Truth = -1.654048, Predicted = -0.438032
#    Component 3: Ground Truth = 1.188589, Predicted = 0.972715
#    Component 4: Ground Truth = -2.283063, Predicted = -0.438032
#    Component 5: Ground Truth = -4.935633, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 3.5899,  5.0577],
#         [-1.6571,  1.1929],
#         [-2.3850, -5.1808]])
# Sample 19:
#    Component 0: Ground Truth = 3.589926, Predicted = -0.438032
#    Component 1: Ground Truth = 5.057737, Predicted = 0.972715
#    Component 2: Ground Truth = -1.657095, Predicted = -0.438032
#    Component 3: Ground Truth = 1.192892, Predicted = 0.972715
#    Component 4: Ground Truth = -2.385043, Predicted = -0.438032
#    Component 5: Ground Truth = -5.180761, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 3.7173,  5.3612],
#         [-1.6605,  1.1976],
#         [-2.4983, -5.4571]])
# Sample 20:
#    Component 0: Ground Truth = 3.717337, Predicted = -0.438032
#    Component 1: Ground Truth = 5.361185, Predicted = 0.972715
#    Component 2: Ground Truth = -1.660471, Predicted = -0.438032
#    Component 3: Ground Truth = 1.197625, Predicted = 0.972715
#    Component 4: Ground Truth = -2.498303, Predicted = -0.438032
#    Component 5: Ground Truth = -5.457100, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 3.8594,  5.7054],
#         [-1.6642,  1.2028],
#         [-2.6246, -5.7705]])
# Sample 21:
#    Component 0: Ground Truth = 3.859416, Predicted = -0.438032
#    Component 1: Ground Truth = 5.705386, Predicted = 0.972715
#    Component 2: Ground Truth = -1.664166, Predicted = -0.438032
#    Component 3: Ground Truth = 1.202798, Predicted = 0.972715
#    Component 4: Ground Truth = -2.624633, Predicted = -0.438032
#    Component 5: Ground Truth = -5.770451, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 4.0186,  6.0984],
#         [-1.6682,  1.2084],
#         [-2.7662, -6.1281]])
# Sample 22:
#    Component 0: Ground Truth = 4.018567, Predicted = -0.438032
#    Component 1: Ground Truth = 6.098374, Predicted = 0.972715
#    Component 2: Ground Truth = -1.668163, Predicted = -0.438032
#    Component 3: Ground Truth = 1.208411, Predicted = 0.972715
#    Component 4: Ground Truth = -2.766220, Predicted = -0.438032
#    Component 5: Ground Truth = -6.128052, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 4.1978,  6.5504],
#         [-1.6725,  1.2145],
#         [-2.9258, -6.5392]])
# Sample 23:
#    Component 0: Ground Truth = 4.197792, Predicted = -0.438032
#    Component 1: Ground Truth = 6.550449, Predicted = 0.972715
#    Component 2: Ground Truth = -1.672460, Predicted = -0.438032
#    Component 3: Ground Truth = 1.214478, Predicted = 0.972715
#    Component 4: Ground Truth = -2.925774, Predicted = -0.438032
#    Component 5: Ground Truth = -6.539232, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 4.4008,  7.0749],
#         [-1.6770,  1.2210],
#         [-3.1066, -7.0159]])
# Sample 24:
#    Component 0: Ground Truth = 4.400799, Predicted = -0.438032
#    Component 1: Ground Truth = 7.074865, Predicted = 0.972715
#    Component 2: Ground Truth = -1.677032, Predicted = -0.438032
#    Component 3: Ground Truth = 1.221002, Predicted = 0.972715
#    Component 4: Ground Truth = -3.106646, Predicted = -0.438032
#    Component 5: Ground Truth = -7.015922, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 4.6323,  7.6891],
#         [-1.6819,  1.2280],
#         [-3.3131, -7.5739]])
# Sample 25:
#    Component 0: Ground Truth = 4.632304, Predicted = -0.438032
#    Component 1: Ground Truth = 7.689090, Predicted = 0.972715
#    Component 2: Ground Truth = -1.681872, Predicted = -0.438032
#    Component 3: Ground Truth = 1.227993, Predicted = 0.972715
#    Component 4: Ground Truth = -3.313105, Predicted = -0.438032
#    Component 5: Ground Truth = -7.573946, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 4.8983,  8.4165],
#         [-1.6870,  1.2355],
#         [-3.5506, -8.2343]])
# Sample 26:
#    Component 0: Ground Truth = 4.898314, Predicted = -0.438032
#    Component 1: Ground Truth = 8.416493, Predicted = 0.972715
#    Component 2: Ground Truth = -1.686965, Predicted = -0.438032
#    Component 3: Ground Truth = 1.235459, Predicted = 0.972715
#    Component 4: Ground Truth = -3.550575, Predicted = -0.438032
#    Component 5: Ground Truth = -8.234342, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 5.2066,  9.2890],
#         [-1.6923,  1.2434],
#         [-3.8261, -9.0259]])
# Sample 27:
#    Component 0: Ground Truth = 5.206602, Predicted = -0.438032
#    Component 1: Ground Truth = 9.288963, Predicted = 0.972715
#    Component 2: Ground Truth = -1.692279, Predicted = -0.438032
#    Component 3: Ground Truth = 1.243401, Predicted = 0.972715
#    Component 4: Ground Truth = -3.826091, Predicted = -0.438032
#    Component 5: Ground Truth = -9.025940, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 5.5674, 10.3512],
#         [-1.6978,  1.2518],
#         [-4.1489, -9.9890]])
# Sample 28:
#    Component 0: Ground Truth = 5.567396, Predicted = -0.438032
#    Component 1: Ground Truth = 10.351172, Predicted = 0.972715
#    Component 2: Ground Truth = -1.697789, Predicted = -0.438032
#    Component 3: Ground Truth = 1.251824, Predicted = 0.972715
#    Component 4: Ground Truth = -4.148904, Predicted = -0.438032
#    Component 5: Ground Truth = -9.989038, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[  5.9945,  11.6676],
#         [ -1.7035,   1.2607],
#         [ -4.5314, -11.1818]])
# Sample 29:
#    Component 0: Ground Truth = 5.994469, Predicted = -0.438032
#    Component 1: Ground Truth = 11.667597, Predicted = 0.972715
#    Component 2: Ground Truth = -1.703480, Predicted = -0.438032
#    Component 3: Ground Truth = 1.260740, Predicted = 0.972715
#    Component 4: Ground Truth = -4.531447, Predicted = -0.438032
#    Component 5: Ground Truth = -11.181842, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[  6.5065,  13.3340],
#         [ -1.7093,   1.2701],
#         [ -4.9906, -12.6908]])
# Sample 30:
#    Component 0: Ground Truth = 6.506497, Predicted = -0.438032
#    Component 1: Ground Truth = 13.334048, Predicted = 0.972715
#    Component 2: Ground Truth = -1.709297, Predicted = -0.438032
#    Component 3: Ground Truth = 1.270139, Predicted = 0.972715
#    Component 4: Ground Truth = -4.990588, Predicted = -0.438032
#    Component 5: Ground Truth = -12.690843, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[  7.1294,  15.4993],
#         [ -1.7152,   1.2800],
#         [ -5.5498, -14.6503]])
# Sample 31:
#    Component 0: Ground Truth = 7.129369, Predicted = -0.438032
#    Component 1: Ground Truth = 15.499346, Predicted = 0.972715
#    Component 2: Ground Truth = -1.715198, Predicted = -0.438032
#    Component 3: Ground Truth = 1.280017, Predicted = 0.972715
#    Component 4: Ground Truth = -5.549765, Predicted = -0.438032
#    Component 5: Ground Truth = -14.650327, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[  7.8997,  18.4062],
#         [ -1.7211,   1.2904],
#         [ -6.2420, -17.2794]])
# Sample 32:
#    Component 0: Ground Truth = 7.899745, Predicted = -0.438032
#    Component 1: Ground Truth = 18.406242, Predicted = 0.972715
#    Component 2: Ground Truth = -1.721138, Predicted = -0.438032
#    Component 3: Ground Truth = 1.290374, Predicted = 0.972715
#    Component 4: Ground Truth = -6.242037, Predicted = -0.438032
#    Component 5: Ground Truth = -17.279438, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[  8.8692,  22.4758],
#         [ -1.7270,   1.3012],
#         [ -7.1140, -20.9582]])
# Sample 33:
#    Component 0: Ground Truth = 8.869180, Predicted = -0.438032
#    Component 1: Ground Truth = 22.475836, Predicted = 0.972715
#    Component 2: Ground Truth = -1.727031, Predicted = -0.438032
#    Component 3: Ground Truth = 1.301181, Predicted = 0.972715
#    Component 4: Ground Truth = -7.114012, Predicted = -0.438032
#    Component 5: Ground Truth = -20.958204, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 10.1082,  28.5011],
#         [ -1.7328,   1.3124],
#         [ -8.2294, -26.4024]])
# Sample 34:
#    Component 0: Ground Truth = 10.108189, Predicted = -0.438032
#    Component 1: Ground Truth = 28.501072, Predicted = 0.972715
#    Component 2: Ground Truth = -1.732788, Predicted = -0.438032
#    Component 3: Ground Truth = 1.312404, Predicted = 0.972715
#    Component 4: Ground Truth = -8.229359, Predicted = -0.438032
#    Component 5: Ground Truth = -26.402395, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 11.6943,  38.1489],
#         [ -1.7383,   1.3240],
#         [ -9.6581, -35.1165]])
# Sample 35:
#    Component 0: Ground Truth = 11.694300, Predicted = -0.438032
#    Component 1: Ground Truth = 38.148941, Predicted = 0.972715
#    Component 2: Ground Truth = -1.738294, Predicted = -0.438032
#    Component 3: Ground Truth = 1.323995, Predicted = 0.972715
#    Component 4: Ground Truth = -9.658143, Predicted = -0.438032
#    Component 5: Ground Truth = -35.116539, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 13.5863,  55.5212],
#         [ -1.7434,   1.3358],
#         [-11.3633, -50.8028]])
# Sample 36:
#    Component 0: Ground Truth = 13.586320, Predicted = -0.438032
#    Component 1: Ground Truth = 55.521160, Predicted = 0.972715
#    Component 2: Ground Truth = -1.743361, Predicted = -0.438032
#    Component 3: Ground Truth = 1.335841, Predicted = 0.972715
#    Component 4: Ground Truth = -11.363267, Predicted = -0.438032
#    Component 5: Ground Truth = -50.802826, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[ 14.5699,  93.5575],
#         [ -1.7477,   1.3478],
#         [-12.2488, -85.1406]])
# Sample 37:
#    Component 0: Ground Truth = 14.569897, Predicted = -0.438032
#    Component 1: Ground Truth = 93.557503, Predicted = 0.972715
#    Component 2: Ground Truth = -1.747723, Predicted = -0.438032
#    Component 3: Ground Truth = 1.347752, Predicted = 0.972715
#    Component 4: Ground Truth = -12.248801, Predicted = -0.438032
#    Component 5: Ground Truth = -85.140556, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[  -1.6216,  216.7079],
#         [  -1.7509,    1.3593],
#         [   2.3673, -196.3020]])
# Sample 38:
#    Component 0: Ground Truth = -1.621582, Predicted = -0.438032
#    Component 1: Ground Truth = 216.707870, Predicted = 0.972715
#    Component 2: Ground Truth = -1.750941, Predicted = -0.438032
#    Component 3: Ground Truth = 1.359312, Predicted = 0.972715
#    Component 4: Ground Truth = 2.367308, Predicted = -0.438032
#    Component 5: Ground Truth = -196.302032, Predicted = 0.972715
# tensor([[-0.4380,  0.9727],
#         [-0.4380,  0.9727],
#         [-0.4380,  0.9727]])
# tensor([[-1028.9575,  1199.9736],
#         [   -1.7521,     1.3691],
#         [  929.6413, -1083.8027]])
# Sample 39:
#    Component 0: Ground Truth = -1028.957520, Predicted = -0.438032
#    Component 1: Ground Truth = 1199.973633, Predicted = 0.972715
#    Component 2: Ground Truth = -1.752145, Predicted = -0.438032
#    Component 3: Ground Truth = 1.369124, Predicted = 0.972715
#    Component 4: Ground Truth = 929.641296, Predicted = -0.438032
#    Component 5: Ground Truth = -1083.802734, Predicted = 0.972715
# tensor([[ 0.3419, -0.7498],
#         [-0.2285,  0.5100],
#         [-0.4380,  0.9727]])
# tensor([[ 23.2870, -65.5661],
#         [ -1.7752,   1.3750],
#         [-20.1027,  58.4702]])
# Sample 40:
#    Component 0: Ground Truth = 23.287010, Predicted = 0.341940
#    Component 1: Ground Truth = -65.566124, Predicted = -0.749771
#    Component 2: Ground Truth = -1.775240, Predicted = -0.228524
#    Component 3: Ground Truth = 1.374963, Predicted = 0.510038
#    Component 4: Ground Truth = -20.102652, Predicted = -0.438032
#    Component 5: Ground Truth = 58.470226, Predicted = 0.972715
# tensor([[ 0.2840, -0.6219],
#         [-0.2388,  0.5328],
#         [-0.4380,  0.9727]])
# tensor([[  5.7656, -14.1670],
#         [ -1.8585,   1.3858],
#         [ -4.2449,  12.0720]])
# Sample 41:
#    Component 0: Ground Truth = 5.765635, Predicted = 0.284017
#    Component 1: Ground Truth = -14.167036, Predicted = -0.621855
#    Component 2: Ground Truth = -1.858466, Predicted = -0.238850
#    Component 3: Ground Truth = 1.385809, Predicted = 0.532842
#    Component 4: Ground Truth = -4.244904, Predicted = -0.438032
#    Component 5: Ground Truth = 12.072002, Predicted = 0.972715
# tensor([[ 0.2578, -0.5640],
#         [-0.2419,  0.5396],
#         [-0.4380,  0.9727]])
# tensor([[ 2.6721, -6.1621],
#         [-2.0042,  1.3983],
#         [-1.3775,  4.8403]])
# Sample 42:
#    Component 0: Ground Truth = 2.672142, Predicted = 0.257808
#    Component 1: Ground Truth = -6.162059, Predicted = -0.563976
#    Component 2: Ground Truth = -2.004224, Predicted = -0.241897
#    Component 3: Ground Truth = 1.398297, Predicted = 0.539572
#    Component 4: Ground Truth = -1.377532, Predicted = -0.438032
#    Component 5: Ground Truth = 4.840269, Predicted = 0.972715
# tensor([[ 0.2376, -0.5193],
#         [-0.2435,  0.5432],
#         [-0.4380,  0.9727]])
# tensor([[ 1.5878, -3.4979],
#         [-2.2191,  1.4054],
#         [-0.2879,  2.4319]])
# Sample 43:
#    Component 0: Ground Truth = 1.587774, Predicted = 0.237582
#    Component 1: Ground Truth = -3.497890, Predicted = -0.519307
#    Component 2: Ground Truth = -2.219084, Predicted = -0.243526
#    Component 3: Ground Truth = 1.405404, Predicted = 0.543171
#    Component 4: Ground Truth = -0.287867, Predicted = -0.438032
#    Component 5: Ground Truth = 2.431872, Predicted = 0.972715
# tensor([[ 0.2247, -0.4908],
#         [-0.2447,  0.5458],
#         [-0.4380,  0.9727]])
# tensor([[ 1.0758, -2.2869],
#         [-2.5118,  1.3947],
#         [ 0.3253,  1.3445]])
# Sample 44:
#    Component 0: Ground Truth = 1.075841, Predicted = 0.224664
#    Component 1: Ground Truth = -2.286913, Predicted = -0.490779
#    Component 2: Ground Truth = -2.511783, Predicted = -0.244697
#    Component 3: Ground Truth = 1.394653, Predicted = 0.545755
#    Component 4: Ground Truth = 0.325299, Predicted = -0.438032
#    Component 5: Ground Truth = 1.344491, Predicted = 0.972715
# tensor([[ 0.2161, -0.4719],
#         [-0.2454,  0.5474],
#         [-0.4380,  0.9727]])
# tensor([[ 0.7894, -1.6317],
#         [-2.8909,  1.3456],
#         [ 0.7795,  0.7784]])
# Sample 45:
#    Component 0: Ground Truth = 0.789450, Predicted = 0.216097
#    Component 1: Ground Truth = -1.631733, Predicted = -0.471861
#    Component 2: Ground Truth = -2.890922, Predicted = -0.245444
#    Component 3: Ground Truth = 1.345639, Predicted = 0.547405
#    Component 4: Ground Truth = 0.779484, Predicted = -0.438032
#    Component 5: Ground Truth = 0.778387, Predicted = 0.972715
# tensor([[ 0.2079, -0.4538],
#         [-0.2459,  0.5485],
#         [-0.4380,  0.9727]])
# tensor([[ 0.6106, -1.2350],
#         [-3.3599,  1.2272],
#         [ 1.1829,  0.4812]])
# Sample 46:
#    Component 0: Ground Truth = 0.610638, Predicted = 0.207929
#    Component 1: Ground Truth = -1.235009, Predicted = -0.453822
#    Component 2: Ground Truth = -3.359947, Predicted = -0.245924
#    Component 3: Ground Truth = 1.227171, Predicted = 0.548465
#    Component 4: Ground Truth = 1.182891, Predicted = -0.438032
#    Component 5: Ground Truth = 0.481225, Predicted = 0.972715
# tensor([[ 0.2001, -0.4365],
#         [-0.2461,  0.5488],
#         [-0.4380,  0.9727]])
# tensor([[ 0.4902, -0.9748],
#         [-3.9075,  0.9959],
#         [ 1.5742,  0.3658]])
# Sample 47:
#    Component 0: Ground Truth = 0.490237, Predicted = 0.200069
#    Component 1: Ground Truth = -0.974847, Predicted = -0.436465
#    Component 2: Ground Truth = -3.907479, Predicted = -0.246057
#    Component 3: Ground Truth = 0.995884, Predicted = 0.548759
#    Component 4: Ground Truth = 1.574184, Predicted = -0.438032
#    Component 5: Ground Truth = 0.365830, Predicted = 0.972715
# tensor([[ 0.1925, -0.4197],
#         [-0.2458,  0.5481],
#         [-0.4380,  0.9727]])
# tensor([[ 0.4045, -0.7940],
#         [-4.4924,  0.6010],
#         [ 1.9535,  0.4065]])
# Sample 48:
#    Component 0: Ground Truth = 0.404454, Predicted = 0.192487
#    Component 1: Ground Truth = -0.794030, Predicted = -0.419721
#    Component 2: Ground Truth = -4.492427, Predicted = -0.245775
#    Component 3: Ground Truth = 0.601048, Predicted = 0.548137
#    Component 4: Ground Truth = 1.953508, Predicted = -0.438032
#    Component 5: Ground Truth = 0.406456, Predicted = 0.972715
# tensor([[ 0.1852, -0.4036],
#         [-0.2451,  0.5467],
#         [-0.4380,  0.9727]])
# tensor([[ 3.4070e-01, -6.6242e-01],
#         [-5.0282e+00,  2.8372e-03],
#         [ 2.2875e+00,  5.9643e-01]])
# Sample 49:
#    Component 0: Ground Truth = 0.340700, Predicted = 0.185169
#    Component 1: Ground Truth = -0.662423, Predicted = -0.403560
#    Component 2: Ground Truth = -5.028220, Predicted = -0.245103
#    Component 3: Ground Truth = 0.002837, Predicted = 0.546651
#    Component 4: Ground Truth = 2.287533, Predicted = -0.438032
#    Component 5: Ground Truth = 0.596429, Predicted = 0.972715
# tensor([[ 0.1781, -0.3879],
#         [-0.2441,  0.5445],
#         [-0.4380,  0.9727]])
# tensor([[ 0.2918, -0.5634],
#         [-5.3826, -0.7919],
#         [ 2.5146,  0.9172]])
# Sample 50:
#    Component 0: Ground Truth = 0.291776, Predicted = 0.178090
#    Component 1: Ground Truth = -0.563430, Predicted = -0.387926
#    Component 2: Ground Truth = -5.382596, Predicted = -0.244134
#    Component 3: Ground Truth = -0.791906, Predicted = 0.544511
#    Component 4: Ground Truth = 2.514596, Predicted = -0.438032
#    Component 5: Ground Truth = 0.917242, Predicted = 0.972715
# tensor([[ 0.1712, -0.3727],
#         [-0.2431,  0.5421],
#         [-0.4380,  0.9727]])
# tensor([[ 0.2532, -0.4868],
#         [-5.4169, -1.6927],
#         [ 2.5671,  1.3128]])
# Sample 51:
#    Component 0: Ground Truth = 0.253248, Predicted = 0.171205
#    Component 1: Ground Truth = -0.486756, Predicted = -0.372720
#    Component 2: Ground Truth = -5.416902, Predicted = -0.243061
#    Component 3: Ground Truth = -1.692672, Predicted = 0.542143
#    Component 4: Ground Truth = 2.567103, Predicted = -0.438032
#    Component 5: Ground Truth = 1.312829, Predicted = 0.972715
# tensor([[ 0.1644, -0.3577],
#         [-0.2422,  0.5401],
#         [-0.4380,  0.9727]])
# tensor([[ 0.2222, -0.4257],
#         [-5.0638, -2.5305],
#         [ 2.4129,  1.6903]])
# Sample 52:
#    Component 0: Ground Truth = 0.222159, Predicted = 0.164403
#    Component 1: Ground Truth = -0.425721, Predicted = -0.357699
#    Component 2: Ground Truth = -5.063813, Predicted = -0.242156
#    Component 3: Ground Truth = -2.530535, Predicted = 0.540143
#    Component 4: Ground Truth = 2.412894, Predicted = -0.438032
#    Component 5: Ground Truth = 1.690294, Predicted = 0.972715
# tensor([[ 0.1576, -0.3426],
#         [-0.2403,  0.5360],
#         [-0.4380,  0.9727]])
# tensor([[ 0.1967, -0.3763],
#         [-4.3852, -3.1325],
#         [ 2.0856,  1.9564]])
# Sample 53:
#    Component 0: Ground Truth = 0.196743, Predicted = 0.157572
#    Component 1: Ground Truth = -0.376320, Predicted = -0.342615
#    Component 2: Ground Truth = -4.385211, Predicted = -0.240284
#    Component 3: Ground Truth = -3.132513, Predicted = 0.536009
#    Component 4: Ground Truth = 2.085640, Predicted = -0.438032
#    Component 5: Ground Truth = 1.956369, Predicted = 0.972715
# tensor([[ 0.1506, -0.3272],
#         [-0.2341,  0.5223],
#         [-0.4380,  0.9727]])
# tensor([[ 0.1756, -0.3357],
#         [-3.5431, -3.4135],
#         [ 1.6701,  2.0647]])
# Sample 54:
#    Component 0: Ground Truth = 0.175572, Predicted = 0.150614
#    Component 1: Ground Truth = -0.335694, Predicted = -0.327247
#    Component 2: Ground Truth = -3.543130, Predicted = -0.234087
#    Component 3: Ground Truth = -3.413490, Predicted = 0.522325
#    Component 4: Ground Truth = 1.670124, Predicted = -0.438032
#    Component 5: Ground Truth = 2.064707, Predicted = 0.972715
# tensor([[ 0.1435, -0.3115],
#         [-0.2287,  0.5104],
#         [-0.4380,  0.9727]])
# tensor([[ 0.1577, -0.3017],
#         [-2.7074, -3.4016],
#         [ 1.2549,  2.0279]])
# Sample 55:
#    Component 0: Ground Truth = 0.157737, Predicted = 0.143466
#    Component 1: Ground Truth = -0.301741, Predicted = -0.311463
#    Component 2: Ground Truth = -2.707390, Predicted = -0.228683
#    Component 3: Ground Truth = -3.401563, Predicted = 0.510389
#    Component 4: Ground Truth = 1.254934, Predicted = -0.438032
#    Component 5: Ground Truth = 2.027883, Predicted = 0.972715
# tensor([[ 0.1361, -0.2952],
#         [-0.2239,  0.4999],
#         [-0.4380,  0.9727]])
# tensor([[ 0.1425, -0.2731],
#         [-1.9861, -3.1901],
#         [ 0.8964,  1.8930]])
# Sample 56:
#    Component 0: Ground Truth = 0.142527, Predicted = 0.136118
#    Component 1: Ground Truth = -0.273133, Predicted = -0.295234
#    Component 2: Ground Truth = -1.986124, Predicted = -0.223949
#    Component 3: Ground Truth = -3.190132, Predicted = 0.499935
#    Component 4: Ground Truth = 0.896359, Predicted = -0.438032
#    Component 5: Ground Truth = 1.893045, Predicted = 0.972715
# tensor([[ 0.1286, -0.2786],
#         [-0.2197,  0.4906],
#         [-0.4380,  0.9727]])
# tensor([[ 0.1295, -0.2485],
#         [-1.4167, -2.8774],
#         [ 0.6143,  1.7094]])
# Sample 57:
#    Component 0: Ground Truth = 0.129461, Predicted = 0.128588
#    Component 1: Ground Truth = -0.248528, Predicted = -0.278605
#    Component 2: Ground Truth = -1.416661, Predicted = -0.219732
#    Component 3: Ground Truth = -2.877409, Predicted = 0.490623
#    Component 4: Ground Truth = 0.614262, Predicted = -0.438032
#    Component 5: Ground Truth = 1.709368, Predicted = 0.972715
# tensor([[ 0.1209, -0.2617],
#         [-0.2159,  0.4821],
#         [-0.4380,  0.9727]])
# tensor([[ 0.1182, -0.2274],
#         [-0.9911, -2.5353],
#         [ 0.4049,  1.5138]])
# Sample 58:
#    Component 0: Ground Truth = 0.118160, Predicted = 0.120910
#    Component 1: Ground Truth = -0.227356, Predicted = -0.261650
#    Component 2: Ground Truth = -0.991125, Predicted = -0.215894
#    Component 3: Ground Truth = -2.535331, Predicted = 0.482146
#    Component 4: Ground Truth = 0.404883, Predicted = -0.438032
#    Component 5: Ground Truth = 1.513769, Predicted = 0.972715
# tensor([[ 0.1131, -0.2444],
#         [-0.2123,  0.4742],
#         [-0.4380,  0.9727]])
# tensor([[ 0.1083, -0.2090],
#         [-0.6832, -2.2057],
#         [ 0.2549,  1.3269]])
# Sample 59:
#    Component 0: Ground Truth = 0.108290, Predicted = 0.113121
#    Component 1: Ground Truth = -0.209046, Predicted = -0.244449
#    Component 2: Ground Truth = -0.683201, Predicted = -0.212314
#    Component 3: Ground Truth = -2.205673, Predicted = 0.474242
#    Component 4: Ground Truth = 0.254870, Predicted = -0.438032
#    Component 5: Ground Truth = 1.326944, Predicted = 0.972715
# tensor([[ 0.1052, -0.2271],
#         [-0.2089,  0.4667],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0996, -0.1928],
#         [-0.4642, -1.9079],
#         [ 0.1497,  1.1587]])
# Sample 60:
#    Component 0: Ground Truth = 0.099611, Predicted = 0.105249
#    Component 1: Ground Truth = -0.192832, Predicted = -0.227064
#    Component 2: Ground Truth = -0.464222, Predicted = -0.208905
#    Component 3: Ground Truth = -1.907933, Predicted = 0.466712
#    Component 4: Ground Truth = 0.149678, Predicted = -0.438032
#    Component 5: Ground Truth = 1.158708, Predicted = 0.972715
# tensor([[ 0.0973, -0.2095],
#         [-0.2056,  0.4594],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0919, -0.1785],
#         [-0.3098, -1.6483],
#         [ 0.0769,  1.0118]])
# Sample 61:
#    Component 0: Ground Truth = 0.091934, Predicted = 0.097318
#    Component 1: Ground Truth = -0.178528, Predicted = -0.209549
#    Component 2: Ground Truth = -0.309795, Predicted = -0.205602
#    Component 3: Ground Truth = -1.648330, Predicted = 0.459419
#    Component 4: Ground Truth = 0.076914, Predicted = -0.438032
#    Component 5: Ground Truth = 1.011849, Predicted = 0.972715
# tensor([[ 0.0893, -0.1919],
#         [-0.2026,  0.4527],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0851, -0.1659],
#         [-0.2012, -1.4262],
#         [ 0.0270,  0.8858]])
# Sample 62:
#    Component 0: Ground Truth = 0.085068, Predicted = 0.089346
#    Component 1: Ground Truth = -0.165939, Predicted = -0.191943
#    Component 2: Ground Truth = -0.201214, Predicted = -0.202580
#    Component 3: Ground Truth = -1.426166, Predicted = 0.452743
#    Component 4: Ground Truth = 0.027037, Predicted = -0.438032
#    Component 5: Ground Truth = 0.885774, Predicted = 0.972715
# tensor([[ 0.0813, -0.1743],
#         [-0.1997,  0.4464],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0790, -0.1545],
#         [-0.1249, -1.2378],
#         [-0.0069,  0.7784]])
# Sample 63:
#    Component 0: Ground Truth = 0.079012, Predicted = 0.081344
#    Component 1: Ground Truth = -0.154495, Predicted = -0.174273
#    Component 2: Ground Truth = -0.124902, Predicted = -0.199712
#    Component 3: Ground Truth = -1.237810, Predicted = 0.446410
#    Component 4: Ground Truth = -0.006866, Predicted = -0.438032
#    Component 5: Ground Truth = 0.778390, Predicted = 0.972715
# tensor([[ 0.0733, -0.1566],
#         [-0.1970,  0.4403],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0735, -0.1444],
#         [-0.0712, -1.0787],
#         [-0.0296,  0.6870]])
# Sample 64:
#    Component 0: Ground Truth = 0.073528, Predicted = 0.073323
#    Component 1: Ground Truth = -0.144386, Predicted = -0.156558
#    Component 2: Ground Truth = -0.071245, Predicted = -0.196951
#    Component 3: Ground Truth = -1.078681, Predicted = 0.440314
#    Component 4: Ground Truth = -0.029612, Predicted = -0.438032
#    Component 5: Ground Truth = 0.687028, Predicted = 0.972715
# tensor([[ 0.0653, -0.1388],
#         [-0.1941,  0.4341],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0686, -0.1352],
#         [-0.0335, -0.9443],
#         [-0.0446,  0.6095]])
# Sample 65:
#    Component 0: Ground Truth = 0.068617, Predicted = 0.065288
#    Component 1: Ground Truth = -0.135231, Predicted = -0.138814
#    Component 2: Ground Truth = -0.033534, Predicted = -0.194131
#    Component 3: Ground Truth = -0.944254, Predicted = 0.434085
#    Component 4: Ground Truth = -0.044632, Predicted = -0.438032
#    Component 5: Ground Truth = 0.609494, Predicted = 0.972715
# tensor([[ 0.0572, -0.1210],
#         [-0.1912,  0.4276],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0642, -0.1270],
#         [-0.0071, -0.8305],
#         [-0.0543,  0.5432]])
# Sample 66:
#    Component 0: Ground Truth = 0.064182, Predicted = 0.057244
#    Component 1: Ground Truth = -0.127030, Predicted = -0.121049
#    Component 2: Ground Truth = -0.007069, Predicted = -0.191202
#    Component 3: Ground Truth = -0.830460, Predicted = 0.427616
#    Component 4: Ground Truth = -0.054312, Predicted = -0.438032
#    Component 5: Ground Truth = 0.543213, Predicted = 0.972715
# tensor([[ 0.0492, -0.1033],
#         [-0.1883,  0.4212],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0602, -0.1196],
#         [ 0.0114, -0.7338],
#         [-0.0602,  0.4866]])
# Sample 67:
#    Component 0: Ground Truth = 0.060177, Predicted = 0.049194
#    Component 1: Ground Truth = -0.119591, Predicted = -0.103271
#    Component 2: Ground Truth = 0.011414, Predicted = -0.188275
#    Component 3: Ground Truth = -0.733810, Predicted = 0.421154
#    Component 4: Ground Truth = -0.060225, Predicted = -0.438032
#    Component 5: Ground Truth = 0.486565, Predicted = 0.972715
# tensor([[ 0.0411, -0.0855],
#         [-0.1853,  0.4147],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0565, -0.1127],
#         [ 0.0242, -0.6514],
#         [-0.0635,  0.4379]])
# Sample 68:
#    Component 0: Ground Truth = 0.056505, Predicted = 0.041140
#    Component 1: Ground Truth = -0.112724, Predicted = -0.085486
#    Component 2: Ground Truth = 0.024211, Predicted = -0.185348
#    Component 3: Ground Truth = -0.651382, Predicted = 0.414689
#    Component 4: Ground Truth = -0.063514, Predicted = -0.438032
#    Component 5: Ground Truth = 0.437925, Predicted = 0.972715
# tensor([[ 0.0344, -0.0707],
#         [-0.1824,  0.4082],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0532, -0.1064],
#         [ 0.0329, -0.5808],
#         [-0.0650,  0.3958]])
# Sample 69:
#    Component 0: Ground Truth = 0.053167, Predicted = 0.034433
#    Component 1: Ground Truth = -0.106430, Predicted = -0.070674
#    Component 2: Ground Truth = 0.032926, Predicted = -0.182417
#    Component 3: Ground Truth = -0.580782, Predicted = 0.408217
#    Component 4: Ground Truth = -0.064993, Predicted = -0.438032
#    Component 5: Ground Truth = 0.395775, Predicted = 0.972715
# tensor([[ 0.0337, -0.0690],
#         [-0.1795,  0.4017],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0501, -0.1007],
#         [ 0.0387, -0.5200],
#         [-0.0652,  0.3592]])
# Sample 70:
#    Component 0: Ground Truth = 0.050116, Predicted = 0.033678
#    Component 1: Ground Truth = -0.100708, Predicted = -0.069007
#    Component 2: Ground Truth = 0.038719, Predicted = -0.179481
#    Component 3: Ground Truth = -0.520020, Predicted = 0.401733
#    Component 4: Ground Truth = -0.065231, Predicted = -0.438032
#    Component 5: Ground Truth = 0.359249, Predicted = 0.972715
# tensor([[ 0.0329, -0.0673],
#         [-0.1765,  0.3952],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0473, -0.0954],
#         [ 0.0424, -0.4675],
#         [-0.0646,  0.3274]])
# Sample 71:
#    Component 0: Ground Truth = 0.047350, Predicted = 0.032911
#    Component 1: Ground Truth = -0.095368, Predicted = -0.067313
#    Component 2: Ground Truth = 0.042403, Predicted = -0.176544
#    Component 3: Ground Truth = -0.467486, Predicted = 0.395247
#    Component 4: Ground Truth = -0.064611, Predicted = -0.438032
#    Component 5: Ground Truth = 0.327397, Predicted = 0.972715
# tensor([[ 0.0321, -0.0656],
#         [-0.1737,  0.3889],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0448, -0.0906],
#         [ 0.0446, -0.4219],
#         [-0.0634,  0.2995]])
# Sample 72:
#    Component 0: Ground Truth = 0.044775, Predicted = 0.032144
#    Component 1: Ground Truth = -0.090599, Predicted = -0.065619
#    Component 2: Ground Truth = 0.044560, Predicted = -0.173664
#    Component 3: Ground Truth = -0.421856, Predicted = 0.388886
#    Component 4: Ground Truth = -0.063419, Predicted = -0.438032
#    Component 5: Ground Truth = 0.299452, Predicted = 0.972715
# tensor([[ 0.0314, -0.0640],
#         [-0.1708,  0.3825],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0424, -0.0860],
#         [ 0.0456, -0.3821],
#         [-0.0618,  0.2748]])
# Sample 73:
#    Component 0: Ground Truth = 0.042391, Predicted = 0.031400
#    Component 1: Ground Truth = -0.086022, Predicted = -0.063976
#    Component 2: Ground Truth = 0.045627, Predicted = -0.170779
#    Component 3: Ground Truth = -0.382051, Predicted = 0.382515
#    Component 4: Ground Truth = -0.061798, Predicted = -0.438032
#    Component 5: Ground Truth = 0.274849, Predicted = 0.972715
# tensor([[ 0.0307, -0.0624],
#         [-0.1679,  0.3761],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0402, -0.0820],
#         [ 0.0459, -0.3472],
#         [-0.0600,  0.2531]])
# Sample 74:
#    Component 0: Ground Truth = 0.040197, Predicted = 0.030666
#    Component 1: Ground Truth = -0.082016, Predicted = -0.062355
#    Component 2: Ground Truth = 0.045902, Predicted = -0.167889
#    Component 3: Ground Truth = -0.347173, Predicted = 0.376133
#    Component 4: Ground Truth = -0.059986, Predicted = -0.438032
#    Component 5: Ground Truth = 0.253105, Predicted = 0.972715
# tensor([[ 0.0299, -0.0607],
#         [-0.1650,  0.3697],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0382, -0.0780],
#         [ 0.0456, -0.3165],
#         [-0.0580,  0.2338]])
# Sample 75:
#    Component 0: Ground Truth = 0.038195, Predicted = 0.029933
#    Component 1: Ground Truth = -0.078011, Predicted = -0.060737
#    Component 2: Ground Truth = 0.045615, Predicted = -0.164995
#    Component 3: Ground Truth = -0.316486, Predicted = 0.369741
#    Component 4: Ground Truth = -0.058031, Predicted = -0.438032
#    Component 5: Ground Truth = 0.233841, Predicted = 0.972715
# tensor([[ 0.0292, -0.0591],
#         [-0.1621,  0.3633],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0363, -0.0746],
#         [ 0.0449, -0.2894],
#         [-0.0560,  0.2166]])
# Sample 76:
#    Component 0: Ground Truth = 0.036287, Predicted = 0.029202
#    Component 1: Ground Truth = -0.074577, Predicted = -0.059122
#    Component 2: Ground Truth = 0.044936, Predicted = -0.162095
#    Component 3: Ground Truth = -0.289379, Predicted = 0.363338
#    Component 4: Ground Truth = -0.055980, Predicted = -0.438032
#    Component 5: Ground Truth = 0.216578, Predicted = 0.972715
# tensor([[ 0.0285, -0.0575],
#         [-0.1592,  0.3569],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0346, -0.0711],
#         [ 0.0440, -0.2653],
#         [-0.0539,  0.2011]])
# Sample 77:
#    Component 0: Ground Truth = 0.034571, Predicted = 0.028472
#    Component 1: Ground Truth = -0.071144, Predicted = -0.057510
#    Component 2: Ground Truth = 0.043982, Predicted = -0.159191
#    Component 3: Ground Truth = -0.265349, Predicted = 0.356925
#    Component 4: Ground Truth = -0.053883, Predicted = -0.438032
#    Component 5: Ground Truth = 0.201130, Predicted = 0.972715
# tensor([[ 0.0277, -0.0559],
#         [-0.1563,  0.3505],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0329, -0.0681],
#         [ 0.0428, -0.2440],
#         [-0.0518,  0.1873]])
# Sample 78:
#    Component 0: Ground Truth = 0.032949, Predicted = 0.027744
#    Component 1: Ground Truth = -0.068092, Predicted = -0.055902
#    Component 2: Ground Truth = 0.042838, Predicted = -0.156283
#    Component 3: Ground Truth = -0.243965, Predicted = 0.350503
#    Component 4: Ground Truth = -0.051832, Predicted = -0.438032
#    Component 5: Ground Truth = 0.187302, Predicted = 0.972715
# tensor([[ 0.0270, -0.0543],
#         [-0.1534,  0.3441],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0314, -0.0650],
#         [ 0.0416, -0.2249],
#         [-0.0498,  0.1748]])
# Sample 79:
#    Component 0: Ground Truth = 0.031424, Predicted = 0.027017
#    Component 1: Ground Truth = -0.065041, Predicted = -0.054297
#    Component 2: Ground Truth = 0.041580, Predicted = -0.153371
#    Component 3: Ground Truth = -0.224873, Predicted = 0.344071
#    Component 4: Ground Truth = -0.049830, Predicted = -0.438032
#    Component 5: Ground Truth = 0.174809, Predicted = 0.972715
# tensor([[ 0.0263, -0.0527],
#         [-0.1505,  0.3376],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0300, -0.0624],
#         [ 0.0403, -0.2078],
#         [-0.0479,  0.1636]])
# Sample 80:
#    Component 0: Ground Truth = 0.030041, Predicted = 0.026292
#    Component 1: Ground Truth = -0.062370, Predicted = -0.052696
#    Component 2: Ground Truth = 0.040251, Predicted = -0.150454
#    Component 3: Ground Truth = -0.207772, Predicted = 0.337631
#    Component 4: Ground Truth = -0.047874, Predicted = -0.438032
#    Component 5: Ground Truth = 0.163555, Predicted = 0.972715
# tensor([[ 0.0256, -0.0511],
#         [-0.1477,  0.3314],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0287, -0.0599],
#         [ 0.0389, -0.1924],
#         [-0.0460,  0.1534]])
# Sample 81:
#    Component 0: Ground Truth = 0.028706, Predicted = 0.025568
#    Component 1: Ground Truth = -0.059891, Predicted = -0.051097
#    Component 2: Ground Truth = 0.038886, Predicted = -0.147654
#    Component 3: Ground Truth = -0.192406, Predicted = 0.331445
#    Component 4: Ground Truth = -0.045967, Predicted = -0.438032
#    Component 5: Ground Truth = 0.153351, Predicted = 0.972715
# tensor([[ 0.0248, -0.0495],
#         [-0.1449,  0.3253],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0275, -0.0574],
#         [ 0.0375, -0.1786],
#         [-0.0442,  0.1440]])
# Sample 82:
#    Component 0: Ground Truth = 0.027466, Predicted = 0.024845
#    Component 1: Ground Truth = -0.057411, Predicted = -0.049501
#    Component 2: Ground Truth = 0.037509, Predicted = -0.144890
#    Component 3: Ground Truth = -0.178559, Predicted = 0.325341
#    Component 4: Ground Truth = -0.044155, Predicted = -0.438032
#    Component 5: Ground Truth = 0.144005, Predicted = 0.972715
# tensor([[ 0.0241, -0.0479],
#         [-0.1421,  0.3192],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0263, -0.0551],
#         [ 0.0362, -0.1660],
#         [-0.0424,  0.1355]])
# Sample 83:
#    Component 0: Ground Truth = 0.026321, Predicted = 0.024124
#    Component 1: Ground Truth = -0.055122, Predicted = -0.047908
#    Component 2: Ground Truth = 0.036150, Predicted = -0.142123
#    Component 3: Ground Truth = -0.166047, Predicted = 0.319230
#    Component 4: Ground Truth = -0.042439, Predicted = -0.438032
#    Component 5: Ground Truth = 0.135517, Predicted = 0.972715
# tensor([[ 0.0234, -0.0463],
#         [-0.1394,  0.3131],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0252, -0.0530],
#         [ 0.0348, -0.1547],
#         [-0.0408,  0.1278]])
# Sample 84:
#    Component 0: Ground Truth = 0.025225, Predicted = 0.023404
#    Component 1: Ground Truth = -0.053024, Predicted = -0.046318
#    Component 2: Ground Truth = 0.034809, Predicted = -0.139353
#    Component 3: Ground Truth = -0.154708, Predicted = 0.313113
#    Component 4: Ground Truth = -0.040769, Predicted = -0.438032
#    Component 5: Ground Truth = 0.127792, Predicted = 0.972715
# tensor([[ 0.0227, -0.0447],
#         [-0.1366,  0.3070],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0242, -0.0511],
#         [ 0.0335, -0.1444],
#         [-0.0391,  0.1206]])
# Sample 85:
#    Component 0: Ground Truth = 0.024223, Predicted = 0.022685
#    Component 1: Ground Truth = -0.051117, Predicted = -0.044730
#    Component 2: Ground Truth = 0.033498, Predicted = -0.136580
#    Component 3: Ground Truth = -0.144410, Predicted = 0.306991
#    Component 4: Ground Truth = -0.039148, Predicted = -0.438032
#    Component 5: Ground Truth = 0.120640, Predicted = 0.972715
# tensor([[ 0.0219, -0.0431],
#         [-0.1338,  0.3009],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0233, -0.0492],
#         [ 0.0322, -0.1350],
#         [-0.0376,  0.1141]])
# Sample 86:
#    Component 0: Ground Truth = 0.023270, Predicted = 0.021928
#    Component 1: Ground Truth = -0.049210, Predicted = -0.043057
# ...
#    Component 5: Ground Truth = 0.010204, Predicted = 0.972715
# tensor([[ 0.0050, -0.0056],
#         [-0.0123,  0.0325],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0031, -0.0072],
#         [ 0.0035, -0.0067],
#         [-0.0046,  0.0101]])
# Sample 172:
#    Component 0: Ground Truth = 0.003099, Predicted = 0.004951
#    Component 1: Ground Truth = -0.007248, Predicted = -0.005566
#    Component 2: Ground Truth = 0.003487, Predicted = -0.012286
#    Component 3: Ground Truth = -0.006700, Predicted = 0.032499
#    Component 4: Ground Truth = -0.004578, Predicted = -0.438032
#    Component 5: Ground Truth = 0.010109, Predicted = 0.972715
# tensor([[ 0.0047, -0.0051],
#         [-0.0112,  0.0302],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0031, -0.0072],
#         [ 0.0034, -0.0066],
#         [-0.0045,  0.0099]])
# Sample 173:
#    Component 0: Ground Truth = 0.003052, Predicted = 0.004731
#    Component 1: Ground Truth = -0.007248, Predicted = -0.005081
#    Component 2: Ground Truth = 0.003427, Predicted = -0.011238
#    Component 3: Ground Truth = -0.006565, Predicted = 0.030186
#    Component 4: Ground Truth = -0.004530, Predicted = -0.438032
#    Component 5: Ground Truth = 0.009918, Predicted = 0.972715
# tensor([[ 0.0045, -0.0046],
#         [-0.0102,  0.0279],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0030, -0.0071],
#         [ 0.0034, -0.0064],
#         [-0.0044,  0.0097]])
# Sample 174:
#    Component 0: Ground Truth = 0.003004, Predicted = 0.004512
#    Component 1: Ground Truth = -0.007057, Predicted = -0.004596
#    Component 2: Ground Truth = 0.003374, Predicted = -0.010191
#    Component 3: Ground Truth = -0.006436, Predicted = 0.027873
#    Component 4: Ground Truth = -0.004435, Predicted = -0.438032
#    Component 5: Ground Truth = 0.009727, Predicted = 0.972715
# tensor([[ 0.0043, -0.0041],
#         [-0.0091,  0.0256],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0030, -0.0071],
#         [ 0.0033, -0.0063],
#         [-0.0044,  0.0096]])
# Sample 175:
#    Component 0: Ground Truth = 0.002956, Predicted = 0.004289
#    Component 1: Ground Truth = -0.007057, Predicted = -0.004104
#    Component 2: Ground Truth = 0.003320, Predicted = -0.009143
#    Component 3: Ground Truth = -0.006309, Predicted = 0.025560
#    Component 4: Ground Truth = -0.004387, Predicted = -0.438032
#    Component 5: Ground Truth = 0.009632, Predicted = 0.972715
# tensor([[ 0.0039, -0.0033],
#         [-0.0081,  0.0232],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0029, -0.0069],
#         [ 0.0033, -0.0062],
#         [-0.0043,  0.0094]])
# Sample 176:
#    Component 0: Ground Truth = 0.002909, Predicted = 0.003939
#    Component 1: Ground Truth = -0.006866, Predicted = -0.003332
#    Component 2: Ground Truth = 0.003266, Predicted = -0.008096
#    Component 3: Ground Truth = -0.006185, Predicted = 0.023246
#    Component 4: Ground Truth = -0.004339, Predicted = -0.438032
#    Component 5: Ground Truth = 0.009441, Predicted = 0.972715
# tensor([[ 0.0036, -0.0026],
#         [-0.0070,  0.0209],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0029, -0.0069],
#         [ 0.0032, -0.0061],
#         [-0.0042,  0.0093]])
# Sample 177:
#    Component 0: Ground Truth = 0.002861, Predicted = 0.003590
#    Component 1: Ground Truth = -0.006866, Predicted = -0.002561
#    Component 2: Ground Truth = 0.003219, Predicted = -0.007048
#    Component 3: Ground Truth = -0.006066, Predicted = 0.020933
#    Component 4: Ground Truth = -0.004244, Predicted = -0.438032
#    Component 5: Ground Truth = 0.009346, Predicted = 0.972715
# tensor([[ 0.0032, -0.0018],
#         [-0.0060,  0.0186],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0029, -0.0067],
#         [ 0.0032, -0.0059],
#         [-0.0042,  0.0092]])
# Sample 178:
#    Component 0: Ground Truth = 0.002861, Predicted = 0.003241
#    Component 1: Ground Truth = -0.006676, Predicted = -0.001790
#    Component 2: Ground Truth = 0.003165, Predicted = -0.006001
#    Component 3: Ground Truth = -0.005949, Predicted = 0.018619
#    Component 4: Ground Truth = -0.004196, Predicted = -0.438032
#    Component 5: Ground Truth = 0.009155, Predicted = 0.972715
# tensor([[ 0.0029, -0.0010],
#         [-0.0050,  0.0163],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0028, -0.0067],
#         [ 0.0031, -0.0058],
#         [-0.0041,  0.0091]])
# Sample 179:
#    Component 0: Ground Truth = 0.002813, Predicted = 0.002892
#    Component 1: Ground Truth = -0.006676, Predicted = -0.001020
#    Component 2: Ground Truth = 0.003117, Predicted = -0.004953
#    Component 3: Ground Truth = -0.005835, Predicted = 0.016306
#    Component 4: Ground Truth = -0.004148, Predicted = -0.438032
#    Component 5: Ground Truth = 0.009060, Predicted = 0.972715
# tensor([[ 2.5430e-03, -2.4849e-04],
#         [-3.9054e-03,  1.3992e-02],
#         [-4.3803e-01,  9.7272e-01]])
# tensor([[ 0.0028, -0.0065],
#         [ 0.0031, -0.0057],
#         [-0.0041,  0.0089]])
# Sample 180:
#    Component 0: Ground Truth = 0.002766, Predicted = 0.002543
#    Component 1: Ground Truth = -0.006485, Predicted = -0.000248
#    Component 2: Ground Truth = 0.003070, Predicted = -0.003905
#    Component 3: Ground Truth = -0.005725, Predicted = 0.013992
#    Component 4: Ground Truth = -0.004101, Predicted = -0.438032
#    Component 5: Ground Truth = 0.008869, Predicted = 0.972715
# tensor([[ 2.1940e-03,  5.2226e-04],
#         [-2.8577e-03,  1.1678e-02],
#         [-4.3803e-01,  9.7272e-01]])
# tensor([[ 0.0027, -0.0065],
#         [ 0.0030, -0.0056],
#         [-0.0040,  0.0088]])
# Sample 181:
#    Component 0: Ground Truth = 0.002718, Predicted = 0.002194
#    Component 1: Ground Truth = -0.006485, Predicted = 0.000522
#    Component 2: Ground Truth = 0.003022, Predicted = -0.002858
#    Component 3: Ground Truth = -0.005618, Predicted = 0.011678
#    Component 4: Ground Truth = -0.004005, Predicted = -0.438032
#    Component 5: Ground Truth = 0.008774, Predicted = 0.972715
# tensor([[ 0.0018,  0.0013],
#         [-0.0018,  0.0094],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0027, -0.0065],
#         [ 0.0030, -0.0055],
#         [-0.0040,  0.0086]])
# Sample 182:
#    Component 0: Ground Truth = 0.002670, Predicted = 0.001845
#    Component 1: Ground Truth = -0.006485, Predicted = 0.001293
#    Component 2: Ground Truth = 0.002980, Predicted = -0.001810
#    Component 3: Ground Truth = -0.005513, Predicted = 0.009364
#    Component 4: Ground Truth = -0.003958, Predicted = -0.438032
#    Component 5: Ground Truth = 0.008583, Predicted = 0.972715
# tensor([[ 1.4958e-03,  2.0640e-03],
#         [-7.6210e-04,  7.0505e-03],
#         [-4.3803e-01,  9.7272e-01]])
# tensor([[ 0.0027, -0.0063],
#         [ 0.0029, -0.0054],
#         [-0.0039,  0.0085]])
# Sample 183:
#    Component 0: Ground Truth = 0.002670, Predicted = 0.001496
#    Component 1: Ground Truth = -0.006294, Predicted = 0.002064
#    Component 2: Ground Truth = 0.002933, Predicted = -0.000762
#    Component 3: Ground Truth = -0.005412, Predicted = 0.007050
#    Component 4: Ground Truth = -0.003910, Predicted = -0.438032
#    Component 5: Ground Truth = 0.008488, Predicted = 0.972715
# tensor([[ 1.1473e-03,  2.8337e-03],
#         [ 2.8574e-04,  4.7364e-03],
#         [-4.3803e-01,  9.7272e-01]])
# tensor([[ 0.0026, -0.0063],
#         [ 0.0029, -0.0053],
#         [-0.0039,  0.0084]])
# Sample 184:
#    Component 0: Ground Truth = 0.002623, Predicted = 0.001147
#    Component 1: Ground Truth = -0.006294, Predicted = 0.002834
#    Component 2: Ground Truth = 0.002891, Predicted = 0.000286
#    Component 3: Ground Truth = -0.005312, Predicted = 0.004736
#    Component 4: Ground Truth = -0.003862, Predicted = -0.438032
#    Component 5: Ground Truth = 0.008392, Predicted = 0.972715
# tensor([[ 7.9855e-04,  3.6039e-03],
#         [ 1.3332e-03,  2.4232e-03],
#         [-4.3803e-01,  9.7272e-01]])
# tensor([[ 0.0026, -0.0061],
#         [ 0.0028, -0.0052],
#         [-0.0038,  0.0082]])
# Sample 185:
#    Component 0: Ground Truth = 0.002575, Predicted = 0.000799
#    Component 1: Ground Truth = -0.006104, Predicted = 0.003604
#    Component 2: Ground Truth = 0.002849, Predicted = 0.001333
#    Component 3: Ground Truth = -0.005215, Predicted = 0.002423
#    Component 4: Ground Truth = -0.003815, Predicted = -0.438032
#    Component 5: Ground Truth = 0.008202, Predicted = 0.972715
# tensor([[ 4.4981e-04,  4.3740e-03],
#         [ 2.3685e-03,  1.3685e-04],
#         [-4.3803e-01,  9.7272e-01]])
# tensor([[ 0.0025, -0.0061],
#         [ 0.0028, -0.0051],
#         [-0.0038,  0.0081]])
# Sample 186:
#    Component 0: Ground Truth = 0.002527, Predicted = 0.000450
#    Component 1: Ground Truth = -0.006104, Predicted = 0.004374
#    Component 2: Ground Truth = 0.002807, Predicted = 0.002369
#    Component 3: Ground Truth = -0.005122, Predicted = 0.000137
#    Component 4: Ground Truth = -0.003767, Predicted = -0.438032
#    Component 5: Ground Truth = 0.008106, Predicted = 0.972715
# tensor([[ 1.0100e-04,  5.1444e-03],
#         [ 3.3934e-03, -2.1266e-03],
#         [-4.3803e-01,  9.7272e-01]])
# tensor([[ 0.0025, -0.0059],
#         [ 0.0028, -0.0050],
#         [-0.0037,  0.0080]])
# Sample 187:
#    Component 0: Ground Truth = 0.002527, Predicted = 0.000101
#    Component 1: Ground Truth = -0.005913, Predicted = 0.005144
#    Component 2: Ground Truth = 0.002766, Predicted = 0.003393
#    Component 3: Ground Truth = -0.005029, Predicted = -0.002127
#    Component 4: Ground Truth = -0.003672, Predicted = -0.438032
#    Component 5: Ground Truth = 0.008011, Predicted = 0.972715
# tensor([[-2.4775e-04,  5.9146e-03],
#         [ 4.4486e-03, -4.4569e-03],
#         [-4.3803e-01,  9.7272e-01]])
# tensor([[ 0.0025, -0.0059],
#         [ 0.0027, -0.0049],
#         [-0.0036,  0.0079]])
# Sample 188:
#    Component 0: Ground Truth = 0.002480, Predicted = -0.000248
#    Component 1: Ground Truth = -0.005913, Predicted = 0.005915
#    Component 2: Ground Truth = 0.002724, Predicted = 0.004449
#    Component 3: Ground Truth = -0.004940, Predicted = -0.004457
#    Component 4: Ground Truth = -0.003624, Predicted = -0.438032
#    Component 5: Ground Truth = 0.007916, Predicted = 0.972715
# tensor([[-5.9670e-04,  6.6851e-03],
#         [ 5.5170e-03, -6.8164e-03],
#         [-4.3803e-01,  9.7272e-01]])
# tensor([[ 0.0024, -0.0059],
#         [ 0.0027, -0.0049],
#         [-0.0036,  0.0078]])
# Sample 189:
#    Component 0: Ground Truth = 0.002432, Predicted = -0.000597
#    Component 1: Ground Truth = -0.005913, Predicted = 0.006685
#    Component 2: Ground Truth = 0.002688, Predicted = 0.005517
#    Component 3: Ground Truth = -0.004853, Predicted = -0.006816
#    Component 4: Ground Truth = -0.003576, Predicted = -0.438032
#    Component 5: Ground Truth = 0.007820, Predicted = 0.972715
# tensor([[-9.4491e-04,  7.4542e-03],
#         [ 6.5853e-03, -9.1756e-03],
#         [-4.3803e-01,  9.7272e-01]])
# tensor([[ 0.0024, -0.0057],
#         [ 0.0026, -0.0048],
#         [-0.0035,  0.0076]])
# Sample 190:
#    Component 0: Ground Truth = 0.002432, Predicted = -0.000945
#    Component 1: Ground Truth = -0.005722, Predicted = 0.007454
#    Component 2: Ground Truth = 0.002646, Predicted = 0.006585
#    Component 3: Ground Truth = -0.004768, Predicted = -0.009176
#    Component 4: Ground Truth = -0.003529, Predicted = -0.438032
#    Component 5: Ground Truth = 0.007629, Predicted = 0.972715
# tensor([[-0.0013,  0.0082],
#         [ 0.0077, -0.0116],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0024, -0.0057],
#         [ 0.0026, -0.0047],
#         [-0.0035,  0.0075]])
# Sample 191:
#    Component 0: Ground Truth = 0.002384, Predicted = -0.001294
#    Component 1: Ground Truth = -0.005722, Predicted = 0.008225
#    Component 2: Ground Truth = 0.002611, Predicted = 0.007674
#    Component 3: Ground Truth = -0.004685, Predicted = -0.011579
#    Component 4: Ground Truth = -0.003481, Predicted = -0.438032
#    Component 5: Ground Truth = 0.007534, Predicted = 0.972715
# tensor([[-0.0016,  0.0090],
#         [ 0.0088, -0.0141],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0023, -0.0055],
#         [ 0.0026, -0.0046],
#         [-0.0034,  0.0074]])
# Sample 192:
#    Component 0: Ground Truth = 0.002337, Predicted = -0.001642
#    Component 1: Ground Truth = -0.005531, Predicted = 0.008993
#    Component 2: Ground Truth = 0.002575, Predicted = 0.008794
#    Component 3: Ground Truth = -0.004605, Predicted = -0.014054
#    Component 4: Ground Truth = -0.003433, Predicted = -0.438032
#    Component 5: Ground Truth = 0.007439, Predicted = 0.972715
# tensor([[-0.0020,  0.0098],
#         [ 0.0099, -0.0165],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0023, -0.0055],
#         [ 0.0025, -0.0045],
#         [-0.0034,  0.0073]])
# Sample 193:
#    Component 0: Ground Truth = 0.002337, Predicted = -0.001991
#    Component 1: Ground Truth = -0.005531, Predicted = 0.009764
#    Component 2: Ground Truth = 0.002539, Predicted = 0.009900
#    Component 3: Ground Truth = -0.004525, Predicted = -0.016495
#    Component 4: Ground Truth = -0.003386, Predicted = -0.438032
#    Component 5: Ground Truth = 0.007343, Predicted = 0.972715
# tensor([[-0.0023,  0.0105],
#         [ 0.0109, -0.0188],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0023, -0.0055],
#         [ 0.0025, -0.0044],
#         [-0.0033,  0.0072]])
# Sample 194:
#    Component 0: Ground Truth = 0.002289, Predicted = -0.002339
#    Component 1: Ground Truth = -0.005531, Predicted = 0.010533
#    Component 2: Ground Truth = 0.002503, Predicted = 0.010922
#    Component 3: Ground Truth = -0.004448, Predicted = -0.018753
#    Component 4: Ground Truth = -0.003338, Predicted = -0.438032
#    Component 5: Ground Truth = 0.007248, Predicted = 0.972715
# tensor([[-0.0027,  0.0113],
#         [ 0.0119, -0.0210],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0022, -0.0053],
#         [ 0.0025, -0.0044],
#         [-0.0033,  0.0072]])
# Sample 195:
#    Component 0: Ground Truth = 0.002241, Predicted = -0.002688
#    Component 1: Ground Truth = -0.005341, Predicted = 0.011303
#    Component 2: Ground Truth = 0.002468, Predicted = 0.011945
#    Component 3: Ground Truth = -0.004372, Predicted = -0.021012
#    Component 4: Ground Truth = -0.003338, Predicted = -0.438032
#    Component 5: Ground Truth = 0.007153, Predicted = 0.972715
# tensor([[-0.0030,  0.0121],
#         [ 0.0129, -0.0232],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0022, -0.0053],
#         [ 0.0024, -0.0043],
#         [-0.0033,  0.0071]])
# Sample 196:
#    Component 0: Ground Truth = 0.002241, Predicted = -0.003036
#    Component 1: Ground Truth = -0.005341, Predicted = 0.012072
#    Component 2: Ground Truth = 0.002438, Predicted = 0.012948
#    Component 3: Ground Truth = -0.004299, Predicted = -0.023226
#    Component 4: Ground Truth = -0.003290, Predicted = -0.438032
#    Component 5: Ground Truth = 0.007057, Predicted = 0.972715
# tensor([[-0.0034,  0.0128],
#         [ 0.0139, -0.0254],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0022, -0.0053],
#         [ 0.0024, -0.0042],
#         [-0.0032,  0.0070]])
# Sample 197:
#    Component 0: Ground Truth = 0.002193, Predicted = -0.003388
#    Component 1: Ground Truth = -0.005341, Predicted = 0.012848
#    Component 2: Ground Truth = 0.002402, Predicted = 0.013926
#    Component 3: Ground Truth = -0.004227, Predicted = -0.025387
#    Component 4: Ground Truth = -0.003242, Predicted = -0.438032
#    Component 5: Ground Truth = 0.006962, Predicted = 0.972715
# tensor([[-0.0037,  0.0136],
#         [ 0.0149, -0.0275],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0022, -0.0051],
#         [ 0.0024, -0.0042],
#         [-0.0032,  0.0069]])
# Sample 198:
#    Component 0: Ground Truth = 0.002193, Predicted = -0.003742
#    Component 1: Ground Truth = -0.005150, Predicted = 0.013631
#    Component 2: Ground Truth = 0.002372, Predicted = 0.014905
#    Component 3: Ground Truth = -0.004157, Predicted = -0.027549
#    Component 4: Ground Truth = -0.003195, Predicted = -0.438032
#    Component 5: Ground Truth = 0.006866, Predicted = 0.972715
# tensor([[-0.0041,  0.0144],
#         [ 0.0159, -0.0297],
#         [-0.4380,  0.9727]])
# tensor([[ 0.0021, -0.0051],
#         [ 0.0023, -0.0041],
#         [-0.0031,  0.0068]])
# Sample 199:
#    Component 0: Ground Truth = 0.002146, Predicted = -0.004096
#    Component 1: Ground Truth = -0.005150, Predicted = 0.014413
#    Component 2: Ground Truth = 0.002337, Predicted = 0.015884
#    Component 3: Ground Truth = -0.004089, Predicted = -0.029710
#    Component 4: Ground Truth = -0.003147, Predicted = -0.438032
#    Component 5: Ground Truth = 0.006771, Predicted = 0.972715
