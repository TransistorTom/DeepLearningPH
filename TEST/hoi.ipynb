# %%
import sys
import os

# Get directory
current_dir = os.getcwd()

# Create project_root for module imports
project_root = os.path.abspath(os.path.join(current_dir, ".."))
sys.path.append(project_root)

# Create data directory path
parent_dir = os.path.dirname(current_dir)
save_dir = os.path.join(parent_dir, "final_messages", "n_body_gravity")
os.makedirs(save_dir, exist_ok=True)

# Importing self-made models and functions
from simulations.n_body_trajectory import n_body_simulation, generate_random_positions, generate_random_velocities, generate_unique_masses
from gnn_model.node_data_list import node_data_list 
from gnn_model.GNN_MLP import GNN_MLP
from gnn_model.train_model import train_model
from gnn_model.pipeline import pipeline

# Import other packages
from pysr import PySRRegressor
import numpy as np
import torch
import pandas as pd
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/juliacall/__init__.py:61: UserWarning: torch was imported before juliacall. This may cause a segfault. To avoid this, import juliacall before importing torch. For updates, see https://github.com/pytorch/pytorch/issues/78829.
#   warnings.warn(
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
model_3, train_messages_3, test_messages_3 = pipeline(train_iterations=64, test_iterations=16,
                 N_train=3, N_test_list=[2, 3, 4, 5, 6], T=128, dt=0.02, dim=2, hidden_channels=128,
                 m_dim=2, out_channels=2, epochs=20, lr=0.0001, G=1.0, single_node=False, testing=True)
# Out:
# Epoch 001: MSE = 1.281737, Mean Relative Error = 3.921820
# Epoch 002: MSE = 1.115803, Mean Relative Error = 3.517240
# Epoch 003: MSE = 0.971525, Mean Relative Error = 3.322888
# Epoch 004: MSE = 0.881562, Mean Relative Error = 3.212323
# Epoch 005: MSE = 0.816954, Mean Relative Error = 3.795496
# Epoch 006: MSE = 0.776377, Mean Relative Error = 3.706107
# Epoch 007: MSE = 0.728020, Mean Relative Error = 3.564572
# Epoch 008: MSE = 0.714951, Mean Relative Error = 4.321532
# Epoch 009: MSE = 0.692018, Mean Relative Error = 4.600280
# Epoch 010: MSE = 0.673432, Mean Relative Error = 5.113424
# Epoch 011: MSE = 0.680546, Mean Relative Error = 3.911061
# Epoch 012: MSE = 0.656857, Mean Relative Error = 4.005616
# Epoch 013: MSE = 0.634608, Mean Relative Error = 3.799608
# Epoch 014: MSE = 0.630743, Mean Relative Error = 3.739285
# Epoch 015: MSE = 0.610888, Mean Relative Error = 3.684139
# Epoch 016: MSE = 0.595264, Mean Relative Error = 3.770298
# Epoch 017: MSE = 0.649681, Mean Relative Error = 3.959217
# Epoch 018: MSE = 0.595703, Mean Relative Error = 4.051835
# Epoch 019: MSE = 0.593124, Mean Relative Error = 3.887865
# Epoch 020: MSE = 0.619724, Mean Relative Error = 3.775111
# 4064
# average loss per/over timestep N=2:   17.26764283246566
# 4064
# average loss per/over timestep N=3:   16.74610860351341
# 4064
# average loss per/over timestep N=4:   14.469162722569193
# 4064
# average loss per/over timestep N=5:   14.908410803986875
# 4064
# average loss per/over timestep N=6:   18.608869269057582

# %%
train_messages_3.to_csv(f"{save_dir}/train_messages_3.csv", index=False)
# Load your cleaned DataFrame
train_df = pd.read_csv(f"{save_dir}/train_messages_3.csv")
train_df['r3'] = train_df['r'] ** 3
features = ['mass_j', 'dx', 'dy', 'r3']

train_X = train_df[features].sample(frac=0.1, random_state=42)
train_y_x = train_df['message_x'].sample(frac=0.1, random_state=42)
train_y_y = train_df['message_y'].sample(frac=0.1, random_state=42)
# Load your cleaned DataFrame
test_df = pd.read_csv(f"{save_dir}/test_messages_3.csv")
test_df['r3'] = test_df['r'] ** 3
features = ['mass_j', 'dx', 'dy', 'r3']

test_X = test_df[features].sample(frac=0.001, random_state=42)
test_y_x = test_df['message_x'].sample(frac=0.001, random_state=42)
test_y_y = test_df['message_y'].sample(frac=0.001, random_state=42)


# Create and fit SR model for message_x
train_model_x = PySRRegressor(
    niterations=500,
    binary_operators=["+", "-", "*", "/"],
    # unary_operators=["cube"],
    model_selection="best",  # Select best tradeoff between complexity and error
    select_k_features=7,  # small number of features
    verbosity=1,
    maxdepth=10
)

train_model_x.fit(train_X.values, train_y_x.values, variable_names = features)

# Print best expression for message_x
print("Best expression for message_x:")
print(train_model_x)

# Optionally: model for message_y too
train_model_y = PySRRegressor(
    niterations=500,
    binary_operators=["+", "-", "*", "/"],
    # unary_operators=["cube"],
    model_selection="best",
    select_k_features=5,  # small number of features
    verbosity=1,
    maxdepth=10
)

train_model_y.fit(train_X.values, train_y_y.values, variable_names = features)
print("Best expression for message_y:")
print(train_model_y)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pysr/sr.py:2582: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Using features ['mass_j' 'dx' 'dy' 'r3']
# Compiling Julia backend...
# [ Info: Started!
# Expressions evaluated per second: 7.440e+04
# Head worker occupation: 16.2%
# Progress: 170 / 7500 total iterations (2.267%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 3           4.125e-01  5.314e+00  y = -0.0022156 / r3
# 5           1.753e-01  4.278e-01  y = dx / (0.0076315 + r3)
# 7           7.076e-02  4.537e-01  y = dx / ((0.015627 / mass_j) + r3)
# 9           3.134e-02  4.072e-01  y = (dx * mass_j) / (0.015627 + (r3 / 0.15468))
# 11          2.327e-02  1.488e-01  y = ((dx * mass_j) + -0.03708) / (0.015627 + (r3 / 0.15468))
# 13          2.277e-02  1.093e-02  y = ((dx * (mass_j - 0.38508)) + -0.099625) / (0.015627 + (r3 ...
#                                   / 0.15468))
# 15          1.780e-02  1.230e-01  y = ((((dx / 0.24949) * mass_j) + -0.56287) / ((r3 / 0.061067)...
#                                    + 0.061067)) / 1.4337
# 17          1.651e-02  3.758e-02  y = (((((dx / 1.0656) / 0.24949) * mass_j) + -0.56287) / (0.05...
#                                   7731 + (r3 / 0.061067))) / 1.4337
# 19          1.569e-02  2.568e-02  y = (((((dx / 1.0656) / 0.24949) * (mass_j - dx)) + -0.56287) ...
#                                   / (0.057731 + (r3 / 0.061067))) / 1.4337
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.

# %%
# Load your cleaned DataFrame
train_df = pd.read_csv(f"{save_dir}/train_messages_3.csv")
train_df['r3'] = train_df['r'] ** 3
features = ['mass_j', 'dx', 'dy', 'r3']

train_X = train_df[features].sample(frac=0.1, random_state=42)
train_y_x = train_df['message_x'].sample(frac=0.1, random_state=42)
train_y_y = train_df['message_y'].sample(frac=0.1, random_state=42)
# Load your cleaned DataFrame
test_df = pd.read_csv(f"{save_dir}/test_messages_3.csv")
test_df['r3'] = test_df['r'] ** 3
features = ['mass_j', 'dx', 'dy', 'r3']

test_X = test_df[features].sample(frac=0.001, random_state=42)
test_y_x = test_df['message_x'].sample(frac=0.001, random_state=42)
test_y_y = test_df['message_y'].sample(frac=0.001, random_state=42)


# Create and fit SR model for message_x
train_model_x = PySRRegressor(
    niterations=500,
    binary_operators=["+", "-", "*", "/"],
    # unary_operators=["cube"],
    model_selection="best",  # Select best tradeoff between complexity and error
    select_k_features=7,  # small number of features
    verbosity=1,
    maxdepth=5
)

train_model_x.fit(train_X.values, train_y_x.values, variable_names = features)

# Print best expression for message_x
print("Best expression for message_x:")
print(train_model_x)

# Optionally: model for message_y too
train_model_y = PySRRegressor(
    niterations=500,
    binary_operators=["+", "-", "*", "/"],
    # unary_operators=["cube"],
    model_selection="best",
    select_k_features=5,  # small number of features
    verbosity=1,
    maxdepth=5
)

train_model_y.fit(train_X.values, train_y_y.values, variable_names = features)
print("Best expression for message_y:")
print(train_model_y)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pysr/sr.py:2582: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# Using features ['mass_j' 'dx' 'dy' 'r3']
# Compiling Julia backend...
# [ Info: Started!
# Expressions evaluated per second: 6.750e+04
# Head worker occupation: 17.5%
# Progress: 154 / 7500 total iterations (2.053%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           3.012e+00  1.594e+01  y = -1.5947
# 3           4.107e-01  9.963e-01  y = -0.0019755 / r3
# 5           2.108e-01  3.335e-01  y = dx / (0.011232 + r3)
# 7           8.995e-02  4.257e-01  y = dx / (-0.74691 + (0.7491 + r3))
# 9           3.030e-02  5.441e-01  y = (dx / (0.014925 + (r3 / 0.15365))) * mass_j
# 11          2.688e-02  5.987e-02  y = (dx / (0.014925 + (r3 / 0.15365))) * (mass_j - dx)
# 13          1.677e-02  2.359e-01  y = (mass_j - (0.16625 / dx)) * (dx / (0.023348 + (r3 / 0.1589...
#                                   8)))
# 15          1.621e-02  1.680e-02  y = (dx / (0.023348 + (r3 / 0.15898))) * ((mass_j - dx) - (0.1...
#                                   6625 / dx))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.720e+04
# Head worker occupation: 14.8%
# Progress: 314 / 7500 total iterations (4.187%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           1.568e-01  4.813e-01  y = dx / (r3 + 0.0061696)
# 7           7.922e-02  3.414e-01  y = dx / ((0.011232 / mass_j) + r3)
# 9           2.949e-02  4.941e-01  y = mass_j * (dx / ((r3 / 0.1503) + 0.013903))
# 11          1.540e-02  3.248e-01  y = ((dx - 0.025025) / (0.025025 + (r3 / 0.15898))) * mass_j
# 13          1.466e-02  2.458e-02  y = ((dx - 0.025025) / (0.025025 + (r3 / 0.15898))) * (mass_j ...
#                                   - dx)
# 15          1.452e-02  4.923e-03  y = ((dx - 0.025025) / (0.025025 + (r3 / 0.15898))) * (mass_j ...
#                                   - (dx + dy))
# 17          1.439e-02  4.433e-03  y = ((dx - 0.025025) / (0.025025 + (r3 / 0.15898))) * ((mass_j...
#                                    - dx) - (0.025025 * r3))
# 19          1.424e-02  5.062e-03  y = ((dx - 0.025025) / (0.025025 + (r3 / 0.15898))) * ((mass_j...
#                                    - (dx + dy)) - (0.025025 * r3))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.170e+04
# Head worker occupation: 14.6%
# Progress: 493 / 7500 total iterations (6.573%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           1.568e-01  4.813e-01  y = dx / (r3 + 0.0061696)
# 7           7.860e-02  3.454e-01  y = dx / ((0.011323 / mass_j) + r3)
# 9           2.949e-02  4.902e-01  y = mass_j * (dx / ((r3 / 0.1503) + 0.013903))
# 11          1.503e-02  3.369e-01  y = ((dx - 0.022723) / ((r3 / 0.15898) + 0.022723)) * mass_j
# 13          1.416e-02  3.008e-02  y = ((dx - 0.022723) / ((r3 / 0.15898) + 0.022723)) * (mass_j ...
#                                   - dx)
# 15          1.404e-02  4.146e-03  y = ((mass_j - dx) - dy) * ((dx - 0.022723) / (0.022723 + (r3 ...
#                                   / 0.15898)))
# 19          1.393e-02  1.917e-03  y = ((dx - 0.022723) / (0.025025 + (r3 / 0.15898))) * ((mass_j...
#                                    - (dx - 0.24684)) - (0.025025 * r3))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.060e+04
# Head worker occupation: 14.4%
# Progress: 658 / 7500 total iterations (8.773%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           9.174e-02  7.494e-01  y = dx / (r3 - -0.0017925)
# 7           7.860e-02  7.733e-02  y = dx / ((0.011323 / mass_j) + r3)
# 9           2.949e-02  4.902e-01  y = mass_j * (dx / ((r3 / 0.1503) + 0.013903))
# 11          1.491e-02  3.410e-01  y = mass_j * ((dx - 0.022527) / (0.023492 + (r3 / 0.15899)))
# 13          1.397e-02  3.255e-02  y = ((dx - 0.02256) / ((r3 / 0.15928) + 0.023585)) * (mass_j -...
#                                    dx)
# 15          1.380e-02  6.132e-03  y = ((dx - 0.02256) / ((r3 / 0.15928) + 0.023585)) * ((mass_j ...
#                                   - dx) - dy)
# 17          1.353e-02  9.634e-03  y = ((dx - (0.022723 * 0.83869)) / ((r3 / 0.15898) + 0.022723)...
#                                   ) * (mass_j - (dx + dy))
# 19          1.347e-02  2.507e-03  y = ((dx - (0.022723 * 0.83869)) / ((r3 / 0.15898) + 0.022723)...
#                                   ) * ((mass_j + 0.088669) - (dx + dy))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.280e+04
# Head worker occupation: 14.2%
# Progress: 834 / 7500 total iterations (11.120%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           9.174e-02  7.494e-01  y = dx / (r3 - -0.0017925)
# 7           7.860e-02  7.733e-02  y = dx / ((0.011323 / mass_j) + r3)
# 9           2.948e-02  4.903e-01  y = mass_j * (dx / ((r3 / 0.14987) + 0.013922))
# 11          1.491e-02  3.409e-01  y = mass_j * ((dx - 0.022527) / (0.023492 + (r3 / 0.15899)))
# 13          1.365e-02  4.420e-02  y = (mass_j - dx) * ((dx - 0.020092) / ((r3 / 0.1599) + 0.0220...
#                                   42))
# 15          1.346e-02  6.969e-03  y = ((mass_j - dx) - dy) * ((dx - 0.020092) / (0.022042 + (r3 ...
#                                   / 0.1599)))
# 17          1.301e-02  1.691e-02  y = ((dx - 0.02256) / ((r3 / 0.15928) + 0.023585)) * (mass_j -...
#                                    ((dx * mass_j) * 0.21849))
# 19          1.284e-02  6.701e-03  y = ((dx - (0.022723 * 0.83869)) / ((r3 / 0.15898) + 0.022723)...
#                                   ) * (mass_j + ((dx * -0.27573) * mass_j))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.690e+04
# Head worker occupation: 14.2%
# Progress: 1012 / 7500 total iterations (13.493%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           9.174e-02  7.494e-01  y = dx / (r3 - -0.0017925)
# 7           7.860e-02  7.733e-02  y = dx / ((0.011323 / mass_j) + r3)
# 9           2.947e-02  4.904e-01  y = (dx / ((r3 / 0.14989) + 0.013871)) * mass_j
# 11          1.481e-02  3.442e-01  y = ((dx - 0.020092) / ((r3 / 0.15928) + 0.022042)) * mass_j
# 13          1.364e-02  4.089e-02  y = (mass_j - dx) * ((dx - 0.020092) / ((r3 / 0.15928) + 0.022...
#                                   042))
# 15          1.346e-02  6.873e-03  y = ((mass_j - dx) - dy) * ((dx - 0.020092) / (0.022042 + (r3 ...
#                                   / 0.1599)))
# 17          1.292e-02  2.032e-02  y = ((dx - 0.022042) / ((r3 / 0.15928) + 0.023585)) * (mass_j ...
#                                   - ((dx * mass_j) * 0.21849))
# 19          1.284e-02  3.290e-03  y = ((dx - (0.022723 * 0.83869)) / ((r3 / 0.15898) + 0.022723)...
#                                   ) * (mass_j + ((dx * -0.27573) * mass_j))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.320e+04
# Head worker occupation: 14.8%
# Progress: 1163 / 7500 total iterations (15.507%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           9.174e-02  7.494e-01  y = dx / (r3 - -0.0017925)
# 7           7.860e-02  7.733e-02  y = dx / ((0.011323 / mass_j) + r3)
# 9           2.947e-02  4.904e-01  y = (dx / ((r3 / 0.14989) + 0.013871)) * mass_j
# 11          1.481e-02  3.442e-01  y = ((dx - 0.020092) / ((r3 / 0.15928) + 0.022042)) * mass_j
# 13          1.358e-02  4.329e-02  y = (mass_j - dx) * ((-0.019091 + dx) / (0.022042 + (r3 / 0.15...
#                                   928)))
# 15          1.334e-02  8.775e-03  y = ((-0.019091 + dx) / (0.022042 + (r3 / 0.15928))) * (mass_j...
#                                    - (dy + dx))
# 17          1.292e-02  1.602e-02  y = ((dx - 0.022042) / ((r3 / 0.15928) + 0.023585)) * (mass_j ...
#                                   - ((dx * mass_j) * 0.21849))
# 19          1.248e-02  1.741e-02  y = ((mass_j - dy) - (dx * (0.15879 * mass_j))) * ((dx - 0.020...
#                                   092) / ((r3 / 0.15928) + 0.022042))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.460e+04
# Head worker occupation: 15.3%
# Progress: 1330 / 7500 total iterations (17.733%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           9.174e-02  7.494e-01  y = dx / (r3 - -0.0017925)
# 7           7.860e-02  7.733e-02  y = dx / ((0.011323 / mass_j) + r3)
# 9           2.947e-02  4.904e-01  y = (dx / ((r3 / 0.14989) + 0.013871)) * mass_j
# 11          1.481e-02  3.442e-01  y = ((dx - 0.020092) / ((r3 / 0.15928) + 0.022042)) * mass_j
# 13          1.358e-02  4.329e-02  y = (mass_j - dx) * ((-0.019091 + dx) / (0.022042 + (r3 / 0.15...
#                                   928)))
# 15          1.334e-02  8.775e-03  y = ((-0.019091 + dx) / (0.022042 + (r3 / 0.15928))) * (mass_j...
#                                    - (dy + dx))
# 17          1.267e-02  2.600e-02  y = (mass_j - (dx * (0.15879 * mass_j))) * ((dx - 0.020092) / ...
#                                   ((r3 / 0.15928) + 0.022042))
# 19          1.248e-02  7.432e-03  y = ((mass_j - dy) - (dx * (0.15879 * mass_j))) * ((dx - 0.020...
#                                   092) / ((r3 / 0.15928) + 0.022042))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.310e+04
# Head worker occupation: 15.2%
# Progress: 1488 / 7500 total iterations (19.840%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           9.174e-02  7.494e-01  y = dx / (r3 - -0.0017925)
# 7           7.076e-02  1.299e-01  y = dx / ((0.015627 / mass_j) + r3)
# 9           2.947e-02  4.378e-01  y = (dx / ((r3 / 0.14989) + 0.013871)) * mass_j
# 11          1.481e-02  3.442e-01  y = ((dx - 0.020092) / ((r3 / 0.15928) + 0.022042)) * mass_j
# 13          1.358e-02  4.329e-02  y = (mass_j - dx) * ((-0.019091 + dx) / (0.022042 + (r3 / 0.15...
#                                   928)))
# 15          1.334e-02  8.775e-03  y = ((-0.019091 + dx) / (0.022042 + (r3 / 0.15928))) * (mass_j...
#                                    - (dy + dx))
# 17          1.266e-02  2.609e-02  y = (mass_j - (dx * (0.15928 * mass_j))) * ((dx - 0.020092) / ...
#                                   ((r3 / 0.15928) + 0.022042))
# 19          1.233e-02  1.318e-02  y = (mass_j - ((dx + dy) * (0.15928 * mass_j))) * ((dx - 0.020...
#                                   092) / ((r3 / 0.15928) + 0.022042))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.180e+04
# Head worker occupation: 15.0%
# Progress: 1653 / 7500 total iterations (22.040%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           9.174e-02  7.494e-01  y = dx / (r3 - -0.0017925)
# 7           7.076e-02  1.299e-01  y = dx / ((0.015627 / mass_j) + r3)
# 9           2.947e-02  4.378e-01  y = (dx / ((r3 / 0.14989) + 0.013871)) * mass_j
# 11          1.481e-02  3.442e-01  y = ((dx - 0.020092) / ((r3 / 0.15928) + 0.022042)) * mass_j
# 13          1.358e-02  4.329e-02  y = (mass_j - dx) * ((-0.019091 + dx) / (0.022042 + (r3 / 0.15...
#                                   928)))
# 15          1.334e-02  8.775e-03  y = ((-0.019091 + dx) / (0.022042 + (r3 / 0.15928))) * (mass_j...
#                                    - (dy + dx))
# 17          1.266e-02  2.609e-02  y = (mass_j - (dx * (0.15928 * mass_j))) * ((dx - 0.020092) / ...
#                                   ((r3 / 0.15928) + 0.022042))
# 19          1.233e-02  1.318e-02  y = (mass_j - ((dx + dy) * (0.15928 * mass_j))) * ((dx - 0.020...
#                                   092) / ((r3 / 0.15928) + 0.022042))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.230e+04
# Head worker occupation: 14.9%
# Progress: 1811 / 7500 total iterations (24.147%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           8.961e-02  7.611e-01  y = dx / (r3 - -0.0021255)
# 7           7.076e-02  1.181e-01  y = dx / ((0.015627 / mass_j) + r3)
# 9           2.947e-02  4.380e-01  y = mass_j * (dx / (0.013835 + (r3 / 0.14957)))
# 11          1.481e-02  3.441e-01  y = ((dx - 0.020092) / ((r3 / 0.15928) + 0.022042)) * mass_j
# 13          1.358e-02  4.329e-02  y = (mass_j - dx) * ((-0.019091 + dx) / (0.022042 + (r3 / 0.15...
#                                   928)))
# 15          1.334e-02  8.775e-03  y = ((-0.019091 + dx) / (0.022042 + (r3 / 0.15928))) * (mass_j...
#                                    - (dy + dx))
# 17          1.266e-02  2.609e-02  y = (mass_j - (dx * (0.15928 * mass_j))) * ((dx - 0.020092) / ...
#                                   ((r3 / 0.15928) + 0.022042))
# 19          1.233e-02  1.318e-02  y = (mass_j - ((dx + dy) * (0.15928 * mass_j))) * ((dx - 0.020...
#                                   092) / ((r3 / 0.15928) + 0.022042))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.320e+04
# Head worker occupation: 14.8%
# Progress: 1970 / 7500 total iterations (26.267%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           8.961e-02  7.611e-01  y = dx / (r3 - -0.0021255)
# 7           7.020e-02  1.221e-01  y = dx / ((0.014853 / mass_j) + r3)
# 9           2.947e-02  4.340e-01  y = mass_j * (dx / (0.013835 + (r3 / 0.14957)))
# 11          1.481e-02  3.441e-01  y = ((dx - 0.020092) / ((r3 / 0.15928) + 0.022042)) * mass_j
# 13          1.358e-02  4.329e-02  y = (mass_j - dx) * ((-0.019091 + dx) / (0.022042 + (r3 / 0.15...
#                                   928)))
# 15          1.334e-02  8.775e-03  y = ((-0.019091 + dx) / (0.022042 + (r3 / 0.15928))) * (mass_j...
#                                    - (dy + dx))
# 17          1.266e-02  2.609e-02  y = (mass_j - (dx * (0.15928 * mass_j))) * ((dx - 0.020092) / ...
#                                   ((r3 / 0.15928) + 0.022042))
# 19          1.233e-02  1.318e-02  y = (mass_j - ((dx + dy) * (0.15928 * mass_j))) * ((dx - 0.020...
#                                   092) / ((r3 / 0.15928) + 0.022042))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.900e+04
# Head worker occupation: 15.2%
# Progress: 2101 / 7500 total iterations (28.013%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           8.961e-02  7.611e-01  y = dx / (r3 - -0.0021255)
# 7           7.020e-02  1.221e-01  y = dx / ((0.014853 / mass_j) + r3)
# 9           2.947e-02  4.340e-01  y = mass_j * (dx / ((r3 / 0.14866) + 0.013855))
# 11          1.481e-02  3.441e-01  y = ((dx - 0.020092) / ((r3 / 0.15928) + 0.022042)) * mass_j
# 13          1.358e-02  4.329e-02  y = (mass_j - dx) * ((-0.019091 + dx) / (0.022042 + (r3 / 0.15...
#                                   928)))
# 15          1.334e-02  8.775e-03  y = ((mass_j - dy) - dx) * ((dx + -0.019091) / (0.022042 + (r3...
#                                    / 0.15928)))
# 17          1.266e-02  2.609e-02  y = (mass_j - (dx * (0.15928 * mass_j))) * ((dx - 0.020092) / ...
#                                   ((r3 / 0.15928) + 0.022042))
# 19          1.233e-02  1.318e-02  y = (mass_j - ((dx + dy) * (0.15928 * mass_j))) * ((dx - 0.020...
#                                   092) / ((r3 / 0.15928) + 0.022042))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.700e+04
# Head worker occupation: 15.1%
# Progress: 2244 / 7500 total iterations (29.920%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           8.961e-02  7.611e-01  y = dx / (r3 - -0.0021255)
# 7           7.020e-02  1.221e-01  y = dx / ((0.014853 / mass_j) + r3)
# 9           2.947e-02  4.340e-01  y = mass_j * (dx / ((r3 / 0.14866) + 0.013855))
# 11          1.481e-02  3.441e-01  y = ((dx - 0.020092) / ((r3 / 0.15928) + 0.022042)) * mass_j
# 13          1.358e-02  4.329e-02  y = (mass_j - dx) * ((-0.019091 + dx) / (0.022042 + (r3 / 0.15...
#                                   928)))
# 15          1.334e-02  8.775e-03  y = ((mass_j - dy) - dx) * ((dx + -0.019091) / (0.022042 + (r3...
#                                    / 0.15928)))
# 17          1.266e-02  2.609e-02  y = (mass_j - (dx * (0.15928 * mass_j))) * ((dx - 0.020092) / ...
#                                   ((r3 / 0.15928) + 0.022042))
# 19          1.233e-02  1.318e-02  y = (mass_j - ((dx + dy) * (0.15928 * mass_j))) * ((dx - 0.020...
#                                   092) / ((r3 / 0.15928) + 0.022042))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.050e+04
# Head worker occupation: 15.8%
# Progress: 2339 / 7500 total iterations (31.187%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           8.961e-02  7.611e-01  y = dx / (r3 - -0.0021255)
# 7           7.020e-02  1.221e-01  y = dx / ((0.014853 / mass_j) + r3)
# 9           2.947e-02  4.340e-01  y = mass_j * (dx / ((r3 / 0.14866) + 0.013855))
# 11          1.479e-02  3.445e-01  y = mass_j * ((-0.02085 + dx) / ((r3 / 0.15906) + 0.022488))
# 13          1.358e-02  4.289e-02  y = (mass_j - dx) * ((-0.019091 + dx) / (0.022042 + (r3 / 0.15...
#                                   928)))
# 15          1.334e-02  8.775e-03  y = ((mass_j - dy) - dx) * ((dx + -0.019091) / (0.022042 + (r3...
#                                    / 0.15928)))
# 17          1.266e-02  2.609e-02  y = (mass_j - (dx * (0.15928 * mass_j))) * ((dx - 0.020092) / ...
#                                   ((r3 / 0.15928) + 0.022042))
# 19          1.233e-02  1.318e-02  y = (mass_j - ((dx + dy) * (0.15928 * mass_j))) * ((dx - 0.020...
#                                   092) / ((r3 / 0.15928) + 0.022042))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.690e+04
# Head worker occupation: 15.6%
# Progress: 2465 / 7500 total iterations (32.867%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           8.960e-02  7.612e-01  y = dx / (r3 - -0.0019755)
# 7           7.020e-02  1.220e-01  y = dx / ((0.014853 / mass_j) + r3)
# 9           2.947e-02  4.340e-01  y = mass_j * (dx / ((r3 / 0.14866) + 0.013855))
# 11          1.479e-02  3.445e-01  y = mass_j * ((-0.02085 + dx) / ((r3 / 0.15906) + 0.022488))
# 13          1.358e-02  4.289e-02  y = (mass_j - dx) * ((-0.019091 + dx) / (0.022042 + (r3 / 0.15...
#                                   928)))
# 15          1.334e-02  8.775e-03  y = ((mass_j - dy) - dx) * ((dx + -0.019091) / (0.022042 + (r3...
#                                    / 0.15928)))
# 17          1.266e-02  2.609e-02  y = (mass_j - (dx * (0.15928 * mass_j))) * ((dx - 0.020092) / ...
#                                   ((r3 / 0.15928) + 0.022042))
# 19          1.233e-02  1.318e-02  y = (mass_j - ((dx + dy) * (0.15928 * mass_j))) * ((dx - 0.020...
#                                   092) / ((r3 / 0.15928) + 0.022042))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.450e+04
# Head worker occupation: 15.2%
# Progress: 2586 / 7500 total iterations (34.480%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           8.960e-02  7.612e-01  y = dx / (r3 - -0.0019755)
# 7           7.020e-02  1.220e-01  y = dx / ((0.014853 / mass_j) + r3)
# 9           2.947e-02  4.340e-01  y = mass_j * (dx / ((r3 / 0.14866) + 0.013855))
# 11          1.479e-02  3.445e-01  y = mass_j * ((-0.02085 + dx) / ((r3 / 0.15906) + 0.022488))
# 13          1.358e-02  4.289e-02  y = (mass_j - dx) * ((-0.019091 + dx) / (0.022042 + (r3 / 0.15...
#                                   928)))
# 15          1.334e-02  8.775e-03  y = ((mass_j - dy) - dx) * ((dx + -0.019091) / (0.022042 + (r3...
#                                    / 0.15928)))
# 17          1.258e-02  2.943e-02  y = (mass_j - (dx * (0.15928 * mass_j))) * ((dx - 0.019256) / ...
#                                   ((r3 / 0.15928) + 0.022042))
# 19          1.233e-02  9.844e-03  y = (mass_j - ((dx + dy) * (0.15928 * mass_j))) * ((dx - 0.020...
#                                   092) / ((r3 / 0.15928) + 0.022042))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.580e+04
# Head worker occupation: 14.3%
# Progress: 2722 / 7500 total iterations (36.293%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           8.960e-02  7.612e-01  y = dx / (r3 - -0.0019755)
# 7           7.020e-02  1.220e-01  y = dx / ((0.014853 / mass_j) + r3)
# 9           2.947e-02  4.340e-01  y = mass_j * (dx / ((r3 / 0.14866) + 0.013855))
# 11          1.479e-02  3.446e-01  y = mass_j * ((-0.02085 + dx) / ((r3 / 0.15928) + 0.022488))
# 13          1.358e-02  4.288e-02  y = ((dx - 0.019256) / ((r3 / 0.15928) + 0.022042)) * (mass_j ...
#                                   - dx)
# 15          1.334e-02  8.731e-03  y = ((mass_j - dy) - dx) * ((dx + -0.019091) / (0.022042 + (r3...
#                                    / 0.15928)))
# 17          1.256e-02  3.020e-02  y = (mass_j - ((dx * 0.20324) * mass_j)) * ((dx - 0.020092) / ...
#                                   ((r3 / 0.15928) + 0.022042))
# 19          1.233e-02  9.071e-03  y = (mass_j - ((dx + dy) * (0.15928 * mass_j))) * ((dx - 0.020...
#                                   092) / ((r3 / 0.15928) + 0.022042))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.200e+04
# Head worker occupation: 15.3%
# Progress: 2786 / 7500 total iterations (37.147%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           8.960e-02  7.612e-01  y = dx / (r3 - -0.0019755)
# 7           7.020e-02  1.220e-01  y = dx / ((0.014853 / mass_j) + r3)
# 9           2.947e-02  4.340e-01  y = mass_j * (dx / ((r3 / 0.14866) + 0.013855))
# 11          1.479e-02  3.446e-01  y = mass_j * ((-0.02085 + dx) / ((r3 / 0.15928) + 0.022488))
# 13          1.358e-02  4.288e-02  y = ((dx - 0.019256) / ((r3 / 0.15928) + 0.022042)) * (mass_j ...
#                                   - dx)
# 15          1.334e-02  8.731e-03  y = ((mass_j - dy) - dx) * ((dx + -0.019091) / (0.022042 + (r3...
#                                    / 0.15928)))
# 17          1.256e-02  3.020e-02  y = (mass_j - ((dx * 0.20324) * mass_j)) * ((dx - 0.020092) / ...
#                                   ((r3 / 0.15928) + 0.022042))
# 19          1.208e-02  1.943e-02  y = (mass_j - ((dx * 0.20324) * (mass_j + dx))) * ((dx - 0.020...
#                                   092) / ((r3 / 0.15928) + 0.022042))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.110e+04
# Head worker occupation: 14.4%
# Progress: 2913 / 7500 total iterations (38.840%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           8.960e-02  7.612e-01  y = dx / (r3 - -0.0019755)
# 7           7.020e-02  1.220e-01  y = dx / ((0.014853 / mass_j) + r3)
# 9           2.947e-02  4.340e-01  y = mass_j * (dx / ((r3 / 0.14866) + 0.013855))
# 11          1.479e-02  3.446e-01  y = mass_j * ((-0.02085 + dx) / ((r3 / 0.15928) + 0.022488))
# 13          1.358e-02  4.288e-02  y = ((dx - 0.019256) / ((r3 / 0.15928) + 0.022042)) * (mass_j ...
#                                   - dx)
# 15          1.334e-02  8.731e-03  y = ((mass_j - dy) - dx) * ((dx + -0.019091) / (0.022042 + (r3...
#                                    / 0.15928)))
# 17          1.256e-02  3.020e-02  y = (mass_j - ((dx * 0.20324) * mass_j)) * ((dx - 0.020092) / ...
#                                   ((r3 / 0.15928) + 0.022042))
# 19          1.208e-02  1.943e-02  y = (mass_j - ((dx * 0.20324) * (mass_j + dx))) * ((dx - 0.020...
#                                   092) / ((r3 / 0.15928) + 0.022042))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.780e+04
# Head worker occupation: 15.8%
# Progress: 2984 / 7500 total iterations (39.787%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           8.960e-02  7.612e-01  y = dx / (r3 - -0.0019755)
# 7           7.020e-02  1.220e-01  y = dx / ((0.014853 / mass_j) + r3)
# 9           2.947e-02  4.340e-01  y = mass_j * (dx / ((r3 / 0.14866) + 0.013855))
# 11          1.479e-02  3.446e-01  y = mass_j * ((-0.02085 + dx) / ((r3 / 0.15928) + 0.022488))
# 13          1.358e-02  4.288e-02  y = ((dx - 0.019256) / ((r3 / 0.15928) + 0.022042)) * (mass_j ...
#                                   - dx)
# 15          1.334e-02  8.731e-03  y = ((mass_j - dy) - dx) * ((dx + -0.019091) / (0.022042 + (r3...
#                                    / 0.15928)))
# 17          1.256e-02  3.020e-02  y = (mass_j - ((dx * 0.20324) * mass_j)) * ((dx - 0.020092) / ...
#                                   ((r3 / 0.15928) + 0.022042))
# 19          1.208e-02  1.943e-02  y = (mass_j - ((dx * 0.20324) * (mass_j + dx))) * ((dx - 0.020...
#                                   092) / ((r3 / 0.15928) + 0.022042))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.680e+04
# Head worker occupation: 15.4%
# Progress: 3091 / 7500 total iterations (41.213%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           8.960e-02  7.612e-01  y = dx / (r3 - -0.0019755)
# 7           7.020e-02  1.220e-01  y = dx / ((0.014853 / mass_j) + r3)
# 9           2.947e-02  4.340e-01  y = mass_j * (dx / ((r3 / 0.14866) + 0.013855))
# 11          1.479e-02  3.446e-01  y = mass_j * ((-0.02085 + dx) / ((r3 / 0.15928) + 0.022488))
# 13          1.358e-02  4.288e-02  y = ((dx - 0.019256) / ((r3 / 0.15928) + 0.022042)) * (mass_j ...
#                                   - dx)
# 15          1.334e-02  8.731e-03  y = ((mass_j - dy) - dx) * ((dx + -0.019091) / (0.022042 + (r3...
#                                    / 0.15928)))
# 17          1.256e-02  3.020e-02  y = (mass_j - ((dx * 0.20324) * mass_j)) * ((dx - 0.020092) / ...
#                                   ((r3 / 0.15928) + 0.022042))
# 19          1.208e-02  1.943e-02  y = (mass_j - ((dx * 0.20324) * (mass_j + dx))) * ((dx - 0.020...
#                                   092) / ((r3 / 0.15928) + 0.022042))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 5.170e+04
# Head worker occupation: 15.6%
# Progress: 3269 / 7500 total iterations (43.587%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           8.960e-02  7.612e-01  y = dx / (r3 - -0.0019755)
# 7           7.020e-02  1.220e-01  y = dx / ((0.014853 / mass_j) + r3)
# 9           2.947e-02  4.341e-01  y = mass_j * (dx / (0.013812 + (r3 / 0.14922)))
# 11          1.479e-02  3.445e-01  y = mass_j * ((-0.02085 + dx) / ((r3 / 0.15928) + 0.022488))
# 13          1.358e-02  4.288e-02  y = ((dx - 0.019256) / ((r3 / 0.15928) + 0.022042)) * (mass_j ...
#                                   - dx)
# 15          1.334e-02  8.731e-03  y = ((mass_j - dy) - dx) * ((dx + -0.019091) / (0.022042 + (r3...
#                                    / 0.15928)))
# 17          1.253e-02  3.137e-02  y = (mass_j - ((dx * 0.20324) * mass_j)) * ((dx - 0.020092) / ...
#                                   ((r3 / 0.15928) + 0.022488))
# 19          1.206e-02  1.935e-02  y = (mass_j - ((dx * 0.20324) * (mass_j + dx))) * ((dx - 0.020...
#                                   092) / ((r3 / 0.15928) + 0.022488))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.420e+04
# Head worker occupation: 15.9%
# Progress: 3461 / 7500 total iterations (46.147%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           8.960e-02  7.612e-01  y = dx / (r3 - -0.0019755)
# 7           7.020e-02  1.220e-01  y = dx / ((0.014853 / mass_j) + r3)
# 9           2.946e-02  4.341e-01  y = (dx / (0.013832 + (r3 / 0.1491))) * mass_j
# 11          1.479e-02  3.445e-01  y = mass_j * ((-0.02085 + dx) / ((r3 / 0.15928) + 0.022488))
# 13          1.358e-02  4.288e-02  y = ((dx - 0.019256) / ((r3 / 0.15928) + 0.022042)) * (mass_j ...
#                                   - dx)
# 15          1.334e-02  8.731e-03  y = ((mass_j - dy) - dx) * ((dx + -0.019091) / (0.022042 + (r3...
#                                    / 0.15928)))
# 17          1.253e-02  3.137e-02  y = (mass_j - ((dx * 0.20324) * mass_j)) * ((dx - 0.020092) / ...
#                                   ((r3 / 0.15928) + 0.022488))
# 19          1.206e-02  1.935e-02  y = (mass_j - ((dx * 0.20324) * (mass_j + dx))) * ((dx - 0.020...
#                                   092) / ((r3 / 0.15928) + 0.022488))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.550e+04
# Head worker occupation: 15.7%
# Progress: 3657 / 7500 total iterations (48.760%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           8.960e-02  7.612e-01  y = dx / (r3 - -0.0019755)
# 7           7.020e-02  1.220e-01  y = dx / ((0.014853 / mass_j) + r3)
# 9           2.946e-02  4.341e-01  y = (dx / (0.013832 + (r3 / 0.1491))) * mass_j
# 11          1.479e-02  3.445e-01  y = mass_j * ((-0.02085 + dx) / ((r3 / 0.15928) + 0.022488))
# 13          1.358e-02  4.288e-02  y = ((dx - 0.019256) / ((r3 / 0.15928) + 0.022042)) * (mass_j ...
#                                   - dx)
# 15          1.334e-02  8.731e-03  y = ((mass_j - dy) - dx) * ((dx + -0.019091) / (0.022042 + (r3...
#                                    / 0.15928)))
# 17          1.253e-02  3.137e-02  y = (mass_j - ((dx * 0.20324) * mass_j)) * ((dx - 0.020092) / ...
#                                   ((r3 / 0.15928) + 0.022488))
# 19          1.206e-02  1.935e-02  y = (mass_j - ((dx * 0.20324) * (mass_j + dx))) * ((dx - 0.020...
#                                   092) / ((r3 / 0.15928) + 0.022488))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.680e+04
# Head worker occupation: 15.3%
# Progress: 3854 / 7500 total iterations (51.387%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           8.960e-02  7.612e-01  y = dx / (r3 - -0.0019755)
# 7           7.020e-02  1.220e-01  y = dx / ((0.014853 / mass_j) + r3)
# 9           2.946e-02  4.341e-01  y = (dx / (0.013832 + (r3 / 0.1491))) * mass_j
# 11          1.479e-02  3.445e-01  y = mass_j * ((-0.02085 + dx) / ((r3 / 0.15928) + 0.022488))
# 13          1.358e-02  4.288e-02  y = ((dx - 0.019256) / ((r3 / 0.15928) + 0.022042)) * (mass_j ...
#                                   - dx)
# 15          1.334e-02  8.731e-03  y = ((mass_j - dy) - dx) * ((dx + -0.019091) / (0.022042 + (r3...
#                                    / 0.15928)))
# 17          1.253e-02  3.137e-02  y = (mass_j - ((dx * 0.20324) * mass_j)) * ((dx - 0.020092) / ...
#                                   ((r3 / 0.15928) + 0.022488))
# 19          1.206e-02  1.935e-02  y = (mass_j - ((dx * 0.20324) * (mass_j + dx))) * ((dx - 0.020...
#                                   092) / ((r3 / 0.15928) + 0.022488))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.110e+04
# Head worker occupation: 15.8%
# Progress: 4060 / 7500 total iterations (54.133%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           8.960e-02  7.612e-01  y = dx / (r3 - -0.0019755)
# 7           7.020e-02  1.220e-01  y = dx / ((0.014853 / mass_j) + r3)
# 9           2.946e-02  4.341e-01  y = (dx / (0.013832 + (r3 / 0.1491))) * mass_j
# 11          1.479e-02  3.445e-01  y = mass_j * ((-0.02085 + dx) / ((r3 / 0.15928) + 0.022488))
# 13          1.358e-02  4.288e-02  y = ((dx - 0.019256) / ((r3 / 0.15928) + 0.022042)) * (mass_j ...
#                                   - dx)
# 15          1.334e-02  8.731e-03  y = ((mass_j - dy) - dx) * ((dx + -0.019091) / (0.022042 + (r3...
#                                    / 0.15928)))
# 17          1.253e-02  3.137e-02  y = (mass_j - ((dx * 0.20324) * mass_j)) * ((dx - 0.020092) / ...
#                                   ((r3 / 0.15928) + 0.022488))
# 19          1.206e-02  1.935e-02  y = (mass_j - ((dx * 0.20324) * (mass_j + dx))) * ((dx - 0.020...
#                                   092) / ((r3 / 0.15928) + 0.022488))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.290e+04
# Head worker occupation: 15.2%
# Progress: 4272 / 7500 total iterations (56.960%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           8.960e-02  7.612e-01  y = dx / (r3 - -0.0019755)
# 7           7.020e-02  1.220e-01  y = dx / ((0.014853 / mass_j) + r3)
# 9           2.946e-02  4.341e-01  y = (dx / (0.013832 + (r3 / 0.1491))) * mass_j
# 11          1.479e-02  3.445e-01  y = mass_j * ((-0.02085 + dx) / ((r3 / 0.15928) + 0.022488))
# 13          1.358e-02  4.288e-02  y = ((dx - 0.019256) / ((r3 / 0.15928) + 0.022042)) * (mass_j ...
#                                   - dx)
# 15          1.334e-02  8.731e-03  y = ((mass_j - dy) - dx) * ((dx + -0.019091) / (0.022042 + (r3...
#                                    / 0.15928)))
# 17          1.253e-02  3.137e-02  y = (mass_j - ((dx * 0.20324) * mass_j)) * ((dx - 0.020092) / ...
#                                   ((r3 / 0.15928) + 0.022488))
# 19          1.206e-02  1.935e-02  y = (mass_j - ((dx * 0.20324) * (mass_j + dx))) * ((dx - 0.020...
#                                   092) / ((r3 / 0.15928) + 0.022488))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.470e+04
# Head worker occupation: 13.9%
# Progress: 4484 / 7500 total iterations (59.787%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.357e-01  1.594e+01  y = -0.021117
# 3           4.107e-01  1.329e-01  y = -0.0019755 / r3
# 5           8.960e-02  7.612e-01  y = dx / (r3 - -0.0019755)
# 7           7.020e-02  1.220e-01  y = dx / ((0.014853 / mass_j) + r3)
# 9           2.946e-02  4.341e-01  y = (dx / (0.013832 + (r3 / 0.1491))) * mass_j
# 11          1.479e-02  3.445e-01  y = mass_j * ((-0.02085 + dx) / ((r3 / 0.15928) + 0.022488))
# 13          1.358e-02  4.288e-02  y = ((dx - 0.019256) / ((r3 / 0.15928) + 0.022042)) * (mass_j ...
# ...
#                                   ))
# 13          2.210e-02  2.753e-02  y = (-0.13011 * ((dy - -0.033056) / (r3 - -0.0035993))) * (mas...
#                                   s_j - dy)
# 15          2.191e-02  4.283e-03  y = (mass_j - (0.0034957 / dx)) * (-0.13011 * ((dy - -0.033056...
#                                   ) / (r3 - -0.0036142)))
# 17          1.708e-02  1.245e-01  y = (mass_j + (0.071879 / (dy + 0.23164))) * (-0.13011 * ((dy ...
#                                   - -0.033056) / (r3 - -0.0036142)))
# 19          1.538e-02  5.225e-02  y = (mass_j + ((dy / -2.6428) / (dy + 0.23164))) * (-0.13011 *...
#                                    ((dy - -0.033056) / (r3 - -0.0038332)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.950e+04
# Head worker occupation: 14.9%
# Progress: 5897 / 7500 total iterations (78.627%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.117e-01  1.594e+01  y = 0.049636
# 3           4.948e-01  1.681e-02  y = -0.0089102 / dx
# 5           1.159e-01  7.255e-01  y = dy / (-0.0048252 - r3)
# 7           7.791e-02  1.988e-01  y = (dy + 0.032838) / (-0.0035993 - r3)
# 9           4.908e-02  2.311e-01  y = (dy - -0.033056) / ((-0.026148 / mass_j) - r3)
# 11          2.335e-02  3.714e-01  y = mass_j * (-0.12971 * ((dy - -0.031706) / (r3 - -0.0035993)...
#                                   ))
# 13          2.210e-02  2.753e-02  y = (-0.13011 * ((dy - -0.033056) / (r3 - -0.0035993))) * (mas...
#                                   s_j - dy)
# 15          2.191e-02  4.283e-03  y = (mass_j - (0.0034957 / dx)) * (-0.13011 * ((dy - -0.033056...
#                                   ) / (r3 - -0.0036142)))
# 17          1.566e-02  1.680e-01  y = (mass_j + (0.090138 / (dy + 0.23164))) * (-0.13011 * ((dy ...
#                                   - -0.033056) / (r3 - -0.004063)))
# 19          1.454e-02  3.711e-02  y = ((mass_j - dy) + (0.090138 / (dy + 0.23164))) * (-0.13011 ...
#                                   * ((dy - -0.033056) / (r3 - -0.004063)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.000e+05
# Head worker occupation: 14.5%
# Progress: 6117 / 7500 total iterations (81.560%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.117e-01  1.594e+01  y = 0.049636
# 3           4.948e-01  1.681e-02  y = -0.0089102 / dx
# 5           1.159e-01  7.255e-01  y = dy / (-0.0048252 - r3)
# 7           7.791e-02  1.988e-01  y = (dy + 0.032838) / (-0.0035993 - r3)
# 9           4.908e-02  2.311e-01  y = (dy - -0.033056) / ((-0.026148 / mass_j) - r3)
# 11          2.335e-02  3.714e-01  y = mass_j * (-0.12971 * ((dy - -0.031706) / (r3 - -0.0035993)...
#                                   ))
# 13          2.210e-02  2.753e-02  y = (-0.13011 * ((dy - -0.033056) / (r3 - -0.0035993))) * (mas...
#                                   s_j - dy)
# 15          2.191e-02  4.283e-03  y = (mass_j - (0.0034957 / dx)) * (-0.13011 * ((dy - -0.033056...
#                                   ) / (r3 - -0.0036142)))
# 17          1.566e-02  1.680e-01  y = (mass_j + (0.090138 / (dy + 0.23164))) * (-0.13011 * ((dy ...
#                                   - -0.033056) / (r3 - -0.004063)))
# 19          1.454e-02  3.711e-02  y = ((mass_j - dy) + (0.090138 / (dy + 0.23164))) * (-0.13011 ...
#                                   * ((dy - -0.033056) / (r3 - -0.004063)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.690e+04
# Head worker occupation: 14.1%
# Progress: 6317 / 7500 total iterations (84.227%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.117e-01  1.594e+01  y = 0.049636
# 3           4.948e-01  1.681e-02  y = -0.0089102 / dx
# 5           1.159e-01  7.255e-01  y = dy / (-0.0048252 - r3)
# 7           7.791e-02  1.988e-01  y = (dy + 0.032838) / (-0.0035993 - r3)
# 9           4.908e-02  2.311e-01  y = (dy - -0.033056) / ((-0.026148 / mass_j) - r3)
# 11          2.335e-02  3.714e-01  y = mass_j * (-0.12971 * ((dy - -0.031706) / (r3 - -0.0035993)...
#                                   ))
# 13          2.210e-02  2.753e-02  y = (-0.13011 * ((dy - -0.033056) / (r3 - -0.0035993))) * (mas...
#                                   s_j - dy)
# 15          2.191e-02  4.283e-03  y = (mass_j - (0.0034957 / dx)) * (-0.13011 * ((dy - -0.033056...
#                                   ) / (r3 - -0.0036142)))
# 17          1.566e-02  1.680e-01  y = (mass_j + (0.090138 / (dy + 0.23164))) * (-0.13011 * ((dy ...
#                                   - -0.033056) / (r3 - -0.004063)))
# 19          1.454e-02  3.711e-02  y = ((mass_j - dy) + (0.090138 / (dy + 0.23164))) * (-0.13011 ...
#                                   * ((dy - -0.033056) / (r3 - -0.004063)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.200e+04
# Head worker occupation: 13.8%
# Progress: 6500 / 7500 total iterations (86.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.117e-01  1.594e+01  y = 0.049636
# 3           4.948e-01  1.681e-02  y = -0.0089102 / dx
# 5           1.159e-01  7.255e-01  y = dy / (-0.0048252 - r3)
# 7           7.788e-02  1.989e-01  y = (dy + 0.032838) / (-0.0036142 - r3)
# 9           4.908e-02  2.309e-01  y = (dy - -0.033056) / ((-0.026148 / mass_j) - r3)
# 11          2.335e-02  3.714e-01  y = mass_j * (-0.12971 * ((dy - -0.031706) / (r3 - -0.0035993)...
#                                   ))
# 13          2.210e-02  2.753e-02  y = (-0.13011 * ((dy - -0.033056) / (r3 - -0.0035993))) * (mas...
#                                   s_j - dy)
# 15          2.191e-02  4.283e-03  y = (mass_j - (0.0034957 / dx)) * (-0.13011 * ((dy - -0.033056...
#                                   ) / (r3 - -0.0036142)))
# 17          1.566e-02  1.680e-01  y = (mass_j + (0.090138 / (dy + 0.23164))) * (-0.13011 * ((dy ...
#                                   - -0.033056) / (r3 - -0.004063)))
# 19          1.454e-02  3.711e-02  y = ((mass_j - dy) + (0.090138 / (dy + 0.23164))) * (-0.13011 ...
#                                   * ((dy - -0.033056) / (r3 - -0.004063)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.780e+04
# Head worker occupation: 13.7%
# Progress: 6685 / 7500 total iterations (89.133%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.117e-01  1.594e+01  y = 0.049636
# 3           4.948e-01  1.681e-02  y = -0.0089102 / dx
# 5           1.159e-01  7.255e-01  y = dy / (-0.0048252 - r3)
# 7           7.788e-02  1.989e-01  y = (dy + 0.032838) / (-0.0036142 - r3)
# 9           4.908e-02  2.309e-01  y = (dy - -0.033056) / ((-0.026148 / mass_j) - r3)
# 11          2.335e-02  3.714e-01  y = mass_j * (-0.12971 * ((dy - -0.031706) / (r3 - -0.0035993)...
#                                   ))
# 13          2.210e-02  2.753e-02  y = (-0.13011 * ((dy - -0.033056) / (r3 - -0.0035993))) * (mas...
#                                   s_j - dy)
# 15          2.191e-02  4.283e-03  y = (mass_j - (0.0034957 / dx)) * (-0.13011 * ((dy - -0.033056...
#                                   ) / (r3 - -0.0036142)))
# 17          1.566e-02  1.680e-01  y = (mass_j + (0.090138 / (dy + 0.23164))) * (-0.13011 * ((dy ...
#                                   - -0.033056) / (r3 - -0.004063)))
# 19          1.454e-02  3.711e-02  y = ((mass_j - dy) + (0.090138 / (dy + 0.23164))) * (-0.13011 ...
#                                   * ((dy - -0.033056) / (r3 - -0.004063)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.540e+04
# Head worker occupation: 13.3%
# Progress: 6891 / 7500 total iterations (91.880%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.117e-01  1.594e+01  y = 0.049636
# 3           4.948e-01  1.681e-02  y = -0.0089102 / dx
# 5           1.159e-01  7.255e-01  y = dy / (-0.0048252 - r3)
# 7           7.788e-02  1.989e-01  y = (dy + 0.032838) / (-0.0036142 - r3)
# 9           4.908e-02  2.309e-01  y = (dy - -0.033056) / ((-0.026148 / mass_j) - r3)
# 11          2.335e-02  3.714e-01  y = mass_j * (-0.12971 * ((dy - -0.031706) / (r3 - -0.0035993)...
#                                   ))
# 13          2.209e-02  2.757e-02  y = (-0.13011 * ((dy - -0.032833) / (r3 - -0.0035993))) * (mas...
#                                   s_j - dy)
# 15          2.191e-02  4.250e-03  y = (mass_j - (0.0034957 / dx)) * (-0.13011 * ((dy - -0.033056...
#                                   ) / (r3 - -0.0036142)))
# 17          1.566e-02  1.680e-01  y = (mass_j + (0.090138 / (dy + 0.23164))) * (-0.13011 * ((dy ...
#                                   - -0.033056) / (r3 - -0.004063)))
# 19          1.454e-02  3.711e-02  y = ((mass_j - dy) + (0.090138 / (dy + 0.23164))) * (-0.13011 ...
#                                   * ((dy - -0.033056) / (r3 - -0.004063)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.690e+04
# Head worker occupation: 13.2%
# Progress: 7106 / 7500 total iterations (94.747%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.117e-01  1.594e+01  y = 0.049636
# 3           4.948e-01  1.681e-02  y = -0.0089102 / dx
# 5           1.159e-01  7.255e-01  y = dy / (-0.0048252 - r3)
# 7           7.788e-02  1.989e-01  y = (dy + 0.032838) / (-0.0036142 - r3)
# 9           4.908e-02  2.309e-01  y = (dy - -0.033056) / ((-0.026148 / mass_j) - r3)
# 11          2.335e-02  3.714e-01  y = mass_j * (-0.12971 * ((dy - -0.031706) / (r3 - -0.0035993)...
#                                   ))
# 13          2.209e-02  2.757e-02  y = (-0.13011 * ((dy - -0.032833) / (r3 - -0.0035993))) * (mas...
#                                   s_j - dy)
# 15          2.191e-02  4.250e-03  y = (mass_j - (0.0034957 / dx)) * (-0.13011 * ((dy - -0.033056...
#                                   ) / (r3 - -0.0036142)))
# 17          1.566e-02  1.680e-01  y = (mass_j + (0.090138 / (dy + 0.23164))) * (-0.13011 * ((dy ...
#                                   - -0.033056) / (r3 - -0.004063)))
# 19          1.454e-02  3.711e-02  y = ((mass_j - dy) + (0.090138 / (dy + 0.23164))) * (-0.13011 ...
#                                   * ((dy - -0.033056) / (r3 - -0.004063)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.070e+04
# Head worker occupation: 12.6%
# Progress: 7322 / 7500 total iterations (97.627%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           5.117e-01  1.594e+01  y = 0.049636
# 3           4.948e-01  1.681e-02  y = -0.0089102 / dx
# 5           1.159e-01  7.255e-01  y = dy / (-0.0048252 - r3)
# 7           7.788e-02  1.989e-01  y = (dy + 0.032838) / (-0.0036142 - r3)
# 9           4.908e-02  2.309e-01  y = (dy - -0.033056) / ((-0.026148 / mass_j) - r3)
# 11          2.335e-02  3.714e-01  y = mass_j * (-0.12971 * ((dy - -0.031706) / (r3 - -0.0035993)...
#                                   ))
# 13          2.209e-02  2.757e-02  y = (-0.13011 * ((dy - -0.032833) / (r3 - -0.0035993))) * (mas...
#                                   s_j - dy)
# 15          2.191e-02  4.250e-03  y = (mass_j - (0.0034957 / dx)) * (-0.13011 * ((dy - -0.033056...
#                                   ) / (r3 - -0.0036142)))
# 17          1.559e-02  1.700e-01  y = (mass_j + (0.090138 / (dy + 0.23164))) * (-0.12971 * ((dy ...
#                                   - -0.033056) / (r3 - -0.004063)))
# 19          1.454e-02  3.510e-02  y = ((mass_j - dy) + (0.090138 / (dy + 0.23164))) * (-0.13011 ...
#                                   * ((dy - -0.033056) / (r3 - -0.004063)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# Best expression for message_y:
# PySRRegressor.equations_ = [
# 	   pick     score                                           equation  \
# 	0        0.000000                                         0.04963564
# 	1        0.016813                                  -0.008910206 / dx
# 	2        0.725529                           dy / (-0.004825214 - r3)
# 	3        0.200750          (0.030374965 + dy) / (-0.0036142347 - r3)
# 	4        0.229094  (dy - -0.03305557) / ((-0.026147982 / mass_j) ...
# 	5        0.371448  mass_j * (-0.12971053 * ((dy - -0.031705935) /...
# 	6        0.027566  (-0.13011481 * ((dy - -0.032833297) / (r3 - -0...
# 	7        0.004250  (mass_j - (0.0034957326 / dx)) * (-0.13011481 ...
# 	8  >>>>  0.169957  (mass_j + (0.09013818 / (dy + 0.23164065))) * ...
# 	9        0.035101  ((mass_j - dy) + (0.09013818 / (dy + 0.2316406...
#
# 	       loss  complexity
# 	0  0.511703           1
# 	1  0.494782           3
# 	2  0.115938           5
# 	3  0.077599           7
# 	4  0.049076           9
# 	5  0.023347          11
# 	6  0.022095          13
# 	7  0.021908          15
# 	8  0.015595          17
# 	9  0.014537          19
# ]

# %%
import numpy as np
import pandas as pd
from pysr import PySRRegressor

# Assume you have already trained a PySR model
train_model_x.refresh()  # Load results if not already loaded

# Extract discovered equations
df_eq = train_model_x.equations_
df = df_eq.sort_values("complexity")  # Ensure sorting by complexity

# Compute the selection criterion
complexities = df_eq["complexity"].values
mse_values = df_eq["loss"].values  # Loss is usually MSE in PySR

# Compute fractional drop in log MSE
delta_log_mse = -np.diff(np.log(mse_values))
delta_complexity = np.diff(complexities)

# Compute selection criterion
selection_criterion = delta_log_mse / delta_complexity

# Find the best model according to the criterion
best_index = np.argmax(selection_criterion)
best_model = df_eq.iloc[best_index + 1]  # +1 because diff reduces size by 1

# Display best model
print(best_model)
# Out:
# complexity                                                  5
# loss                                                 0.089596
# score                                                0.761232
# equation                            dx / (r3 - -0.0019755173)
# sympy_format                      dx/(r3 - 1*(-0.0019755173))
# lambda_format    PySRFunction(X=>dx/(r3 - 1*(-0.0019755173)))
# Name: 2, dtype: object
